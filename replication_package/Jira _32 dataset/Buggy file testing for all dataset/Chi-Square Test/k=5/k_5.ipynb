# %%
## Load Data and preparing datasets

# Import for Load Data
from os import listdir
from os.path import isfile, join
import pandas as pd

# Import for Split Data into Training and Testing Samples
from sklearn.model_selection import train_test_split


import os
import numpy as np
from glob import glob
import subprocess
import sys
import importlib
import numpy
import shap
import matplotlib.pyplot as plt
import random
import lime
import lime.lime_tabular
from sklearn.ensemble import RandomForestClassifier
from pyBreakDown.explainer import Explainer
from pyBreakDown.explanation import Explanation
from pyexplainer.pyexplainer_pyexplainer import PyExplainer
import io
import contextlib
import re
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# feature agreement
def calculate_task1(dict1, dict2):
    if len(dict1) == 0 or len(dict2) == 0:
        return 0.00
    keys1 = set(dict1.keys())
    keys2 = set(dict2.keys())
    common_keys = len(keys1.intersection(keys2))
    return common_keys / max(len(dict1), len(dict2))

# Rank Agreement
def calculate_task2(dict1, dict2):
    if len(dict1) == 0 or len(dict2) == 0:
        return 0.00
    keys1 = list(dict1.keys())
    keys2 = list(dict2.keys())
    common_keys = 0
    for i in range(min(len(keys1), len(keys2))):
        if keys1[i] == keys2[i]:
            common_keys += 1
    return common_keys / max(len(dict1), len(dict2))

# Sign Agreement
def calculate_task3(dict1, dict2):
    if len(dict1) == 0 or len(dict2) == 0:
        return 0.00
    common_signs = 0
    total_common = 0
    for key in dict1:
        if key in dict2:
            if dict1[key] * dict2[key] > 0:
                common_signs += 1
            total_common += 1
    if total_common == 0:
        return 0.00
    return common_signs / total_common

file_list = glob("/Users/saumenduroy/Desktop/TOSEM_replicationpackage/data_jira/*.csv")
tested_file = []

for file in file_list:
    main_file=file
    train_dataset = pd.read_csv(file, index_col = 'File')
    
    test_data_list = [f for f in file_list if f != file]
    test_dataset = pd.DataFrame(columns=["File"]+train_dataset.columns.values.tolist())
    for test_file in test_data_list:
        tmp_df = pd.read_csv(test_file)
        test_dataset = pd.DataFrame(np.concatenate([test_dataset.values, tmp_df.values]), columns=tmp_df.columns)
    test_dataset.set_index("File", inplace=True)
    outcome = 'RealBug'
    features = ['CountPath_Max', 'CountPath_Mean', 'Del_lines', 'Added_lines', 'CountLine']
    # commits - # of commits that modify the file of interest
    # Added lines - # of added lines of code
    # Count class coupled - # of classes that interact or couple with the class of interest
    # LOC - # of lines of code
    # RatioCommentToCode - The ratio of lines of comments to lines of code

    # process outcome to 0 and 1
    train_dataset[outcome] = pd.Categorical(train_dataset[outcome])
    train_dataset[outcome] = train_dataset[outcome].cat.codes

    test_dataset[outcome] = pd.Categorical(test_dataset[outcome])
    test_dataset[outcome] = test_dataset[outcome].cat.codes

    X_train = train_dataset.loc[:, features]
    X_test = test_dataset.loc[:, features]

    y_train = train_dataset.loc[:, outcome]
    y_test = test_dataset.loc[:, outcome]

    class_labels = ['Clean', 'Defective']

    X_train.columns = features
    X_test.columns = features
    training_data = pd.concat([X_train, y_train], axis=1)
    testing_data = pd.concat([X_test, y_test], axis=1)

    our_rf_model = RandomForestClassifier(random_state=0)
    our_rf_model.fit(X_train, y_train)  
    
    #### LIME

    # Import for LIME
    
    
    file_to_be_explained = ""
    
    worked = True
    
    while worked:
        try:
            
            random_file = random.choice(testing_data.index.values.tolist())
            if random_file in tested_file:
                continue
            file_to_be_explained = random_file
            # LIME Step 1 - Construct an explainer
            our_lime_explainer = lime.lime_tabular.LimeTabularExplainer(
                                        training_data = X_train.values,  
                                        mode = 'classification',
                                        training_labels = y_train,
                                        feature_names = features,
                                        class_names = class_labels,
                                        discretize_continuous = True)

            # LIME Step 2 - Use the constructed explainer with the predict function 
            # of your predictive model to explain any instance
            lime_local_explanation_of_an_instance = our_lime_explainer.explain_instance(
                                        data_row = X_test.loc[file_to_be_explained, : ],
                                        predict_fn = our_rf_model.predict_proba, 
                                        num_features = len(features),
                                        top_labels = 1)

            #explainer = lime_tabular.LimeTabularExplainer(X_train, mode = "regression", feature_names = boston_housing.feature_names)
            #explanation = explainer.explain_instance(X_test[0], model.predict, num_features = len(boston_housing.feature_names))
            lime_prob = lime_local_explanation_of_an_instance.predict_proba
            if lime_prob[1] >= 0.67:
                print(f'Explaining {file_to_be_explained} with LIME')
                lime_results = lime_local_explanation_of_an_instance.as_list()
                lime_dict = {}
                for results in lime_results:
                    feat = ""
                    for r in results:
                        ignoring_sym = [">=", ">", "<=", "<", "="]
                        if isinstance(r, str):
                            feat = re.sub(r'[^a-zA-Z\s_]', '', r).rstrip().lstrip()
                        else:
                            if r >= 0:
                                lime_dict[feat] = 1
                            else:
                                lime_dict[feat] = -1
                print(lime_dict)
            
                # Please use the code below to visualise the generated LIME explanation.
                ### save lime output
                # lime_local_explanation_of_an_instance.show_in_notebook()
                
                
                ### SHAP:
                file_to_be_explained_idx = list(X_test.index).index(file_to_be_explained)
                explainer = shap.Explainer(our_rf_model)
                shap_values = explainer(X_test)
                # shap.plots.bar(shap_values[file_to_be_explained_idx, :, 1], show=True)
                explain_file_val = shap_values[file_to_be_explained_idx, :, 1].values.tolist()
                shap_dict = {}
                test_columns = X_test.columns.values.tolist()
                for col_index in range(0, len(test_columns)):
                    shap_dict[test_columns[col_index]] = explain_file_val[col_index]
                sorted_shap_dict = dict(sorted(shap_dict.items(), key=lambda item: abs(item[1]), reverse=True))
                for keys in sorted_shap_dict.keys():
                    if sorted_shap_dict[keys] >= 0:
                        sorted_shap_dict[keys] = 1
                    else:
                        sorted_shap_dict[keys] = -1
                print(sorted_shap_dict)
                
                
                #Breakdown
                our_rf_model = RandomForestClassifier(random_state=0)
                our_rf_model.fit(X_train, y_train)
                #make explainer object
                exp = Explainer(clf=our_rf_model, data= X_train, colnames=features)
                #make explanation object that contains all information
                explanation = exp.explain(observation=X_test.iloc[file_to_be_explained_idx,:].values,direction="up",useIntercept=True)
                # explanation.visualize()
                output_buffer = io.StringIO()
                with contextlib.redirect_stdout(output_buffer):
                    explanation.text()

                captured_output = output_buffer.getvalue()
                with open("test.txt", "w") as file:
                    file.write(captured_output)
                    
                breakdown_df = pd.read_csv("test.txt", sep='\t')
                
                counter=-1
                breakdown_dict={}
                for _, row in breakdown_df.iterrows():
                    counter+=1
                    if counter < 1:
                        continue
                    row_val = row.values.tolist()
                    row_val = row_val[0].split(" ")
                    row_val_main = []
                    for c in row_val:
                        if len(c) == 0 or c == "=":
                            continue
                        row_val_main.append(c)
                    if float(row_val_main[2]) >= 0:
                        breakdown_dict[row_val_main[0]] = 1
                    else:
                        breakdown_dict[row_val_main[0]] = -1
                    if counter == len(features):
                        break
                print(breakdown_dict)
                
                
                #### pyexplainer
                rf_model = RandomForestClassifier(random_state=0)
                rf_model.fit(X_train, y_train) 
                np.random.seed(0)
                pyexp = PyExplainer(X_train = X_train,
                                           y_train = y_train,
                                           indep = X_train.columns,
                                           dep = outcome,
                                           top_k_rules=5,
                                           blackbox_model = rf_model)

                # PyExplainer Step 2 - Generate the rule-based explanation of an instance to be explained
                exp_obj = pyexp.explain(X_explain = X_test.loc[file_to_be_explained,:].to_frame().transpose(),
                                        y_explain = pd.Series(bool(y_test.loc[file_to_be_explained]), 
                                                                      index = [file_to_be_explained],
                                                                      name = outcome),
                                        search_function = 'crossoverinterpolation',
                                        max_iter=1000,
                                        max_rules=20,
                                        random_state=0,
                                        reuse_local_model=True)

                # Please use the code below to visualise the generated PyExplainer explanation (What-If interactive visualisation).
                pyexp.visualise(exp_obj, title="Why this file is predicted as defect-introducing?")
                top_rules = pyexp.parse_top_rules(exp_obj['top_k_positive_rules'],exp_obj['top_k_negative_rules'])['top_tofollow_rules']
                bullet_data = pyexp.generate_bullet_data(pyexp.parse_top_rules(exp_obj['top_k_positive_rules'],exp_obj['top_k_negative_rules']))
                pyexp_dict = {}
                for rules in range(0, len(top_rules)):
                    variable = top_rules[rules]['variable']
                    value = float(top_rules[rules]['value'])
                    marker = bullet_data[rules]['markers'][0]
                    if top_rules[rules]['lessthan']:
                        if marker <= value:
                            pyexp_dict[variable] = 1
                        else:
                            pyexp_dict[variable] = -1
                    else:
                        if marker > value:
                            pyexp_dict[variable] = 1
                        else:
                            pyexp_dict[variable] = -1

                print(pyexp_dict)
                worked=False
                tested_file.append(file_to_be_explained)
                
                    
                data_task1 = np.array([
                    [calculate_task1(lime_dict, lime_dict), calculate_task1(lime_dict, sorted_shap_dict), calculate_task1(lime_dict, breakdown_dict), calculate_task1(lime_dict, pyexp_dict)],
                    [calculate_task1(sorted_shap_dict, lime_dict), calculate_task1(sorted_shap_dict, sorted_shap_dict), calculate_task1(sorted_shap_dict, breakdown_dict), calculate_task1(sorted_shap_dict, pyexp_dict)],
                    [calculate_task1(breakdown_dict, lime_dict), calculate_task1(breakdown_dict, sorted_shap_dict), calculate_task1(breakdown_dict, breakdown_dict), calculate_task1(breakdown_dict, pyexp_dict)],
                    [calculate_task1(pyexp_dict, lime_dict), calculate_task1(pyexp_dict, sorted_shap_dict), calculate_task1(pyexp_dict, breakdown_dict), calculate_task1(pyexp_dict, pyexp_dict)]
                ])

                data_task2 = np.array([
                    [calculate_task2(lime_dict, lime_dict), calculate_task2(lime_dict, sorted_shap_dict), calculate_task2(lime_dict, breakdown_dict), calculate_task2(lime_dict, pyexp_dict)],
                    [calculate_task2(sorted_shap_dict, lime_dict), calculate_task2(sorted_shap_dict, sorted_shap_dict), calculate_task2(sorted_shap_dict, breakdown_dict), calculate_task2(sorted_shap_dict, pyexp_dict)],
                    [calculate_task2(breakdown_dict, lime_dict), calculate_task2(breakdown_dict, sorted_shap_dict), calculate_task2(breakdown_dict, breakdown_dict), calculate_task2(breakdown_dict, pyexp_dict)],
                    [calculate_task2(pyexp_dict, lime_dict), calculate_task2(pyexp_dict, sorted_shap_dict), calculate_task2(pyexp_dict, breakdown_dict), calculate_task2(pyexp_dict, pyexp_dict)]
                ])

                data_task3 = np.array([
                    [calculate_task3(lime_dict, lime_dict), calculate_task3(lime_dict, sorted_shap_dict), calculate_task3(lime_dict, breakdown_dict), calculate_task3(lime_dict, pyexp_dict)],
                    [calculate_task3(sorted_shap_dict, lime_dict), calculate_task3(sorted_shap_dict, sorted_shap_dict), calculate_task3(sorted_shap_dict, breakdown_dict), calculate_task3(sorted_shap_dict, pyexp_dict)],
                    [calculate_task3(breakdown_dict, lime_dict), calculate_task3(breakdown_dict, sorted_shap_dict), calculate_task3(breakdown_dict, breakdown_dict), calculate_task3(breakdown_dict, pyexp_dict)],
                    [calculate_task3(pyexp_dict, lime_dict), calculate_task3(pyexp_dict, sorted_shap_dict), calculate_task3(pyexp_dict, breakdown_dict), calculate_task3(pyexp_dict, pyexp_dict)]
                ])

                # Row and column labels
                pairs = ["LIME", "SHAP", "BreakDown", "PyExplainer"]
                tasks = ["Feature Agreement", "Rank Agreement", "Sign Agreement"]

                # Create the figure and subplots
                fig, axes = plt.subplots(1, 3, figsize=(18, 6))
                fig.suptitle("Processing file: "+main_file.split("/")[-1])

                # Plot heatmap for FA
                sns.heatmap(data_task1, annot=True, cmap="coolwarm", fmt=".2f", linewidths=.5, xticklabels=pairs, yticklabels=pairs, ax=axes[0])
                axes[0].set_title(tasks[0] + " (When k="+str(len(features))+")")
                
                # Plot heatmap for SA
                sns.heatmap(data_task3, annot=True, cmap="coolwarm", fmt=".2f", linewidths=.5, xticklabels=pairs, yticklabels=pairs, ax=axes[1])
                axes[1].set_title(tasks[2] + " (When k="+str(len(features))+")")

                # Plot heatmap for RA
                sns.heatmap(data_task2, annot=True, cmap="coolwarm", fmt=".2f", linewidths=.5, xticklabels=pairs, yticklabels=pairs, ax=axes[2])
                axes[2].set_title(tasks[1] + " (When k="+str(len(features))+")")

                plt.tight_layout()
                fig_file_name = main_file.split("/")[-1].replace(".", "_")+"-"+file_to_be_explained.replace("/", "_").replace(".","_")+"_fa_ra_sa_plot.png"
                plt.savefig(fig_file_name)
                
            else:
                continue
            
        except Exception as e:
            pass
# Out:
# Explaining ql/src/java/org/apache/hadoop/hive/ql/exec/TopNHash.java with LIME
# {'Added_lines': 1, 'CountLine': 1, 'Del_lines': -1, 'CountPath_Max': 1, 'CountPath_Mean': -1}
# {'Added_lines': 1, 'CountLine': 1, 'CountPath_Mean': 1, 'Del_lines': -1, 'CountPath_Max': 1}
# {'Added_lines': 1, 'CountLine': 1, 'CountPath_Max': 1, 'CountPath_Mean': 1, 'Del_lines': 1}
# set top_k_rules failed, top_k_rules should be int in range 1 - 15 (both included)
# PyExplainer can not find rules to avoid!
# This could lead to blank explanation UI!
# Please check whether the global model is properly trained with sufficient training data.
# HBox(children=(Label(value='Risk Score: '), FloatProgress(value=0.0, bar_style='info', layout=Layout(width='40…
# Output(layout=Layout(border='3px solid black'))
# FloatSlider(value=259.0, continuous_update=False, description='#1 The value of CountLine is more than 259', la…
# FloatSlider(value=259.0, continuous_update=False, description='#2 The value of Added_lines is more than 259', …
# FloatSlider(value=1.31, continuous_update=False, description='#3 The value of CountPath_Mean is more than 1.31…
# set top_k_rules failed, top_k_rules should be int in range 1 - 15 (both included)
# PyExplainer can not find rules to avoid!
# This could lead to blank explanation UI!
# Please check whether the global model is properly trained with sufficient training data.
# set top_k_rules failed, top_k_rules should be int in range 1 - 15 (both included)
# PyExplainer can not find rules to avoid!
# This could lead to blank explanation UI!
# Please check whether the global model is properly trained with sufficient training data.
# {'CountLine': 1, 'Added_lines': -1, 'CountPath_Mean': 1}
# Explaining wicket-core/src/main/java/org/apache/wicket/markup/html/form/FormComponent.java with LIME
# {'CountLine': 1, 'Added_lines': 1, 'CountPath_Max': 1, 'Del_lines': 1, 'CountPath_Mean': 1}
# {'CountLine': 1, 'Added_lines': 1, 'Del_lines': 1, 'CountPath_Mean': 1, 'CountPath_Max': 1}
# {'Del_lines': -1, 'Added_lines': 1, 'CountLine': 1, 'CountPath_Max': 1, 'CountPath_Mean': 1}
# set top_k_rules failed, top_k_rules should be int in range 1 - 15 (both included)
# PyExplainer can not find rules to avoid!
# This could lead to blank explanation UI!
# Please check whether the global model is properly trained with sufficient training data.
# HBox(children=(Label(value='Risk Score: '), FloatProgress(value=0.0, bar_style='info', layout=Layout(width='40…
# Output(layout=Layout(border='3px solid black'))
# FloatSlider(value=1550.0, continuous_update=False, description='#1 The value of CountLine is more than 1550', …
# FloatSlider(value=2.56, continuous_update=False, description='#2 The value of CountPath_Mean is less than 2.56…
# FloatSlider(value=115.0, continuous_update=False, description='#3 The value of Added_lines is more than 115', …
# set top_k_rules failed, top_k_rules should be int in range 1 - 15 (both included)
# PyExplainer can not find rules to avoid!
# This could lead to blank explanation UI!
# Please check whether the global model is properly trained with sufficient training data.
# set top_k_rules failed, top_k_rules should be int in range 1 - 15 (both included)
# PyExplainer can not find rules to avoid!
# This could lead to blank explanation UI!
# Please check whether the global model is properly trained with sufficient training data.
# {'CountLine': -1, 'CountPath_Mean': -1, 'Added_lines': -1}
# Explaining lucene/backwards/src/test/org/apache/lucene/index/TestSegmentTermEnum.java with LIME
# {'CountLine': -1, 'Added_lines': -1, 'Del_lines': -1, 'CountPath_Max': -1, 'CountPath_Mean': 1}
# {'CountPath_Mean': 1, 'CountPath_Max': 1, 'CountLine': 1, 'Del_lines': 1, 'Added_lines': 1}
# {'CountLine': -1, 'CountPath_Max': -1, 'CountPath_Mean': 1, 'Added_lines': 1, 'Del_lines': 1}
# set top_k_rules failed, top_k_rules should be int in range 1 - 15 (both included)
# PyExplainer can not find rules to avoid!
# This could lead to blank explanation UI!
# Please check whether the global model is properly trained with sufficient training data.
# HBox(children=(Label(value='Risk Score: '), FloatProgress(value=0.0, bar_style='info', layout=Layout(width='40…
# Output(layout=Layout(border='3px solid black'))
# FloatSlider(value=1.25, continuous_update=False, description='#1 The value of CountPath_Mean is more than 1.25…
# FloatSlider(value=0.0, continuous_update=False, description='#2 The value of Added_lines is more than 0', layo…
# FloatSlider(value=123.0, continuous_update=False, description='#3 The value of CountLine is more than 123', la…
# set top_k_rules failed, top_k_rules should be int in range 1 - 15 (both included)
# PyExplainer can not find rules to avoid!
# This could lead to blank explanation UI!
# Please check whether the global model is properly trained with sufficient training data.
# set top_k_rules failed, top_k_rules should be int in range 1 - 15 (both included)
# PyExplainer can not find rules to avoid!
# This could lead to blank explanation UI!
# Please check whether the global model is properly trained with sufficient training data.
# {'CountPath_Mean': 1, 'Added_lines': 1, 'CountLine': -1}
# Explaining src/test/java/org/apache/hadoop/hbase/io/encoding/TestDataBlockEncoders.java with LIME
# {'CountLine': 1, 'CountPath_Mean': 1, 'Added_lines': 1, 'CountPath_Max': 1, 'Del_lines': 1}
# {'Added_lines': 1, 'CountLine': 1, 'Del_lines': 1, 'CountPath_Max': 1, 'CountPath_Mean': 1}
# {'Del_lines': -1, 'CountPath_Mean': -1, 'CountPath_Max': 1, 'CountLine': 1, 'Added_lines': 1}
# set top_k_rules failed, top_k_rules should be int in range 1 - 15 (both included)
# PyExplainer can not find rules to avoid!
# This could lead to blank explanation UI!
# Please check whether the global model is properly trained with sufficient training data.
# HBox(children=(Label(value='Risk Score: '), FloatProgress(value=0.0, bar_style='info', layout=Layout(width='40…
# Output(layout=Layout(border='3px solid black'))
# FloatSlider(value=346.0, continuous_update=False, description='#1 The value of CountLine is more than 346', la…
# FloatSlider(value=389.0, continuous_update=False, description='#2 The value of Del_lines is less than 389', la…
# set top_k_rules failed, top_k_rules should be int in range 1 - 15 (both included)
# PyExplainer can not find rules to avoid!
# This could lead to blank explanation UI!
# Please check whether the global model is properly trained with sufficient training data.
# set top_k_rules failed, top_k_rules should be int in range 1 - 15 (both included)
# PyExplainer can not find rules to avoid!
# This could lead to blank explanation UI!
# Please check whether the global model is properly trained with sufficient training data.
# {'CountLine': 1, 'Del_lines': 1}
# Explaining src/main/java/org/apache/hadoop/hbase/migration/HRegionInfo090x.java with LIME
# {'CountLine': 1, 'CountPath_Max': 1, 'Del_lines': -1, 'Added_lines': 1, 'CountPath_Mean': 1}
# {'CountLine': 1, 'CountPath_Max': 1, 'CountPath_Mean': 1, 'Added_lines': -1, 'Del_lines': -1}
# {'Added_lines': -1, 'CountLine': -1, 'CountPath_Max': 1, 'CountPath_Mean': 1, 'Del_lines': 1}
# HBox(children=(Label(value='Risk Score: '), FloatProgress(value=0.0, bar_style='info', layout=Layout(width='40…
# Output(layout=Layout(border='3px solid black'))
# FloatSlider(value=680.0, continuous_update=False, description='#1 The value of CountLine is less than 680', la…
# {'CountLine': 1}
# Explaining activemq-unit-tests/src/test/java/org/apache/activemq/ActiveMQInputStreamTest.java with LIME
# {'Del_lines': -1, 'Added_lines': 1, 'CountLine': -1, 'CountPath_Mean': 1, 'CountPath_Max': 1}
# {'Added_lines': 1, 'CountPath_Max': 1, 'CountPath_Mean': 1, 'CountLine': 1, 'Del_lines': 1}
# {'CountLine': -1, 'CountPath_Mean': -1, 'Del_lines': 1, 'Added_lines': 1, 'CountPath_Max': 1}
# HBox(children=(Label(value='Risk Score: '), FloatProgress(value=0.0, bar_style='info', layout=Layout(width='40…
# Output(layout=Layout(border='3px solid black'))
# FloatSlider(value=141.0, continuous_update=False, description='#1 The value of Added_lines is more than 141', …
# {'Added_lines': -1}
# Explaining java/testing/org/apache/derbyTesting/functionTests/tests/jdbcapi/J2EEDataSourceTest.java with LIME
# {'CountPath_Max': 1, 'CountLine': 1, 'Del_lines': 1, 'Added_lines': 1, 'CountPath_Mean': -1}
# {'CountLine': 1, 'CountPath_Max': 1, 'Del_lines': 1, 'Added_lines': 1, 'CountPath_Mean': 1}
# {'CountPath_Mean': -1, 'Del_lines': 1, 'CountLine': 1, 'CountPath_Max': 1, 'Added_lines': 1}
# set top_k_rules failed, top_k_rules should be int in range 1 - 15 (both included)
# PyExplainer can not find rules to avoid!
# This could lead to blank explanation UI!
# Please check whether the global model is properly trained with sufficient training data.
# HBox(children=(Label(value='Risk Score: '), FloatProgress(value=0.0, bar_style='info', layout=Layout(width='40…
# Output(layout=Layout(border='3px solid black'))
# FloatSlider(value=4116.0, continuous_update=False, description='#1 The value of CountLine is more than 4116', …
# FloatSlider(value=9009222.29, continuous_update=False, description='#2 The value of CountPath_Mean is more tha…
# FloatSlider(value=43.0, continuous_update=False, description='#3 The value of Del_lines is more than 43', layo…
# set top_k_rules failed, top_k_rules should be int in range 1 - 15 (both included)
# PyExplainer can not find rules to avoid!
# This could lead to blank explanation UI!
# Please check whether the global model is properly trained with sufficient training data.
# set top_k_rules failed, top_k_rules should be int in range 1 - 15 (both included)
# PyExplainer can not find rules to avoid!
# This could lead to blank explanation UI!
# Please check whether the global model is properly trained with sufficient training data.
# {'CountLine': -1, 'CountPath_Mean': -1, 'Del_lines': -1}
# Explaining jdbc/src/java/org/apache/hive/jdbc/HiveConnection.java with LIME
# {'Added_lines': 1, 'CountPath_Max': 1, 'CountLine': 1, 'Del_lines': 1, 'CountPath_Mean': -1}
# {'CountLine': 1, 'Added_lines': 1, 'Del_lines': 1, 'CountPath_Mean': 1, 'CountPath_Max': -1}
# {'CountLine': 1, 'Del_lines': 1, 'Added_lines': 1, 'CountPath_Max': 1, 'CountPath_Mean': 1}
# set top_k_rules failed, top_k_rules should be int in range 1 - 15 (both included)
# PyExplainer can not find rules to avoid!
# This could lead to blank explanation UI!
# Please check whether the global model is properly trained with sufficient training data.
# HBox(children=(Label(value='Risk Score: '), FloatProgress(value=0.0, bar_style='info', layout=Layout(width='40…
# Output(layout=Layout(border='3px solid black'))
# FloatSlider(value=885.0, continuous_update=False, description='#1 The value of CountLine is more than 885', la…
# FloatSlider(value=80.0, continuous_update=False, description='#2 The value of Del_lines is more than 80', layo…
# FloatSlider(value=9.0, continuous_update=False, description='#3 The value of CountPath_Max is more than 9', la…
# set top_k_rules failed, top_k_rules should be int in range 1 - 15 (both included)
# PyExplainer can not find rules to avoid!
# This could lead to blank explanation UI!
# Please check whether the global model is properly trained with sufficient training data.
# set top_k_rules failed, top_k_rules should be int in range 1 - 15 (both included)
# PyExplainer can not find rules to avoid!
# This could lead to blank explanation UI!
# Please check whether the global model is properly trained with sufficient training data.
# {'CountLine': -1, 'Del_lines': 1, 'CountPath_Max': 1}
# Explaining src/main/java/org/apache/hadoop/hbase/regionserver/Store.java with LIME
# {'Del_lines': 1, 'CountLine': 1, 'CountPath_Mean': -1, 'Added_lines': 1, 'CountPath_Max': 1}
# {'CountLine': 1, 'Del_lines': 1, 'CountPath_Mean': 1, 'CountPath_Max': 1, 'Added_lines': 1}
# {'CountLine': 1, 'Del_lines': 1, 'CountPath_Mean': 1, 'CountPath_Max': 1, 'Added_lines': 1}
# set top_k_rules failed, top_k_rules should be int in range 1 - 15 (both included)
# PyExplainer can not find rules to avoid!
# This could lead to blank explanation UI!
# Please check whether the global model is properly trained with sufficient training data.
# HBox(children=(Label(value='Risk Score: '), FloatProgress(value=0.0, bar_style='info', layout=Layout(width='40…
# Output(layout=Layout(border='3px solid black'))
# FloatSlider(value=800.0, continuous_update=False, description='#1 The value of Added_lines is less than 800', …
# FloatSlider(value=1610.0, continuous_update=False, description='#2 The value of CountPath_Max is more than 161…
# FloatSlider(value=2316.0, continuous_update=False, description='#3 The value of CountLine is less than 2316', …
# set top_k_rules failed, top_k_rules should be int in range 1 - 15 (both included)
# PyExplainer can not find rules to avoid!
# This could lead to blank explanation UI!
# Please check whether the global model is properly trained with sufficient training data.
# set top_k_rules failed, top_k_rules should be int in range 1 - 15 (both included)
# PyExplainer can not find rules to avoid!
# This could lead to blank explanation UI!
# Please check whether the global model is properly trained with sufficient training data.
# {'Added_lines': -1, 'CountPath_Max': -1, 'CountLine': 1}
# Explaining hbase-client/src/main/java/org/apache/hadoop/hbase/ipc/RpcClient.java with LIME
# {'CountLine': 1, 'Del_lines': 1, 'CountPath_Max': 1, 'Added_lines': 1, 'CountPath_Mean': 1}
# {'Del_lines': 1, 'CountLine': 1, 'Added_lines': 1, 'CountPath_Max': 1, 'CountPath_Mean': 1}
# {'CountLine': 1, 'Del_lines': 1, 'Added_lines': 1, 'CountPath_Max': 1, 'CountPath_Mean': 1}
# HBox(children=(Label(value='Risk Score: '), FloatProgress(value=0.0, bar_style='info', layout=Layout(width='40…
# Output(layout=Layout(border='3px solid black'))
# FloatSlider(value=25.0, continuous_update=False, description='#1 The value of Del_lines is more than 25', layo…
# {'Del_lines': -1}
# Explaining ql/src/java/org/apache/hadoop/hive/ql/exec/persistence/PTFRowContainer.java with LIME
# {'CountLine': 1, 'Added_lines': 1, 'CountPath_Max': 1, 'Del_lines': 1, 'CountPath_Mean': -1}
# {'Added_lines': 1, 'Del_lines': 1, 'CountLine': 1, 'CountPath_Max': -1, 'CountPath_Mean': 1}
# {'CountPath_Max': -1, 'CountPath_Mean': -1, 'CountLine': -1, 'Added_lines': 1, 'Del_lines': 1}
# HBox(children=(Label(value='Risk Score: '), FloatProgress(value=0.0, bar_style='info', layout=Layout(width='40…
# Output(layout=Layout(border='3px solid black'))
# FloatSlider(value=306.0, continuous_update=False, description='#1 The value of CountLine is less than 306', la…
# {'CountLine': 1}
# Explaining lucene/src/test/org/apache/lucene/index/TestTermVectorsWriter.java with LIME
# {'CountLine': 1, 'CountPath_Max': 1, 'Del_lines': 1, 'CountPath_Mean': -1, 'Added_lines': 1}
# {'CountLine': 1, 'Del_lines': 1, 'Added_lines': 1, 'CountPath_Max': 1, 'CountPath_Mean': 1}
# {'CountLine': 1, 'CountPath_Max': -1, 'Del_lines': 1, 'Added_lines': 1, 'CountPath_Mean': 1}
# set top_k_rules failed, top_k_rules should be int in range 1 - 15 (both included)
# PyExplainer can not find rules to avoid!
# This could lead to blank explanation UI!
# Please check whether the global model is properly trained with sufficient training data.
# HBox(children=(Label(value='Risk Score: '), FloatProgress(value=0.0, bar_style='info', layout=Layout(width='40…
# Output(layout=Layout(border='3px solid black'))
# FloatSlider(value=1.71, continuous_update=False, description='#1 The value of CountPath_Mean is more than 1.71…
# FloatSlider(value=1.0, continuous_update=False, description='#2 The value of Del_lines is more than 1', layout…
# FloatSlider(value=473.0, continuous_update=False, description='#3 The value of CountLine is less than 473', la…
# set top_k_rules failed, top_k_rules should be int in range 1 - 15 (both included)
# PyExplainer can not find rules to avoid!
# This could lead to blank explanation UI!
# Please check whether the global model is properly trained with sufficient training data.
# set top_k_rules failed, top_k_rules should be int in range 1 - 15 (both included)
# PyExplainer can not find rules to avoid!
# This could lead to blank explanation UI!
# Please check whether the global model is properly trained with sufficient training data.
# {'CountPath_Mean': -1, 'Del_lines': 1, 'CountLine': 1}
# Explaining cli/src/test/org/apache/hadoop/hive/cli/TestOptionsProcessor.java with LIME
# {'Added_lines': 1, 'CountPath_Max': -1, 'CountLine': -1, 'Del_lines': -1, 'CountPath_Mean': 1}
# {'Added_lines': 1, 'CountLine': 1, 'Del_lines': 1, 'CountPath_Mean': 1, 'CountPath_Max': 1}
# {'CountLine': -1, 'Added_lines': 1, 'Del_lines': 1, 'CountPath_Max': 1, 'CountPath_Mean': 1}
# set top_k_rules failed, top_k_rules should be int in range 1 - 15 (both included)
# PyExplainer can not find rules to avoid!
# This could lead to blank explanation UI!
# Please check whether the global model is properly trained with sufficient training data.
# HBox(children=(Label(value='Risk Score: '), FloatProgress(value=0.0, bar_style='info', layout=Layout(width='40…
# Output(layout=Layout(border='3px solid black'))
# FloatSlider(value=84.0, continuous_update=False, description='#1 The value of CountLine is more than 84', layo…
# FloatSlider(value=1.0, continuous_update=False, description='#2 The value of CountPath_Mean is more than 1.0',…
# FloatSlider(value=0.0, continuous_update=False, description='#3 The value of Del_lines is more than 0', layout…
# set top_k_rules failed, top_k_rules should be int in range 1 - 15 (both included)
# PyExplainer can not find rules to avoid!
# This could lead to blank explanation UI!
# Please check whether the global model is properly trained with sufficient training data.
# set top_k_rules failed, top_k_rules should be int in range 1 - 15 (both included)
# PyExplainer can not find rules to avoid!
# This could lead to blank explanation UI!
# Please check whether the global model is properly trained with sufficient training data.
# {'CountLine': -1, 'CountPath_Mean': 1, 'Del_lines': 1}
# Explaining ql/src/java/org/apache/hadoop/hive/ql/plan/PTFDeserializer.java with LIME
# {'Del_lines': 1, 'CountPath_Mean': 1, 'CountLine': 1, 'Added_lines': 1, 'CountPath_Max': 1}
# {'Del_lines': 1, 'CountPath_Max': 1, 'CountLine': 1, 'Added_lines': 1, 'CountPath_Mean': 1}
# {'Added_lines': -1, 'Del_lines': 1, 'CountLine': 1, 'CountPath_Max': 1, 'CountPath_Mean': 1}
# HBox(children=(Label(value='Risk Score: '), FloatProgress(value=0.0, bar_style='info', layout=Layout(width='40…
# Output(layout=Layout(border='3px solid black'))
# FloatSlider(value=334.0, continuous_update=False, description='#1 The value of CountLine is more than 334', la…
# {'CountLine': -1}
# Explaining src/main/java/org/apache/hadoop/hbase/master/HMaster.java with LIME
# {'CountPath_Max': 1, 'Added_lines': 1, 'CountLine': 1, 'Del_lines': 1, 'CountPath_Mean': 1}
# {'Added_lines': 1, 'Del_lines': 1, 'CountPath_Max': 1, 'CountLine': 1, 'CountPath_Mean': 1}
# {'CountPath_Mean': -1, 'CountLine': 1, 'Added_lines': 1, 'CountPath_Max': -1, 'Del_lines': 1}
# PyExplainer can not find rules to follow!
# This could lead to blank explanation UI!
# Please check whether the global model is properly trained with sufficient training data.
# HBox(children=(Label(value='Risk Score: '), FloatProgress(value=0.0, bar_style='info', layout=Layout(width='40…
# Output(layout=Layout(border='3px solid black'))
# PyExplainer can not find rules to follow!
# This could lead to blank explanation UI!
# Please check whether the global model is properly trained with sufficient training data.
# PyExplainer can not find rules to follow!
# This could lead to blank explanation UI!
# Please check whether the global model is properly trained with sufficient training data.
# {}
# Explaining components/camel-spring/src/test/java/org/apache/camel/language/spel/SpelResourceTest.java with LIME
# {'Added_lines': 1, 'CountLine': -1, 'CountPath_Max': -1, 'Del_lines': -1, 'CountPath_Mean': 1}
# {'Added_lines': 1, 'CountLine': 1, 'Del_lines': 1, 'CountPath_Mean': 1, 'CountPath_Max': 1}
# {'CountLine': -1, 'Added_lines': 1, 'Del_lines': 1, 'CountPath_Mean': 1, 'CountPath_Max': 1}
# set top_k_rules failed, top_k_rules should be int in range 1 - 15 (both included)
# PyExplainer can not find rules to avoid!
# This could lead to blank explanation UI!
# Please check whether the global model is properly trained with sufficient training data.
# HBox(children=(Label(value='Risk Score: '), FloatProgress(value=0.0, bar_style='info', layout=Layout(width='40…
# Output(layout=Layout(border='3px solid black'))
# FloatSlider(value=0.0, continuous_update=False, description='#1 The value of Del_lines is less than 0', layout…
# FloatSlider(value=48.0, continuous_update=False, description='#2 The value of Added_lines is more than 48', la…
# FloatSlider(value=1.0, continuous_update=False, description='#3 The value of CountPath_Mean is more than 1.0',…
# set top_k_rules failed, top_k_rules should be int in range 1 - 15 (both included)
# PyExplainer can not find rules to avoid!
# This could lead to blank explanation UI!
# Please check whether the global model is properly trained with sufficient training data.
# set top_k_rules failed, top_k_rules should be int in range 1 - 15 (both included)
# PyExplainer can not find rules to avoid!
# This could lead to blank explanation UI!
# Please check whether the global model is properly trained with sufficient training data.
# {'Del_lines': -1, 'Added_lines': 1, 'CountPath_Mean': 1}
# Explaining service/src/java/org/apache/hive/service/cli/session/HiveSessionImpl.java with LIME
# {'Added_lines': 1, 'CountPath_Max': 1, 'CountLine': 1, 'CountPath_Mean': 1, 'Del_lines': 1}
# {'Del_lines': 1, 'Added_lines': 1, 'CountLine': 1, 'CountPath_Max': 1, 'CountPath_Mean': 1}
# {'CountLine': -1, 'CountPath_Max': 1, 'Added_lines': 1, 'Del_lines': 1, 'CountPath_Mean': 1}
# HBox(children=(Label(value='Risk Score: '), FloatProgress(value=0.0, bar_style='info', layout=Layout(width='40…
# Output(layout=Layout(border='3px solid black'))
# FloatSlider(value=1.79, continuous_update=False, description='#1 The value of CountPath_Mean is less than 1.79…
# {'CountPath_Mean': -1}
# Explaining wicket-core/src/main/java/org/apache/wicket/settings/IResourceSettings.java with LIME
# {'CountLine': 1, 'Del_lines': 1, 'CountPath_Max': -1, 'CountPath_Mean': -1, 'Added_lines': -1}
# {'CountLine': 1, 'Del_lines': 1, 'Added_lines': 1, 'CountPath_Mean': 1, 'CountPath_Max': 1}
# {'CountPath_Mean': -1, 'CountPath_Max': 1, 'CountLine': 1, 'Del_lines': 1, 'Added_lines': 1}
# set top_k_rules failed, top_k_rules should be int in range 1 - 15 (both included)
# PyExplainer can not find rules to avoid!
# This could lead to blank explanation UI!
# Please check whether the global model is properly trained with sufficient training data.
# HBox(children=(Label(value='Risk Score: '), FloatProgress(value=0.0, bar_style='info', layout=Layout(width='40…
# Output(layout=Layout(border='3px solid black'))
# FloatSlider(value=1.0, continuous_update=False, description='#1 The value of CountPath_Mean is less than 1.0',…
# FloatSlider(value=1.0, continuous_update=False, description='#2 The value of CountPath_Max is more than 1', la…
# FloatSlider(value=348.0, continuous_update=False, description='#3 The value of CountLine is more than 348', la…
# set top_k_rules failed, top_k_rules should be int in range 1 - 15 (both included)
# PyExplainer can not find rules to avoid!
# This could lead to blank explanation UI!
# Please check whether the global model is properly trained with sufficient training data.
# set top_k_rules failed, top_k_rules should be int in range 1 - 15 (both included)
# PyExplainer can not find rules to avoid!
# This could lead to blank explanation UI!
# Please check whether the global model is properly trained with sufficient training data.
# {'CountPath_Mean': -1, 'CountPath_Max': 1, 'CountLine': 1}
# Explaining jdk-1.4/wicket/src/main/java/org/apache/wicket/protocol/http/TestFilePageStore.java with LIME
# {'Added_lines': 1, 'CountPath_Mean': 1, 'CountLine': 1, 'Del_lines': 1, 'CountPath_Max': 1}
# {'Del_lines': 1, 'Added_lines': 1, 'CountPath_Mean': 1, 'CountPath_Max': 1, 'CountLine': 1}
# {'CountLine': -1, 'Added_lines': 1, 'CountPath_Max': -1, 'Del_lines': 1, 'CountPath_Mean': 1}
# set top_k_rules failed, top_k_rules should be int in range 1 - 15 (both included)
# PyExplainer can not find rules to avoid!
# This could lead to blank explanation UI!
# Please check whether the global model is properly trained with sufficient training data.
# HBox(children=(Label(value='Risk Score: '), FloatProgress(value=0.0, bar_style='info', layout=Layout(width='40…
# Output(layout=Layout(border='3px solid black'))
# FloatSlider(value=570.0, continuous_update=False, description='#1 The value of Added_lines is more than 570', …
# FloatSlider(value=22.0, continuous_update=False, description='#2 The value of Del_lines is more than 22', layo…
# FloatSlider(value=268.0, continuous_update=False, description='#3 The value of CountLine is less than 268', la…
# set top_k_rules failed, top_k_rules should be int in range 1 - 15 (both included)
# PyExplainer can not find rules to avoid!
# This could lead to blank explanation UI!
# Please check whether the global model is properly trained with sufficient training data.
# set top_k_rules failed, top_k_rules should be int in range 1 - 15 (both included)
# PyExplainer can not find rules to avoid!
# This could lead to blank explanation UI!
# Please check whether the global model is properly trained with sufficient training data.
# {'Added_lines': 1, 'Del_lines': 1, 'CountLine': 1}
# Explaining hcatalog/hcatalog-pig-adapter/src/test/java/org/apache/hcatalog/pig/TestHCatStorer.java with LIME
# {'CountPath_Max': 1, 'CountPath_Mean': 1, 'Del_lines': 1, 'Added_lines': 1, 'CountLine': 1}
# {'Del_lines': 1, 'Added_lines': 1, 'CountPath_Max': 1, 'CountPath_Mean': 1, 'CountLine': -1}
# {'CountLine': -1, 'CountPath_Max': 1, 'CountPath_Mean': 1, 'Added_lines': 1, 'Del_lines': 1}
# set top_k_rules failed, top_k_rules should be int in range 1 - 15 (both included)
# PyExplainer can not find rules to avoid!
# This could lead to blank explanation UI!
# Please check whether the global model is properly trained with sufficient training data.
# HBox(children=(Label(value='Risk Score: '), FloatProgress(value=0.0, bar_style='info', layout=Layout(width='40…
# Output(layout=Layout(border='3px solid black'))
# FloatSlider(value=7.56, continuous_update=False, description='#1 The value of CountPath_Mean is more than 7.56…
# FloatSlider(value=660.0, continuous_update=False, description='#2 The value of CountLine is more than 660', la…
# FloatSlider(value=1285.0, continuous_update=False, description='#3 The value of Del_lines is more than 1285', …
# set top_k_rules failed, top_k_rules should be int in range 1 - 15 (both included)
# PyExplainer can not find rules to avoid!
# This could lead to blank explanation UI!
# Please check whether the global model is properly trained with sufficient training data.
# set top_k_rules failed, top_k_rules should be int in range 1 - 15 (both included)
# PyExplainer can not find rules to avoid!
# This could lead to blank explanation UI!
# Please check whether the global model is properly trained with sufficient training data.
# {'CountPath_Mean': -1, 'CountLine': 1, 'Del_lines': -1}
# Explaining lucene/contrib/instantiated/src/java/org/apache/lucene/store/instantiated/InstantiatedIndex.java with LIME
# {'Del_lines': 1, 'CountPath_Mean': 1, 'Added_lines': 1, 'CountPath_Max': 1, 'CountLine': 1}
# {'Del_lines': 1, 'CountPath_Max': 1, 'Added_lines': 1, 'CountPath_Mean': 1, 'CountLine': 1}
# {'Added_lines': -1, 'Del_lines': 1, 'CountPath_Max': 1, 'CountPath_Mean': 1, 'CountLine': 1}
# set top_k_rules failed, top_k_rules should be int in range 1 - 15 (both included)
# PyExplainer can not find rules to avoid!
# This could lead to blank explanation UI!
# Please check whether the global model is properly trained with sufficient training data.
# HBox(children=(Label(value='Risk Score: '), FloatProgress(value=0.0, bar_style='info', layout=Layout(width='40…
# Output(layout=Layout(border='3px solid black'))
# FloatSlider(value=7.0, continuous_update=False, description='#1 The value of Del_lines is more than 7', layout…
# FloatSlider(value=82722816.0, continuous_update=False, description='#2 The value of CountPath_Max is more than…
# FloatSlider(value=3939182.71, continuous_update=False, description='#3 The value of CountPath_Mean is more tha…
# set top_k_rules failed, top_k_rules should be int in range 1 - 15 (both included)
# PyExplainer can not find rules to avoid!
# This could lead to blank explanation UI!
# Please check whether the global model is properly trained with sufficient training data.
# set top_k_rules failed, top_k_rules should be int in range 1 - 15 (both included)
# PyExplainer can not find rules to avoid!
# This could lead to blank explanation UI!
# Please check whether the global model is properly trained with sufficient training data.
# {'Del_lines': -1, 'CountPath_Max': -1, 'CountPath_Mean': -1}
# Explaining jdk-1.4/wicket-extensions/src/main/java/org/apache/wicket/extensions/markup/html/tree/table/PropertyRenderableColumn.java with LIME
# {'Added_lines': 1, 'Del_lines': 1, 'CountLine': -1, 'CountPath_Max': -1, 'CountPath_Mean': 1}
# {'Added_lines': 1, 'Del_lines': 1, 'CountLine': -1, 'CountPath_Mean': 1, 'CountPath_Max': 1}
# {'CountLine': -1, 'Del_lines': -1, 'CountPath_Max': 1, 'Added_lines': 1, 'CountPath_Mean': 1}
# set top_k_rules failed, top_k_rules should be int in range 1 - 15 (both included)
# PyExplainer can not find rules to avoid!
# This could lead to blank explanation UI!
# Please check whether the global model is properly trained with sufficient training data.
# HBox(children=(Label(value='Risk Score: '), FloatProgress(value=0.0, bar_style='info', layout=Layout(width='40…
# Output(layout=Layout(border='3px solid black'))
# FloatSlider(value=139.0, continuous_update=False, description='#1 The value of CountLine is more than 139', la…
# FloatSlider(value=279.0, continuous_update=False, description='#2 The value of Added_lines is less than 279', …
# FloatSlider(value=1.29, continuous_update=False, description='#3 The value of CountPath_Mean is less than 1.29…
# set top_k_rules failed, top_k_rules should be int in range 1 - 15 (both included)
# PyExplainer can not find rules to avoid!
# This could lead to blank explanation UI!
# Please check whether the global model is properly trained with sufficient training data.
# set top_k_rules failed, top_k_rules should be int in range 1 - 15 (both included)
# PyExplainer can not find rules to avoid!
# This could lead to blank explanation UI!
# Please check whether the global model is properly trained with sufficient training data.
# {'CountLine': 1, 'Added_lines': -1, 'CountPath_Mean': -1}
# Explaining hcatalog/webhcat/java-client/src/test/java/org/apache/hcatalog/api/TestHCatClient.java with LIME
# {'Del_lines': 1, 'Added_lines': 1, 'CountPath_Max': 1, 'CountPath_Mean': 1, 'CountLine': -1}
# {'Del_lines': 1, 'Added_lines': 1, 'CountPath_Max': 1, 'CountPath_Mean': 1, 'CountLine': 1}
# {'Del_lines': 1, 'Added_lines': 1, 'CountPath_Max': 1, 'CountPath_Mean': 1, 'CountLine': 1}
# HBox(children=(Label(value='Risk Score: '), FloatProgress(value=0.0, bar_style='info', layout=Layout(width='40…
# Output(layout=Layout(border='3px solid black'))
# FloatSlider(value=1192.0, continuous_update=False, description='#1 The value of Del_lines is more than 1192', …
# FloatSlider(value=1195.0, continuous_update=False, description='#2 The value of Added_lines is more than 1195'…
# {'Del_lines': -1, 'Added_lines': -1}
# Explaining components/camel-jetty/src/test/java/org/apache/camel/component/jetty/JettyHttpBridgeEncodedPathTest.java with LIME
# {'Added_lines': 1, 'Del_lines': 1, 'CountLine': -1, 'CountPath_Mean': -1, 'CountPath_Max': -1}
# {'Del_lines': 1, 'Added_lines': 1, 'CountLine': 1, 'CountPath_Max': 1, 'CountPath_Mean': -1}
# {'CountPath_Mean': -1, 'Added_lines': 1, 'Del_lines': 1, 'CountLine': 1, 'CountPath_Max': 1}
# set top_k_rules failed, top_k_rules should be int in range 1 - 15 (both included)
# PyExplainer can not find rules to avoid!
# This could lead to blank explanation UI!
# Please check whether the global model is properly trained with sufficient training data.
# HBox(children=(Label(value='Risk Score: '), FloatProgress(value=0.0, bar_style='info', layout=Layout(width='40…
# Output(layout=Layout(border='3px solid black'))
# FloatSlider(value=66.0, continuous_update=False, description='#1 The value of CountLine is more than 66', layo…
# set top_k_rules failed, top_k_rules should be int in range 1 - 15 (both included)
# PyExplainer can not find rules to avoid!
# This could lead to blank explanation UI!
# Please check whether the global model is properly trained with sufficient training data.
# set top_k_rules failed, top_k_rules should be int in range 1 - 15 (both included)
# PyExplainer can not find rules to avoid!
# This could lead to blank explanation UI!
# Please check whether the global model is properly trained with sufficient training data.
# {'CountLine': 1}
# Explaining jdk-1.4/wicket/src/main/java/org/apache/wicket/util/tester/BaseWicketTester.java with LIME
# {'CountPath_Max': 1, 'Added_lines': 1, 'CountPath_Mean': 1, 'Del_lines': 1, 'CountLine': 1}
# {'Del_lines': 1, 'Added_lines': 1, 'CountLine': 1, 'CountPath_Max': 1, 'CountPath_Mean': 1}
# {'CountLine': -1, 'CountPath_Mean': -1, 'CountPath_Max': 1, 'Del_lines': 1, 'Added_lines': 1}
# set top_k_rules failed, top_k_rules should be int in range 1 - 15 (both included)
# PyExplainer can not find rules to avoid!
# This could lead to blank explanation UI!
# Please check whether the global model is properly trained with sufficient training data.
# HBox(children=(Label(value='Risk Score: '), FloatProgress(value=0.0, bar_style='info', layout=Layout(width='40…
# Output(layout=Layout(border='3px solid black'))
# FloatSlider(value=202.0, continuous_update=False, description='#1 The value of Del_lines is more than 202', la…
# FloatSlider(value=13.0, continuous_update=False, description='#2 The value of CountPath_Max is more than 13', …
# FloatSlider(value=2631.0, continuous_update=False, description='#3 The value of Added_lines is less than 2631'…
# set top_k_rules failed, top_k_rules should be int in range 1 - 15 (both included)
# PyExplainer can not find rules to avoid!
# This could lead to blank explanation UI!
# Please check whether the global model is properly trained with sufficient training data.
# set top_k_rules failed, top_k_rules should be int in range 1 - 15 (both included)
# PyExplainer can not find rules to avoid!
# This could lead to blank explanation UI!
# Please check whether the global model is properly trained with sufficient training data.
# {'Del_lines': 1, 'CountPath_Max': -1, 'Added_lines': 1}
# Explaining testutils/ptest2/src/main/java/org/apache/hive/ptest/execution/PTest.java with LIME
# {'Added_lines': 1, 'Del_lines': 1, 'CountLine': 1, 'CountPath_Mean': 1, 'CountPath_Max': 1}
# {'Added_lines': 1, 'Del_lines': 1, 'CountLine': 1, 'CountPath_Mean': 1, 'CountPath_Max': 1}
# {'Del_lines': -1, 'CountPath_Max': 1, 'CountPath_Mean': 1, 'CountLine': 1, 'Added_lines': 1}
# set top_k_rules failed, top_k_rules should be int in range 1 - 15 (both included)
# PyExplainer can not find rules to avoid!
# This could lead to blank explanation UI!
# Please check whether the global model is properly trained with sufficient training data.
# HBox(children=(Label(value='Risk Score: '), FloatProgress(value=0.0, bar_style='info', layout=Layout(width='40…
# Output(layout=Layout(border='3px solid black'))
# FloatSlider(value=450.0, continuous_update=False, description='#1 The value of Added_lines is more than 450', …
# FloatSlider(value=111.0, continuous_update=False, description='#2 The value of Del_lines is more than 111', la…
# FloatSlider(value=319.0, continuous_update=False, description='#3 The value of CountLine is more than 319', la…
# set top_k_rules failed, top_k_rules should be int in range 1 - 15 (both included)
# PyExplainer can not find rules to avoid!
# This could lead to blank explanation UI!
# Please check whether the global model is properly trained with sufficient training data.
# set top_k_rules failed, top_k_rules should be int in range 1 - 15 (both included)
# PyExplainer can not find rules to avoid!
# This could lead to blank explanation UI!
# Please check whether the global model is properly trained with sufficient training data.
# {'Added_lines': -1, 'Del_lines': -1, 'CountLine': -1}
# Explaining wicket-core/src/test/java/org/apache/wicket/markup/html/form/RadioGroupTest.java with LIME
# {'Added_lines': 1, 'Del_lines': 1, 'CountPath_Max': -1, 'CountLine': 1, 'CountPath_Mean': 1}
# {'Del_lines': 1, 'Added_lines': 1, 'CountPath_Max': -1, 'CountLine': -1, 'CountPath_Mean': 1}
# {'Added_lines': 1, 'Del_lines': 1, 'CountLine': 1, 'CountPath_Max': 1, 'CountPath_Mean': 1}
# set top_k_rules failed, top_k_rules should be int in range 1 - 15 (both included)
# PyExplainer can not find rules to avoid!
# This could lead to blank explanation UI!
# Please check whether the global model is properly trained with sufficient training data.
# HBox(children=(Label(value='Risk Score: '), FloatProgress(value=0.0, bar_style='info', layout=Layout(width='40…
# Output(layout=Layout(border='3px solid black'))
# FloatSlider(value=24.0, continuous_update=False, description='#1 The value of Added_lines is more than 24', la…
# FloatSlider(value=238.0, continuous_update=False, description='#2 The value of CountLine is less than 238', la…
# FloatSlider(value=1.33, continuous_update=False, description='#3 The value of CountPath_Mean is more than 1.33…
# set top_k_rules failed, top_k_rules should be int in range 1 - 15 (both included)
# PyExplainer can not find rules to avoid!
# This could lead to blank explanation UI!
# Please check whether the global model is properly trained with sufficient training data.
# set top_k_rules failed, top_k_rules should be int in range 1 - 15 (both included)
# PyExplainer can not find rules to avoid!
# This could lead to blank explanation UI!
# Please check whether the global model is properly trained with sufficient training data.
# {'Added_lines': -1, 'CountLine': 1, 'CountPath_Mean': 1}
# Explaining lucene/contrib/highlighter/src/java/org/apache/lucene/search/highlight/WeightedSpanTermExtractor.java with LIME
# {'CountPath_Max': 1, 'CountLine': 1, 'Del_lines': 1, 'Added_lines': 1, 'CountPath_Mean': -1}
# {'CountPath_Max': 1, 'CountPath_Mean': 1, 'CountLine': 1, 'Del_lines': 1, 'Added_lines': -1}
# {'CountPath_Mean': -1, 'CountPath_Max': 1, 'CountLine': 1, 'Del_lines': 1, 'Added_lines': 1}
# set top_k_rules failed, top_k_rules should be int in range 1 - 15 (both included)
# PyExplainer can not find rules to avoid!
# This could lead to blank explanation UI!
# Please check whether the global model is properly trained with sufficient training data.
# HBox(children=(Label(value='Risk Score: '), FloatProgress(value=0.0, bar_style='info', layout=Layout(width='40…
# Output(layout=Layout(border='3px solid black'))
# FloatSlider(value=20.0, continuous_update=False, description='#1 The value of Added_lines is more than 20', la…
# FloatSlider(value=22.86, continuous_update=False, description='#2 The value of CountPath_Mean is less than 22.…
# FloatSlider(value=360.0, continuous_update=False, description='#3 The value of CountPath_Max is more than 360.…
# set top_k_rules failed, top_k_rules should be int in range 1 - 15 (both included)
# PyExplainer can not find rules to avoid!
# This could lead to blank explanation UI!
# Please check whether the global model is properly trained with sufficient training data.
# set top_k_rules failed, top_k_rules should be int in range 1 - 15 (both included)
# PyExplainer can not find rules to avoid!
# This could lead to blank explanation UI!
# Please check whether the global model is properly trained with sufficient training data.
# {'Added_lines': 1, 'CountPath_Mean': 1, 'CountPath_Max': -1}
# Explaining src/main/java/org/apache/hadoop/hbase/client/HConnectionManager.java with LIME
# {'Added_lines': 1, 'CountLine': 1, 'Del_lines': 1, 'CountPath_Mean': -1, 'CountPath_Max': 1}
# {'Added_lines': 1, 'CountLine': 1, 'Del_lines': 1, 'CountPath_Max': 1, 'CountPath_Mean': 1}
# {'Added_lines': 1, 'Del_lines': 1, 'CountPath_Max': 1, 'CountLine': 1, 'CountPath_Mean': 1}
# HBox(children=(Label(value='Risk Score: '), FloatProgress(value=0.0, bar_style='info', layout=Layout(width='40…
# Output(layout=Layout(border='3px solid black'))
# FloatSlider(value=1840.0, continuous_update=False, description='#1 The value of CountLine is more than 1840', …
# {'CountLine': -1}
# Explaining contrib/snowball/src/java/net/sf/snowball/ext/DutchStemmer.java with LIME
# {'CountLine': 1, 'CountPath_Max': 1, 'Del_lines': -1, 'CountPath_Mean': 1, 'Added_lines': -1}
# {'CountLine': 1, 'CountPath_Max': 1, 'CountPath_Mean': 1, 'Del_lines': -1, 'Added_lines': -1}
# {'Added_lines': -1, 'Del_lines': -1, 'CountPath_Max': -1, 'CountLine': 1, 'CountPath_Mean': 1}
# set top_k_rules failed, top_k_rules should be int in range 1 - 15 (both included)
# PyExplainer can not find rules to avoid!
# This could lead to blank explanation UI!
# Please check whether the global model is properly trained with sufficient training data.
# HBox(children=(Label(value='Risk Score: '), FloatProgress(value=0.0, bar_style='info', layout=Layout(width='40…
# Output(layout=Layout(border='3px solid black'))
# FloatSlider(value=0.0, continuous_update=False, description='#1 The value of Del_lines is more than 0', layout…
# FloatSlider(value=1966080.0, continuous_update=False, description='#2 The value of CountPath_Max is more than …
# FloatSlider(value=0.0, continuous_update=False, description='#3 The value of Added_lines is more than 0', layo…
# set top_k_rules failed, top_k_rules should be int in range 1 - 15 (both included)
# PyExplainer can not find rules to avoid!
# This could lead to blank explanation UI!
# Please check whether the global model is properly trained with sufficient training data.
# set top_k_rules failed, top_k_rules should be int in range 1 - 15 (both included)
# PyExplainer can not find rules to avoid!
# This could lead to blank explanation UI!
# Please check whether the global model is properly trained with sufficient training data.
# {'Del_lines': 1, 'CountPath_Max': -1, 'Added_lines': 1}
# Explaining src/org/jruby/ir/operands/BacktickString.java with LIME
# {'Added_lines': 1, 'Del_lines': 1, 'CountLine': -1, 'CountPath_Max': -1, 'CountPath_Mean': -1}
# {'Added_lines': 1, 'Del_lines': 1, 'CountLine': 1, 'CountPath_Mean': 1, 'CountPath_Max': 1}
# {'CountPath_Max': -1, 'CountPath_Mean': -1, 'Del_lines': 1, 'Added_lines': 1, 'CountLine': 1}
# set top_k_rules failed, top_k_rules should be int in range 1 - 15 (both included)
# PyExplainer can not find rules to avoid!
# This could lead to blank explanation UI!
# Please check whether the global model is properly trained with sufficient training data.
# HBox(children=(Label(value='Risk Score: '), FloatProgress(value=0.0, bar_style='info', layout=Layout(width='40…
# Output(layout=Layout(border='3px solid black'))
# FloatSlider(value=87.0, continuous_update=False, description='#1 The value of CountLine is less than 87', layo…
# FloatSlider(value=392.0, continuous_update=False, description='#2 The value of Del_lines is more than 392', la…
# FloatSlider(value=5264.0, continuous_update=False, description='#3 The value of Added_lines is more than 5264'…
# set top_k_rules failed, top_k_rules should be int in range 1 - 15 (both included)
# PyExplainer can not find rules to avoid!
# This could lead to blank explanation UI!
# Please check whether the global model is properly trained with sufficient training data.
# set top_k_rules failed, top_k_rules should be int in range 1 - 15 (both included)
# PyExplainer can not find rules to avoid!
# This could lead to blank explanation UI!
# Please check whether the global model is properly trained with sufficient training data.
# {'CountLine': -1, 'Del_lines': -1, 'Added_lines': -1}
# Explaining lucene/src/java/org/apache/lucene/index/IndexReader.java with LIME
# {'Added_lines': 1, 'CountLine': 1, 'Del_lines': 1, 'CountPath_Mean': 1, 'CountPath_Max': 1}
# {'Added_lines': 1, 'Del_lines': 1, 'CountLine': 1, 'CountPath_Mean': 1, 'CountPath_Max': 1}
# {'Del_lines': -1, 'Added_lines': 1, 'CountPath_Mean': 1, 'CountLine': 1, 'CountPath_Max': 1}
# set top_k_rules failed, top_k_rules should be int in range 1 - 15 (both included)
# PyExplainer can not find rules to avoid!
# This could lead to blank explanation UI!
# Please check whether the global model is properly trained with sufficient training data.
# HBox(children=(Label(value='Risk Score: '), FloatProgress(value=0.0, bar_style='info', layout=Layout(width='40…
# Output(layout=Layout(border='3px solid black'))
# FloatSlider(value=105.0, continuous_update=False, description='#1 The value of Del_lines is less than 105', la…
# set top_k_rules failed, top_k_rules should be int in range 1 - 15 (both included)
# PyExplainer can not find rules to avoid!
# This could lead to blank explanation UI!
# Please check whether the global model is properly trained with sufficient training data.
# set top_k_rules failed, top_k_rules should be int in range 1 - 15 (both included)
# PyExplainer can not find rules to avoid!
# This could lead to blank explanation UI!
# Please check whether the global model is properly trained with sufficient training data.
# {'Del_lines': -1}
