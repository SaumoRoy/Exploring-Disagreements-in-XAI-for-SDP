# %%
import pandas as pd
import numpy as np
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2
data = pd.read_csv('/Users/saumenduroy/Documents/PhD Life/Explainability + SOAR/Explainers code/Best datset_model perspective_AUC/Data/lucene-3.1.csv')
data = data.drop('File', axis=1)
X = data.iloc[:,0:]  #independent columns
y = data.iloc[:,-1]    #target column i.e Realbug
#apply SelectKBest class to extract top 10 best features
bestfeatures = SelectKBest(score_func=chi2, k=10)
fit = bestfeatures.fit(X,y)
dfscores = pd.DataFrame(fit.scores_)
dfcolumns = pd.DataFrame(X.columns)
#concat two dataframes for better visualization 
featureScores = pd.concat([dfcolumns,dfscores],axis=1)
featureScores.columns = ['Specs','Score']  #naming the dataframe columns
print(featureScores.nlargest(10,'Score'))  #print 10 best features
# Out:
#                Specs         Score
# 48     CountPath_Max  6.814585e+10
# 49    CountPath_Mean  7.317042e+09
# 58         Del_lines  5.616917e+05
# 57       Added_lines  2.064953e+05
# 2          CountLine  1.895193e+05
# 31         CountStmt  1.124913e+05
# 27     CountLineCode  1.118585e+05
# 23  CountLineCodeExe  9.716616e+04
# 33    CountSemicolon  9.117785e+04
# 28      CountStmtExe  9.090058e+04

# %%
## Load Data and preparing datasets

# Import for Load Data
from os import listdir
from os.path import isfile, join
import pandas as pd

# Import for Split Data into Training and Testing Samples
from sklearn.model_selection import train_test_split

train_dataset = pd.read_csv(('/Users/saumenduroy/Documents/PhD Life/Explainability + SOAR/Explainers code/Best datset_model perspective_AUC/Data/lucene-2.9.0.csv'), index_col = 'File')
test_dataset = pd.read_csv(('/Users/saumenduroy/Documents/PhD Life/Explainability + SOAR/Explainers code/Best datset_model perspective_AUC/Data/lucene-3.1.csv'), index_col = 'File')

outcome = 'RealBug'
features = ['CountPath_Max', 'CountPath_Mean', 'Del_lines', 'Added_lines', 'CountLine', 'CountStmt', 'CountLineCode', 'CountLineCodeExe', 'CountSemicolon', 'CountStmtExe']
# commits - # of commits that modify the file of interest
# Added lines - # of added lines of code
# Count class coupled - # of classes that interact or couple with the class of interest
# LOC - # of lines of code
# RatioCommentToCode - The ratio of lines of comments to lines of code

# process outcome to 0 and 1
train_dataset[outcome] = pd.Categorical(train_dataset[outcome])
train_dataset[outcome] = train_dataset[outcome].cat.codes

test_dataset[outcome] = pd.Categorical(test_dataset[outcome])
test_dataset[outcome] = test_dataset[outcome].cat.codes

X_train = train_dataset.loc[:, features]
X_test = test_dataset.loc[:, features]

y_train = train_dataset.loc[:, outcome]
y_test = test_dataset.loc[:, outcome]

class_labels = ['Clean', 'Defective']

X_train.columns = features
X_test.columns = features
training_data = pd.concat([X_train, y_train], axis=1)
testing_data = pd.concat([X_test, y_test], axis=1)

# %%
test_dataset
# Out:
#                                                     CountDeclMethodPrivate  \
# File
# lucene/backwards/src/test/org/apache/lucene/ana...                       0
# lucene/backwards/src/test/org/apache/lucene/ana...                       0
# lucene/backwards/src/test/org/apache/lucene/ana...                       0
# lucene/backwards/src/test/org/apache/lucene/ana...                       1
# lucene/backwards/src/test/org/apache/lucene/ana...                       0
# ...                                                                    ...
# solr/src/webapp/src/org/apache/solr/servlet/Sol...                       2
# solr/src/webapp/src/org/apache/solr/servlet/Sol...                       0
# solr/src/webapp/src/org/apache/solr/servlet/Sol...                       0
# solr/src/webapp/src/org/apache/solr/servlet/Sol...                       0
# solr/src/webapp/src/org/apache/solr/servlet/Sol...                       0
#
#                                                     AvgLineCode  CountLine  \
# File
# lucene/backwards/src/test/org/apache/lucene/ana...            4        170
# lucene/backwards/src/test/org/apache/lucene/ana...            9        163
# lucene/backwards/src/test/org/apache/lucene/ana...          528       1906
# lucene/backwards/src/test/org/apache/lucene/ana...           21        110
# lucene/backwards/src/test/org/apache/lucene/ana...           21        180
# ...                                                         ...        ...
# solr/src/webapp/src/org/apache/solr/servlet/Sol...           21        414
# solr/src/webapp/src/org/apache/solr/servlet/Sol...           11        413
# solr/src/webapp/src/org/apache/solr/servlet/Sol...           17        150
# solr/src/webapp/src/org/apache/solr/servlet/Sol...            3         33
# solr/src/webapp/src/org/apache/solr/servlet/Sol...           13         90
#
#                                                     MaxCyclomatic  \
# File
# lucene/backwards/src/test/org/apache/lucene/ana...             12
# lucene/backwards/src/test/org/apache/lucene/ana...              3
# lucene/backwards/src/test/org/apache/lucene/ana...              5
# lucene/backwards/src/test/org/apache/lucene/ana...              2
# lucene/backwards/src/test/org/apache/lucene/ana...             10
# ...                                                           ...
# solr/src/webapp/src/org/apache/solr/servlet/Sol...             25
# solr/src/webapp/src/org/apache/solr/servlet/Sol...             13
# solr/src/webapp/src/org/apache/solr/servlet/Sol...             11
# solr/src/webapp/src/org/apache/solr/servlet/Sol...              1
# solr/src/webapp/src/org/apache/solr/servlet/Sol...              3
#
#                                                     CountDeclMethodDefault  \
# File
# lucene/backwards/src/test/org/apache/lucene/ana...                       0
# lucene/backwards/src/test/org/apache/lucene/ana...                       1
# lucene/backwards/src/test/org/apache/lucene/ana...                       1
# lucene/backwards/src/test/org/apache/lucene/ana...                       0
# lucene/backwards/src/test/org/apache/lucene/ana...                       0
# ...                                                                    ...
# solr/src/webapp/src/org/apache/solr/servlet/Sol...                       0
# solr/src/webapp/src/org/apache/solr/servlet/Sol...                       1
# solr/src/webapp/src/org/apache/solr/servlet/Sol...                       1
# solr/src/webapp/src/org/apache/solr/servlet/Sol...                       0
# solr/src/webapp/src/org/apache/solr/servlet/Sol...                       0
#
#                                                     AvgEssential  \
# File
# lucene/backwards/src/test/org/apache/lucene/ana...             1
# lucene/backwards/src/test/org/apache/lucene/ana...             1
# lucene/backwards/src/test/org/apache/lucene/ana...             1
# lucene/backwards/src/test/org/apache/lucene/ana...             1
# lucene/backwards/src/test/org/apache/lucene/ana...             1
# ...                                                          ...
# solr/src/webapp/src/org/apache/solr/servlet/Sol...             2
# solr/src/webapp/src/org/apache/solr/servlet/Sol...             1
# solr/src/webapp/src/org/apache/solr/servlet/Sol...             1
# solr/src/webapp/src/org/apache/solr/servlet/Sol...             1
# solr/src/webapp/src/org/apache/solr/servlet/Sol...             1
#
#                                                     CountDeclClassVariable  \
# File
# lucene/backwards/src/test/org/apache/lucene/ana...                       0
# lucene/backwards/src/test/org/apache/lucene/ana...                       0
# lucene/backwards/src/test/org/apache/lucene/ana...                       0
# lucene/backwards/src/test/org/apache/lucene/ana...                       0
# lucene/backwards/src/test/org/apache/lucene/ana...                       1
# ...                                                                    ...
# solr/src/webapp/src/org/apache/solr/servlet/Sol...                       1
# solr/src/webapp/src/org/apache/solr/servlet/Sol...                       4
# solr/src/webapp/src/org/apache/solr/servlet/Sol...                       1
# solr/src/webapp/src/org/apache/solr/servlet/Sol...                       0
# solr/src/webapp/src/org/apache/solr/servlet/Sol...                       1
#
#                                                     SumCyclomaticStrict  \
# File
# lucene/backwards/src/test/org/apache/lucene/ana...                   34
# lucene/backwards/src/test/org/apache/lucene/ana...                   12
# lucene/backwards/src/test/org/apache/lucene/ana...                    7
# lucene/backwards/src/test/org/apache/lucene/ana...                    5
# lucene/backwards/src/test/org/apache/lucene/ana...                   17
# ...                                                                 ...
# solr/src/webapp/src/org/apache/solr/servlet/Sol...                   59
# solr/src/webapp/src/org/apache/solr/servlet/Sol...                   48
# solr/src/webapp/src/org/apache/solr/servlet/Sol...                   18
# solr/src/webapp/src/org/apache/solr/servlet/Sol...                    1
# solr/src/webapp/src/org/apache/solr/servlet/Sol...                    4
#
#                                                     AvgCyclomatic  AvgLine  \
# File
# lucene/backwards/src/test/org/apache/lucene/ana...              2        5
# lucene/backwards/src/test/org/apache/lucene/ana...              1       10
# lucene/backwards/src/test/org/apache/lucene/ana...              2      608
# lucene/backwards/src/test/org/apache/lucene/ana...              2       26
# lucene/backwards/src/test/org/apache/lucene/ana...              3       25
# ...                                                           ...      ...
# solr/src/webapp/src/org/apache/solr/servlet/Sol...              5       29
# solr/src/webapp/src/org/apache/solr/servlet/Sol...              3       15
# solr/src/webapp/src/org/apache/solr/servlet/Sol...              4       21
# solr/src/webapp/src/org/apache/solr/servlet/Sol...              1        3
# solr/src/webapp/src/org/apache/solr/servlet/Sol...              2       17
#
#                                                     ...  OWN_LINE  OWN_COMMIT  \
# File                                                ...
# lucene/backwards/src/test/org/apache/lucene/ana...  ...  1.000000    0.000000
# lucene/backwards/src/test/org/apache/lucene/ana...  ...  0.987805    0.000000
# lucene/backwards/src/test/org/apache/lucene/ana...  ...  1.000000    0.000000
# lucene/backwards/src/test/org/apache/lucene/ana...  ...  1.000000    0.000000
# lucene/backwards/src/test/org/apache/lucene/ana...  ...  1.000000    0.000000
# ...                                                 ...       ...         ...
# solr/src/webapp/src/org/apache/solr/servlet/Sol...  ...  0.355072    0.428571
# solr/src/webapp/src/org/apache/solr/servlet/Sol...  ...  0.590799    0.000000
# solr/src/webapp/src/org/apache/solr/servlet/Sol...  ...  0.489933    0.750000
# solr/src/webapp/src/org/apache/solr/servlet/Sol...  ...  1.000000    1.000000
# solr/src/webapp/src/org/apache/solr/servlet/Sol...  ...  0.422222    0.500000
#
#                                                     MINOR_COMMIT  MINOR_LINE  \
# File
# lucene/backwards/src/test/org/apache/lucene/ana...             0           1
# lucene/backwards/src/test/org/apache/lucene/ana...             0           1
# lucene/backwards/src/test/org/apache/lucene/ana...             0           1
# lucene/backwards/src/test/org/apache/lucene/ana...             0           1
# lucene/backwards/src/test/org/apache/lucene/ana...             0           1
# ...                                                          ...         ...
# solr/src/webapp/src/org/apache/solr/servlet/Sol...             0           5
# solr/src/webapp/src/org/apache/solr/servlet/Sol...             0           3
# solr/src/webapp/src/org/apache/solr/servlet/Sol...             0           4
# solr/src/webapp/src/org/apache/solr/servlet/Sol...             0           1
# solr/src/webapp/src/org/apache/solr/servlet/Sol...             0           4
#
#                                                     MAJOR_COMMIT  MAJOR_LINE  \
# File
# lucene/backwards/src/test/org/apache/lucene/ana...             0           0
# lucene/backwards/src/test/org/apache/lucene/ana...             0           1
# lucene/backwards/src/test/org/apache/lucene/ana...             0           0
# lucene/backwards/src/test/org/apache/lucene/ana...             0           0
# lucene/backwards/src/test/org/apache/lucene/ana...             0           0
# ...                                                          ...         ...
# solr/src/webapp/src/org/apache/solr/servlet/Sol...             4           4
# solr/src/webapp/src/org/apache/solr/servlet/Sol...             0           2
# solr/src/webapp/src/org/apache/solr/servlet/Sol...             2           3
# solr/src/webapp/src/org/apache/solr/servlet/Sol...             1           0
# solr/src/webapp/src/org/apache/solr/servlet/Sol...             2           0
#
#                                                     HeuBug  HeuBugCount  \
# File
# lucene/backwards/src/test/org/apache/lucene/ana...   False            0
# lucene/backwards/src/test/org/apache/lucene/ana...   False            0
# lucene/backwards/src/test/org/apache/lucene/ana...   False            0
# lucene/backwards/src/test/org/apache/lucene/ana...   False            0
# lucene/backwards/src/test/org/apache/lucene/ana...   False            0
# ...                                                    ...          ...
# solr/src/webapp/src/org/apache/solr/servlet/Sol...   False            0
# solr/src/webapp/src/org/apache/solr/servlet/Sol...   False            0
# solr/src/webapp/src/org/apache/solr/servlet/Sol...   False            0
# solr/src/webapp/src/org/apache/solr/servlet/Sol...   False            0
# solr/src/webapp/src/org/apache/solr/servlet/Sol...   False            0
#
#                                                     RealBug  RealBugCount
# File
# lucene/backwards/src/test/org/apache/lucene/ana...        0             0
# lucene/backwards/src/test/org/apache/lucene/ana...        0             0
# lucene/backwards/src/test/org/apache/lucene/ana...        0             0
# lucene/backwards/src/test/org/apache/lucene/ana...        0             0
# lucene/backwards/src/test/org/apache/lucene/ana...        0             0
# ...                                                     ...           ...
# solr/src/webapp/src/org/apache/solr/servlet/Sol...        0             0
# solr/src/webapp/src/org/apache/solr/servlet/Sol...        0             0
# solr/src/webapp/src/org/apache/solr/servlet/Sol...        0             0
# solr/src/webapp/src/org/apache/solr/servlet/Sol...        0             0
# solr/src/webapp/src/org/apache/solr/servlet/Sol...        0             0
#
# [2806 rows x 69 columns]

# %%
from sklearn.ensemble import RandomForestClassifier
our_rf_model = RandomForestClassifier(random_state=0)
our_rf_model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=0)

# %%
y_test.value_counts()
# Out:
# 0    2699
# 1     107
# Name: RealBug, dtype: int64

# %%
from sklearn import metrics
from matplotlib import pyplot as plt
y_pred_proba = our_rf_model.predict_proba(X_test)[::,1]
fpr, tpr, _ = metrics.roc_curve(y_test,  y_pred_proba)
auc = metrics.roc_auc_score(y_test, y_pred_proba)

#create ROC curve
plt.plot(fpr,tpr,label="AUC="+str(auc))
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.legend(loc=4)
plt.show()

# %% [markdown]
# ## LIME

# %%
# Import for LIME
import lime
import lime.lime_tabular

file_to_be_explained = 'lucene/contrib/queryparser/src/java/org/apache/lucene/queryParser/standard/parser/StandardSyntaxParser.java'

print(f'Explaining {file_to_be_explained} with LIME')
# Out:
# Explaining lucene/contrib/queryparser/src/java/org/apache/lucene/queryParser/standard/parser/StandardSyntaxParser.java with LIME

# %%
# LIME Step 1 - Construct an explainer
our_lime_explainer = lime.lime_tabular.LimeTabularExplainer(
                            training_data = X_train.values,  
                            mode = 'classification',
                            training_labels = y_train,
                            feature_names = features,
                            class_names = class_labels,
                            discretize_continuous = True)
                            
# LIME Step 2 - Use the constructed explainer with the predict function 
# of your predictive model to explain any instance
lime_local_explanation_of_an_instance = our_lime_explainer.explain_instance(
                           # X_test[0],
                          # data_row = X_test.loc['FileName.py', : ], 
                            data_row = X_test.loc[file_to_be_explained, : ],
                            predict_fn = our_rf_model.predict_proba, 
                            num_features = 10,
                            top_labels = 1)

#explainer = lime_tabular.LimeTabularExplainer(X_train, mode = "regression", feature_names = boston_housing.feature_names)
#explanation = explainer.explain_instance(X_test[0], model.predict, num_features = len(boston_housing.feature_names))
                            
# Please use the code below to visualise the generated LIME explanation.
lime_local_explanation_of_an_instance.show_in_notebook()
# Out:
# /Users/saumenduroy/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py:409: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# <html>
#         <meta http-equiv="content-type" content="text/html; charset=UTF8">
#         <head><script>var lime =
# /******/ (function(modules) { // webpackBootstrap
# /******/ 	// The module cache
# /******/ 	var installedModules = {};
# /******/
# /******/ 	// The require function
# /******/ 	function __webpack_require__(moduleId) {
# /******/
# /******/ 		// Check if module is in cache
# /******/ 		if(installedModules[moduleId])
# /******/ 			return installedModules[moduleId].exports;
# /******/
# /******/ 		// Create a new module (and put it into the cache)
# /******/ 		var module = installedModules[moduleId] = {
# /******/ 			exports: {},
# /******/ 			id: moduleId,
# /******/ 			loaded: false
# /******/ 		};
# /******/
# /******/ 		// Execute the module function
# /******/ 		modules[moduleId].call(module.exports, module, module.exports, __webpack_require__);
# /******/
# /******/ 		// Flag the module as loaded
# /******/ 		module.loaded = true;
# /******/
# /******/ 		// Return the exports of the module
# /******/ 		return module.exports;
# /******/ 	}
# /******/
# /******/
# /******/ 	// expose the modules object (__webpack_modules__)
# /******/ 	__webpack_require__.m = modules;
# /******/
# /******/ 	// expose the module cache
# /******/ 	__webpack_require__.c = installedModules;
# /******/
# /******/ 	// __webpack_public_path__
# /******/ 	__webpack_require__.p = "";
# /******/
# /******/ 	// Load entry module and return exports
# /******/ 	return __webpack_require__(0);
# /******/ })
# /************************************************************************/
# /******/ ([
# /* 0 */
# /***/ (function(module, exports, __webpack_require__) {
#
# 	/* WEBPACK VAR INJECTION */(function(global) {'use strict';
#
# 	Object.defineProperty(exports, "__esModule", {
# 	  value: true
# 	});
# 	exports.PredictedValue = exports.PredictProba = exports.Barchart = exports.Explanation = undefined;
#
# 	var _explanation = __webpack_require__(1);
#
# 	var _explanation2 = _interopRequireDefault(_explanation);
#
# 	var _bar_chart = __webpack_require__(3);
#
# 	var _bar_chart2 = _interopRequireDefault(_bar_chart);
#
# 	var _predict_proba = __webpack_require__(6);
#
# 	var _predict_proba2 = _interopRequireDefault(_predict_proba);
#
# 	var _predicted_value = __webpack_require__(7);
#
# 	var _predicted_value2 = _interopRequireDefault(_predicted_value);
#
# 	function _interopRequireDefault(obj) { return obj && obj.__esModule ? obj : { default: obj }; }
#
# 	if (!global._babelPolyfill) {
# 	  __webpack_require__(8);
# 	}
#
# 	__webpack_require__(339);
#
# 	exports.Explanation = _explanation2.default;
# 	exports.Barchart = _bar_chart2.default;
# 	exports.PredictProba = _predict_proba2.default;
# 	exports.PredictedValue = _predicted_value2.default;
# 	//require('style-loader');
# 	/* WEBPACK VAR INJECTION */}.call(exports, (function() { return this; }())))
#
# /***/ }),
# /* 1 */
# /***/ (function(module, exports, __webpack_require__) {
#
# 	'use strict';
#
# 	Object.defineProperty(exports, "__esModule", {
# 	  value: true
# 	});
#
# 	var _slicedToArray = function () { function sliceIterator(arr, i) { var _arr = []; var _n = true; var _d = false; var _e = undefined; try { for (var _i = arr[Symbol.iterator](), _s; !(_n = (_s = _i.next()).done); _n = true) { _arr.push(_s.value); if (i && _arr.length === i) break; } } catch (err) { _d = true; _e = err; } finally { try { if (!_n && _i["return"]) _i["return"](); } finally { if (_d) throw _e; } } return _arr; } return function (arr, i) { if (Array.isArray(arr)) { return arr; } else if (Symbol.iterator in Object(arr)) { return sliceIterator(arr, i); } else { throw new TypeError("Invalid attempt to destructure non-iterable instance"); } }; }();
#
# 	var _d2 = __webpack_require__(2);
#
# 	var _d3 = _interopRequireDefault(_d2);
#
# 	var _bar_chart = __webpack_require__(3);
#
# 	var _bar_chart2 = _interopRequireDefault(_bar_chart);
#
# 	var _lodash = __webpack_require__(4);
#
# 	function _interopRequireDefault(obj) { return obj && obj.__esModule ? obj : { default: obj }; }
#
# 	function _classCallCheck(instance, Constructor) { if (!(instance instanceof Constructor)) { throw new TypeError("Cannot call a class as a function"); } }
#
# 	var Explanation = function () {
# 	  function Explanation(class_names) {
# 	    _classCallCheck(this, Explanation);
#
# 	    this.names = class_names;
# 	    if (class_names.length < 10) {
# 	      this.colors = _d3.default.scale.category10().domain(this.names);
# 	      this.colors_i = _d3.default.scale.category10().domain((0, _lodash.range)(this.names.length));
# 	    } else {
# 	      this.colors = _d3.default.scale.category20().domain(this.names);
# 	      this.colors_i = _d3.default.scale.category20().domain((0, _lodash.range)(this.names.length));
# 	    }
# 	  }
# 	  // exp: [(feature-name, weight), ...]
# 	  // label: int
# 	  // div: d3 selection
#
#
# 	  Explanation.prototype.show = function show(exp, label, div) {
# 	    var svg = div.append('svg').style('width', '100%');
# 	    var colors = ['#5F9EA0', this.colors_i(label)];
# 	    var names = ['NOT ' + this.names[label], this.names[label]];
# 	    if (this.names.length == 2) {
# 	      colors = [this.colors_i(0), this.colors_i(1)];
# 	      names = this.names;
# 	    }
# 	    var plot = new _bar_chart2.default(svg, exp, true, names, colors, true, 10);
# 	    svg.style('height', plot.svg_height + 'px');
# 	  };
# 	  // exp has all ocurrences of words, with start index and weight:
# 	  // exp = [('word', 132, -0.13), ('word3', 111, 1.3)
#
#
# 	  Explanation.prototype.show_raw_text = function show_raw_text(exp, label, raw, div) {
# 	    var opacity = arguments.length > 4 && arguments[4] !== undefined ? arguments[4] : true;
#
# 	    //let colors=['#5F9EA0', this.colors(this.exp['class'])];
# 	    var colors = ['#5F9EA0', this.colors_i(label)];
# 	    if (this.names.length == 2) {
# 	      colors = [this.colors_i(0), this.colors_i(1)];
# 	    }
# 	    var word_lists = [[], []];
# 	    var max_weight = -1;
# 	    var _iteratorNormalCompletion = true;
# 	    var _didIteratorError = false;
# 	    var _iteratorError = undefined;
#
# 	    try {
# 	      for (var _iterator = exp[Symbol.iterator](), _step; !(_iteratorNormalCompletion = (_step = _iterator.next()).done); _iteratorNormalCompletion = true) {
# 	        var _step$value = _slicedToArray(_step.value, 3),
# 	            word = _step$value[0],
# 	            start = _step$value[1],
# 	            weight = _step$value[2];
#
# 	        if (weight > 0) {
# 	          word_lists[1].push([start, start + word.length, weight]);
# 	        } else {
# 	          word_lists[0].push([start, start + word.length, -weight]);
# 	        }
# 	        max_weight = Math.max(max_weight, Math.abs(weight));
# 	      }
# 	    } catch (err) {
# 	      _didIteratorError = true;
# 	      _iteratorError = err;
# 	    } finally {
# 	      try {
# 	        if (!_iteratorNormalCompletion && _iterator.return) {
# 	          _iterator.return();
# 	        }
# 	      } finally {
# 	        if (_didIteratorError) {
# 	          throw _iteratorError;
# 	        }
# 	      }
# 	    }
#
# 	    if (!opacity) {
# 	      max_weight = 0;
# 	    }
# 	    this.display_raw_text(div, raw, word_lists, colors, max_weight, true);
# 	  };
# 	  // exp is list of (feature_name, value, weight)
#
#
# 	  Explanation.prototype.show_raw_tabular = function show_raw_tabular(exp, label, div) {
# 	    div.classed('lime', true).classed('table_div', true);
# 	    var colors = ['#5F9EA0', this.colors_i(label)];
# 	    if (this.names.length == 2) {
# 	      colors = [this.colors_i(0), this.colors_i(1)];
# 	    }
# 	    var table = div.append('table');
# 	    var thead = table.append('tr');
# 	    thead.append('td').text('Feature');
# 	    thead.append('td').text('Value');
# 	    thead.style('color', 'black').style('font-size', '20px');
# 	    var _iteratorNormalCompletion2 = true;
# 	    var _didIteratorError2 = false;
# 	    var _iteratorError2 = undefined;
#
# 	    try {
# 	      for (var _iterator2 = exp[Symbol.iterator](), _step2; !(_iteratorNormalCompletion2 = (_step2 = _iterator2.next()).done); _iteratorNormalCompletion2 = true) {
# 	        var _step2$value = _slicedToArray(_step2.value, 3),
# 	            fname = _step2$value[0],
# 	            value = _step2$value[1],
# 	            weight = _s

# %%
lime_local_explanation_of_an_instance.as_map()
# Out:
# {0: [(2, 0.06932286895276678),
#   (3, 0.06596564934557661),
#   (1, -0.053227853507562345),
#   (0, -0.028295581475254107),
#   (7, -0.012647349469715337),
#   (9, 0.012070963419703144),
#   (8, -0.00841695749812084),
#   (5, 0.008405338912332775),
#   (6, -0.005828137121342481),
#   (4, -0.0004554848880368046)]}

# %%
X_test.loc[file_to_be_explained,:]
# Out:
# CountPath_Max       1032.000000
# CountPath_Mean        47.863636
# Del_lines              0.000000
# Added_lines            0.000000
# CountLine            170.000000
# CountStmt             90.000000
# CountLineCode        112.000000
# CountLineCodeExe      56.000000
# CountSemicolon        56.000000
# CountStmtExe          56.000000
# Name: lucene/backwards/src/test/org/apache/lucene/analysis/BaseTokenStreamTestCase.java, dtype: float64

# %%
test_indx_list = X_test.index.tolist()
test_dict={}
for n in test_indx_list:
    exp = our_lime_explainer.explain_instance(X_test.loc[n].values, our_rf_model.predict_proba, num_features=5, top_labels = 1, num_samples = 2500)
    a=exp.as_map()
    test_dict[n] = a
test_dict
# Out:
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# ...
#     -0.09243194720073468),
#    (3, -0.05845032642743765),
#    (0, -0.048134571563464824),
#    (1, -0.029846681926028195),
#    (2, 0.010709408569845525)]},
#  'lucene/contrib/queryparser/src/java/org/apache/lucene/queryParser/standard/processors/DefaultPhraseSlopQueryNodeProcessor.java': {1: [(2,
#     -0.11428763218740458),
#    (3, -0.1032949950258626),
#    (1, -0.032987820196166105),
#    (0, -0.02625910091044555),
#    (4, -0.021061756658414466)]},
#  'lucene/contrib/queryparser/src/java/org/apache/lucene/queryParser/standard/processors/FuzzyQueryNodeProcessor.java': {1: [(2,
#     -0.10862064533547292),
#    (3, -0.10740928690186334),
#    (4, -0.08831265047395012),
#    (0, -0.04381665586513388),
#    (1, -0.04199150091039148)]},
#  'lucene/contrib/queryparser/src/java/org/apache/lucene/queryParser/standard/processors/GroupQueryNodeProcessor.java': {1: [(2,
#     -0.12465792171794002),
#    (3, -0.10335837659292278),
#    (0, 0.0997848051621333),
#    (1, 0.08347364219420011),
#    (4, -0.022506037605488364)]},
#  'lucene/contrib/queryparser/src/java/org/apache/lucene/queryParser/standard/processors/LowercaseExpandedTermsQueryNodeProcessor.java': {1: [(3,
#     -0.08902275078940508),
#    (4, -0.07957929594453074),
#    (0, -0.04328190305104334),
#    (1, -0.03704200740758657),
#    (2, 0.01626382583971908)]},
#  'lucene/contrib/queryparser/src/java/org/apache/lucene/queryParser/standard/processors/MatchAllDocsQueryNodeProcessor.java': {1: [(2,
#     -0.10960874998793539),
#    (3, -0.09641360047594569),
#    (4, -0.08954920892898083),
#    (0, -0.041897561109436175),
#    (1, -0.025646528538396506)]},
#  'lucene/contrib/queryparser/src/java/org/apache/lucene/queryParser/standard/processors/MultiFieldQueryNodeProcessor.java': {1: [(2,
#     -0.11044432588591582),
#    (3, -0.10558060803356858),
#    (0, 0.0819702894143681),
#    (1, 0.081943534089169),
#    (4, -0.03472499427390761)]},
#  'lucene/contrib/queryparser/src/java/org/apache/lucene/queryParser/standard/processors/MultiTermRewriteMethodProcessor.java': {1: [(2,
#     -0.11626444468197204),
#    (3, -0.09659504229464108),
#    (4, -0.08612179457591922),
#    (1, -0.04103399971804366),
#    (0, -0.03719448836845962)]},
#  'lucene/contrib/queryparser/src/java/org/apache/lucene/queryParser/standard/processors/ParametricRangeQueryNodeProcessor.java': {1: [(0,
#     0.10673075518653609),
#    (2, 0.10620666729063594),
#    (1, 0.08133153404802494),
#    (3, -0.07506489243122899),
#    (4, -0.02644671031502043)]},
#  'lucene/contrib/queryparser/src/java/org/apache/lucene/queryParser/standard/processors/PhraseSlopQueryNodeProcessor.java': {1: [(2,
#     -0.12149877474149821),
#    (3, -0.09940530994379061),
#    (4, -0.0849988786002233),
#    (0, -0.03444410138443901),
#    (1, -0.029588023537125297)]},
#  'lucene/contrib/queryparser/src/java/org/apache/lucene/queryParser/standard/processors/RemoveEmptyNonLeafQueryNodeProcessor.java': {1: [(3,
#     -0.10070061115005932),
#    (2, -0.09847550941766771),
#    (0, -0.062104422929356765),
#    (1, -0.04516404912271523),
#    (4, -0.030757728762769995)]},
#  'lucene/contrib/queryparser/src/java/org/apache/lucene/queryParser/standard/processors/StandardQueryNodeProcessorPipeline.java': {1: [(2,
#     0.1036497522210391),
#    (4, -0.0955562357937219),
#    (3, -0.07610014509006881),
#    (1, -0.01676392715351993),
#    (0, -0.014398998984103772)]},
#  'lucene/contrib/queryparser/src/java/org/apache/lucene/queryParser/standard/processors/WildcardQueryNodeProcessor.java': {1: [(2,
#     -0.11969118176436376),
#    (3, -0.09974606194596529),
#    (1, 0.0756195298819417),
#    (0, -0.03853054865597138),
#    (4, -0.022697112504484394)]},
#  'lucene/contrib/queryparser/src/java/org/apache/lucene/queryParser/standard/QueryParserUtil.java': {1: [(2,
#     -0.11811619789456285),
#    (3, -0.0983980627071347),
#    (1, 0.07837972893318301),
#    (4, -0.03918703148853636),
#    (0, -0.033667140779572245)]},
#  'lucene/contrib/queryparser/src/java/org/apache/lucene/queryParser/standard/QueryParserWrapper.java': {1: [(4,
#     0.25216952127213255),
#    (2, 0.08822862381607532),
#    (3, -0.06597084405643584),
#    (0, -0.04658123129546002),
#    (1, -0.029248866662403835)]},
#  'lucene/contrib/queryparser/src/java/org/apache/lucene/queryParser/standard/StandardQueryParser.java': {1: [(4,
#     0.24041903812044013),
#    (2, 0.0954307395537463),
#    (3, -0.08195511107410061),
#    (0, -0.03810616931276223),
#    (1, -0.031476072886202106)]},
#  'lucene/contrib/queryparser/src/java/org/apache/lucene/queryParser/surround/parser/CharStream.java': {1: [(4,
#     -0.08728002231902567),
#    (3, -0.07755884119102202),
#    (2, 0.05735458257174349),
#    (0, -0.014330422251601208),
#    (1, -0.012431374742407913)]},
#  'lucene/contrib/queryparser/src/java/org/apache/lucene/queryParser/surround/parser/FastCharStream.java': {1: [(2,
#     -0.11868483030806719),
#    (3, -0.10277423996183818),
#    (0, -0.053855423811250705),
#    (1, -0.031768020284739934),
#    (4, -0.022150764836650898)]},
#  'lucene/contrib/queryparser/src/java/org/apache/lucene/queryParser/surround/parser/ParseException.java': {1: [(3,
#     -0.11352231779702668),
#    (2, -0.1131146417987326),
#    (0, 0.09122576165174326),
#    (1, 0.08761289048663123),
#    (4, -0.021500844381149888)]},
#  'lucene/contrib/queryparser/src/java/org/apache/lucene/queryParser/surround/parser/QueryParser.java': {1: [(4,
#     0.23492470353390027),
#    (2, 0.09590058978932109),
#    (0, 0.09409117990884787),
#    (1, 0.08566696179912264),
#    (3, -0.0634529042859323)]},
#  'lucene/contrib/queryparser/src/java/org/apache/lucene/queryParser/surround/parser/QueryParserConstants.java': {1: [(3,
#     -0.11945581032459099),
#    (2, -0.09938619994819621),
#    (4, -0.07775418426330209),
#    (1, -0.00779428980495598),
#    (0, -0.006634914329203188)]},
#  'lucene/contrib/queryparser/src/java/org/apache/lucene/queryParser/surround/parser/QueryParserTokenManager.java': {1: [(4,
#     0.23241634891300433),
#    (2, -0.11622177054225745),
#    (3, -0.10116895448506147),
#    (0, 0.08770485079511679),
#    (1, 0.08046708789796454)]},
#  'lucene/contrib/queryparser/src/java/org/apache/lucene/queryParser/surround/parser/Token.java': {1: [(3,
#     -0.10142020584207635),
#    (2, -0.10110938754556907),
#    (4, -0.034662081339645046),
#    (1, -0.024711965506755643),
#    (0, -0.014607373255692434)]},
#  'lucene/contrib/queryparser/src/java/org/apache/lucene/queryParser/surround/parser/TokenMgrError.java': {1: [(2,
#     -0.1081929800507277),
#    (3, -0.10645673869639538),
#    (0, 0.09411781121398595),
#    (1, -0.038658866606048996),
#    (4, -0.026719992244029142)]},
#  'lucene/contrib/queryparser/src/java/org/apache/lucene/queryParser/surround/query/AndQuery.java': {1: [(2,
#     -0.11530881986874869),
#    (4, -0.11486789003833962),
#    (3, -0.10792539327095715),
#    (1, -0.013026790472424077),
#    (0, -0.009627753989158242)]},
#  'lucene/contrib/queryparser/src/java/org/apache/lucene/queryParser/surround/query/BasicQueryFactory.java': {1: [(4,
#     -0.11767715593973803),
#    (3, -0.11055203122685132),
#    (2, -0.10825287522196066),
#    (0, -0.03907353081678489),
#    (1, -0.029726781280595582)]},
#  'lucene/contrib/queryparser/src/java/org/apache/lucene/queryParser/surround/query/ComposedQuery.java': {1: [(2,
#     -0.10550085656058425),
#    (3, -0.10013732025062973),
#    (4, -0.029738132046337518),
#    (0, -0.028410589928319425),
#    (1, -0.02765755773748352)]},
#  'lucene/contrib/queryparser/src/java/org/apache/lucene/queryParser/surround/query/DistanceQuery.java': {1: [(3,
#     -0.10534378338588431),
#    (2, -0.0998545372203869),
#    (0, -0.05625366118096585),
#    (1, -0.035231782609517634),
#    (4, -0.03229562524161604)]},
#  'lucene/contrib/queryparser/src/java/org/apache/lucene/queryParser/surround/query/DistanceSubQuery.java': {1: [(4,
#     -0.11419758265389535),
#    (2, -0.10965277069489011),
#    (3, -0.10771777261997523),
#    (1, -0.015475842376261565),
#    (0, -0.004687009812441029)]},
#  'lucene/contrib/queryparser/src/java/org/apache/lucene/queryParser/surround/query/FieldsQuery.java': {1: [(2,
#     -0.1219034809848544),
#    (3, -0.09791507297853937),
#    (4, -0.08739392822062533),
#    (0, -0.03959747341014811),
#    (1, -0.024222585070646462)]},
#  'lucene/contrib/queryparser/src/java/org/apache/lucene/queryParser/surround/query/NotQuery.java': {1: [(2,
#     -0.1258009059605947),
#    (4, -0.1194606046466406),
#    (3, -0.08818186904007747),
#    (1, -0.023018628785640576),
#    (0, -0.014017520338044388)]},
#  'lucene/contrib/queryparser/src/java/org/apache/lucene/queryParser/surround/query/OrQuery.java': {1: [(4,
#     -0.11616187226172216),
#    (2, -0.11324445073460924),
#    (3, -0.10416339652489595),
#    (0, -0.03692921558194402),
#    (1, -0.02731925021952834)]},
#  'lucene/contrib/queryparser/src/java/org/apache/lucene/queryParser/surround/query/SimpleTerm.java': {1: [(2,
#     -0.1236403172385822),
#    (3, -0.10715267779951079),
#    (0, -0.04054390175394458),
#    (1, -0.03949630702832039),
#    (4, -0.021992752237147202)]},
#  'lucene/contrib/queryparser/src/java/org/apache/lucene/queryParser/surround/query/SpanNearClauseFactory.java': {1: [(2,
#     -0.11888485994012554),
#    (3, -0.09509399706351934),
#    (0, -0.0420506237870597),
#    (1, -0.03020836255037927),
#    (4, -0.029592313467554577)]},
#  'lucene/contrib/queryparser/src/java/org/apache/lucene/queryParser/surround/query/SrndBooleanQuery.java': {1: [(4,
#     -0.1197077877474817),
#    (2, -0.10468708763315743),
#    (3, -0.09622603581311212),
#    (0, -0.047331362246575324),
#    (1, -0.014914304648281158)]},
#  'lucene/contrib/queryparser/src/java/org/apache/lucene/queryParser/surround/query/SrndPrefixQuery.java': {1: [(2,
#     -0.11767779478076726),
#    (3, -0.09469074670501579),
#    (4, -0.09203933550130601),
#    (0, -0.033566067653912804),
#    (1, -0.030692528682312762)]},
#  'lucene/contrib/queryparser/src/java/org/apache/lucene/queryParser/surround/query/SrndQuery.java': {1: [(2,
#     -0.11233048628171048),
#    (3, -0.10655458226218295),
#    (4, -0.09368202355644802),
#    (0, -0.0339441219521184),
#    (1, -0.031445319213121416)]},
#  'lucene/contrib/queryparser/src/java/org/apache/lucene/queryParser/surround/query/SrndTermQuery.java': {1: [(2,
#     -0.11888865032697706),
#    (3, -0.10515183185201019),
#    (4, -0.10351396234084166),
#    (1, -0.04331466848419505),
#    (0, -0.04238782988714827)]},
#  'lucene/contrib/queryparser/src/java/org/apache/lucene/queryParser/surround/query/SrndTruncQuery.java': {1: [(2,
#     -0.11674619754713202),
#    (3, -0.11087756504067023),
#    (4, -0.0923027569646764),
#    (0, -0.03872037680550651),
#    (1, -0.028861481421278142)]},
#  'lucene/contrib/queryparser/src/java/org/apache/lucene/queryParser/surround/query/TooManyBasicQueries.java': {1: [(4,
#     -0.12454672733712378),
#    (2, -0.11541405462332426),
#    (3, -0.1085869741296689),
#    (1, -0.02118632154059468),
#    (0, -0.0008907811862136728)]},
#  'lucene/contrib/queryparser/src/test/org/apache/lucene/queryParser/analyzing/TestAnalyzingQueryParser.java': {1: [(2,
#     -0.10811412655026831),
#    (3, -0.09697660896539485),
#    (0, -0.02921265900717151),
#    (4, -0.027067334804856603),
#    (1, -0.015509751558184072)]},
#  'lucene/contrib/queryparser/src/test/org/apache/lucene/queryParser/complexPhrase/TestComplexPhraseQuery.java': {1: [(2,
#     -0.1167959310760036),
#    (3, -0.10293052681515648),
#    (0, -0.04156348559417631),
#    (1, -0.03970353852629999),
#    (4, -0.03526892113207275)]},
#  'lucene/contrib/queryparser/src/test/org/apache/lucene/queryParser/core/builders/TestQueryTreeBuilder.java': {1: [(4,
#     -0.11399306464611629),
#    (2, -0.11096131652700653),
#    (0, -0.03523506612664605),
#    (1, -0.020969319542928157),
#    (3, 0.010122901548000312)]},
#  'lucene/contrib/queryparser/src/test/org/apache/lucene/queryParser/core/nodes/TestQueryNode.java': {1: [(4,
#     -0.11328831121137764),
#    (3, -0.08584505486967949),
#    (2, 0.04846834198407488),
#    (1, -0.009904592664683989),
#    (0, 0.0021091513976828637)]},
#  'lucene/contrib/queryparser/src/test/org/apache/lucene/queryParser/ext/ExtensionStub.java': {1: [(2,
#     -0.11411675070965663),
#    (4, -0.11246614993965043),
#    (3, -0.1114762715959227),
#    (0, -0.023113628692214946),
#    (1, -0.014910576866076468)]},
#  'lucene/contrib/queryparser/src/test/org/apache/lucene/queryParser/ext/TestExtendableQueryParser.java': {1: [(2,
#     -0.13171220903034445),
#    (3, -0.0965621713423421),
#    (4, -0.035997842470011754),
#    (1, -0.033371338014410404),
#    (0, -0.02948368958378663)]},
#  'lucene/contrib/queryparser/src/test/org/apache/lucene/queryParser/ext/TestExtensions.java': {1: [(2,
#     -0.11020463368995971),
#    (3, -0.09633588963274195),
#    (4, -0.08042186352779028),
#    (1, -0.044291021585977156),
#    (0, -0.03493410691333256)]},
#  'lucene/contrib/queryparser/src/test/org/apache/lucene/queryParser/precedence/TestPrecedenceQueryParser.java': {1: [(4,
#     0.2405613242155327),
#    (3, 0.15781765459892722),
#    (2, 0.09542812906510718),
#    (0, -0.03936775826614482),
#    (1, -0.038131478089740045)]},
#  'lucene/contrib/queryparser/src/test/org/apache/lucene/queryParser/spans/SpanOrQueryNodeBuilder.java': {1: [(4,
#     -0.11679323272372769),
#    (2, -0.10966791918458278),
#    (3, -0.10631552470999223),
#    (1, -0.03718325805937917),
#    (0, -0.03136033996395609)]},
#  'lucene/contrib/queryparser/src/test/org/apache/lucene/queryParser/spans/SpansQueryConfigHandler.java': {1: [(4,
#     -0.1205917557723677),
#    (3, -0.06571209409819605),
#    (0, -0.016153018035459654),
#    (1, -0.015256987758918946),
#    (2, 0.004515120696444606)]},
#  'lucene/contrib/queryparser/src/test/org/apache/lucene/queryParser/spans/SpansQueryTreeBuilder.java': {1: [(4,
#     -0.12814324984000364),
#    (2, -0.11967850755942197),
#    (3, -0.09181561722952912),
#    (1, -0.011277187920303872),
#    (0, 0.002987636848944527)]},
#  'lucene/contrib/queryparser/src/test/org/apache/lucene/queryParser/spans/SpansValidatorQueryNodeProcessor.java': {1: [(2,
#     -0.10840915916380697),
#    (3, -0.10351507796651405),
#    (4, -0.08191343830566276),
#    (1, -0.040364521636128206),
#    (0, -0.029309233750296846)]},
#  'lucene/contrib/queryparser/src/test/org/apache/lucene/queryParser/spans/SpanTermQueryNodeBuilder.java': {1: [(4,
#     -0.12248309513825063),
#    (2, -0.11250290690619213),
#    (3, -0.1093425060413186),
#    (0, -0.014878077711435499),
#    (1, -0.014616986941150266)]},
#  'lucene/contrib/queryparser/src/test/org/apache/lucene/queryParser/spans/TestSpanQueryParser.java': {1: [(4,
#     0.23350612682068164),
#    (0, 0.0903107022007453),
#    (1, 0.08306682764864236),
#    (3, -0.07286588142949199),
#    (2, 0.05612921927649632)]},
#  'lucene/contrib/queryparser/src/test/org/apache/lucene/queryParser/spans/TestSpanQueryParserSimpleSample.java': {1: [(3,
#     -0.08376700350613188),
#    (1, 0.07691161723978805),
#    (2, 0.06216844139624511),
#    (0, -0.04796446320325725),
#    (4, -0.03858373448778643)]},
#  'lucene/contrib/queryparser/src/test/org/apache/lucene/queryParser/spans/UniqueFieldAttribute.java': {1: [(2,
#     -0.13432720289293),
#    (4, -0.11764153893132566),
#    (3, -0.1073433212501706),
#    (1, -0.017591240359829508),
#    (0, 0.0027659427505692656)]},
#  'lucene/contrib/queryparser/src/test/org/apache/lucene/queryParser/spans/UniqueFieldAttributeImpl.java': {1: [(3,
#     -0.09565162488575052),
#    (4, -0.0876185835565556),
#    (2, 0.04935131784164301),
#    (0, -0.03603129439782499),
#    (1, -0.0290895815383651)]},
#  'lucene/contrib/queryparser/src/test/org/apache/lucene/queryParser/spans/UniqueFieldQueryNodeProcessor.java': {1: [(2,
#     -0.11418086000165266),
#    (3, -0.10227332047184018),
#    (4, -0.08492421119920632),
#    (0, -0.04693236047318896),
#    (1, -0.044037152659603736)]},
#  'lucene/contrib/queryparser/src/test/org/apache/lucene/queryParser/standard/config/TestAttributes.java': {1: [(4,
#     -0.11725901043191979),
#    (2, 0.063058474440438),
#    (0, -0.022599150078068023),
#    (1, -0.011440983775204163),
#    (3, 0.007668547692633291)]},
#  'lucene/contrib/queryparser/src/test/org/apache/lucene/queryParser/standard/TestMultiAnalyzerQPHelper.java': {1: [(4,
#     0.23470743624113427),
#    (2, -0.12043561279658582),
#    (3, -0.10410481242708691),
#    (0, -0.043115821657646616),
#    (1, -0.04168642876876244)]},
#  ...}

# %%
test_indx_list = X_test.index.tolist()
test_dict={}
for n in test_indx_list:
    exp = our_lime_explainer.explain_instance(X_test.loc[n].values, our_rf_model.predict_proba, num_features=5, top_labels = 1, num_samples = 2500)
    a=exp.as_map()
    test_dict[n] = a
test_dict
# Out:
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# ...
#     0.11976480349257487),
#    (4, 0.10339497475207889),
#    (3, 0.09704426383766177),
#    (0, 0.043727538283245215),
#    (1, 0.04220997823360594)]},
#  'lucene/contrib/queryparser/src/java/org/apache/lucene/queryParser/standard/processors/BoostQueryNodeProcessor.java': {0: [(4,
#     0.09400029332030238),
#    (3, 0.07778299026719665),
#    (1, 0.04342881486119266),
#    (0, 0.02750070417495414),
#    (2, 0.009351792062718)]},
#  'lucene/contrib/queryparser/src/java/org/apache/lucene/queryParser/standard/processors/DefaultPhraseSlopQueryNodeProcessor.java': {1: [(2,
#     -0.11360442528421887),
#    (3, -0.10405031550215459),
#    (1, -0.03174115782367508),
#    (0, -0.025109791933737437),
#    (4, -0.020199751695482618)]},
#  'lucene/contrib/queryparser/src/java/org/apache/lucene/queryParser/standard/processors/FuzzyQueryNodeProcessor.java': {0: [(2,
#     0.11975688773478407),
#    (3, 0.10301102467325815),
#    (4, 0.08601932626800565),
#    (0, 0.05761801530413863),
#    (1, 0.025747192941356654)]},
#  'lucene/contrib/queryparser/src/java/org/apache/lucene/queryParser/standard/processors/GroupQueryNodeProcessor.java': {0: [(2,
#     0.11680966751716036),
#    (0, -0.10561995526528824),
#    (3, 0.10414849716252064),
#    (1, -0.08164557257022056),
#    (4, 0.025699035092127606)]},
#  'lucene/contrib/queryparser/src/java/org/apache/lucene/queryParser/standard/processors/LowercaseExpandedTermsQueryNodeProcessor.java': {0: [(3,
#     0.08584590348569074),
#    (4, 0.0709238393892404),
#    (0, 0.04211621540687546),
#    (1, 0.038565692789326575),
#    (2, -0.006907573558546221)]},
#  'lucene/contrib/queryparser/src/java/org/apache/lucene/queryParser/standard/processors/MatchAllDocsQueryNodeProcessor.java': {0: [(2,
#     0.10812316785451576),
#    (3, 0.09221444471747996),
#    (4, 0.08489540149948771),
#    (1, 0.03512782658925208),
#    (0, 0.034772157076864)]},
#  'lucene/contrib/queryparser/src/java/org/apache/lucene/queryParser/standard/processors/MultiFieldQueryNodeProcessor.java': {0: [(2,
#     0.12281715056960318),
#    (3, 0.10704145653136111),
#    (0, -0.08420061344479884),
#    (1, -0.07587869145827365),
#    (4, 0.024574038287204815)]},
#  'lucene/contrib/queryparser/src/java/org/apache/lucene/queryParser/standard/processors/MultiTermRewriteMethodProcessor.java': {0: [(2,
#     0.1153190000203492),
#    (4, 0.09498740172423054),
#    (3, 0.09420543720558275),
#    (0, 0.04187282337574238),
#    (1, 0.04075744629094609)]},
#  'lucene/contrib/queryparser/src/java/org/apache/lucene/queryParser/standard/processors/ParametricRangeQueryNodeProcessor.java': {0: [(0,
#     -0.11145524513552219),
#    (2, -0.09698643787812478),
#    (1, -0.0886518252337674),
#    (3, 0.07461046407138677),
#    (4, 0.03996474694406574)]},
#  'lucene/contrib/queryparser/src/java/org/apache/lucene/queryParser/standard/processors/PhraseSlopQueryNodeProcessor.java': {0: [(2,
#     0.11903577341295128),
#    (3, 0.0998610928225101),
#    (4, 0.09546536925255879),
#    (0, 0.0404307433077137),
#    (1, 0.013899991162432086)]},
#  'lucene/contrib/queryparser/src/java/org/apache/lucene/queryParser/standard/processors/RemoveEmptyNonLeafQueryNodeProcessor.java': {0: [(3,
#     0.1068767382859882),
#    (2, 0.09962301734694018),
#    (1, 0.04293152534561648),
#    (0, 0.03151850642933578),
#    (4, 0.02059238955899722)]},
#  'lucene/contrib/queryparser/src/java/org/apache/lucene/queryParser/standard/processors/StandardQueryNodeProcessorPipeline.java': {0: [(4,
#     0.08653556116654289),
#    (3, 0.08495761714836994),
#    (2, -0.08236631809410006),
#    (1, 0.04147469423238123),
#    (0, 0.009678631860851945)]},
#  'lucene/contrib/queryparser/src/java/org/apache/lucene/queryParser/standard/processors/WildcardQueryNodeProcessor.java': {0: [(2,
#     0.11241982994395003),
#    (3, 0.10274979136085609),
#    (1, -0.08081610099479769),
#    (0, 0.04561899151037859),
#    (4, 0.03899419969869422)]},
#  'lucene/contrib/queryparser/src/java/org/apache/lucene/queryParser/standard/QueryParserUtil.java': {0: [(2,
#     0.11742365088407129),
#    (3, 0.10961896842314645),
#    (1, -0.08695667539375276),
#    (0, 0.04447647680223277),
#    (4, 0.038885184101174655)]},
#  'lucene/contrib/queryparser/src/java/org/apache/lucene/queryParser/standard/QueryParserWrapper.java': {1: [(4,
#     0.2401820776146247),
#    (2, 0.09746243360450826),
#    (3, -0.06480492575915744),
#    (1, -0.03881010282954352),
#    (0, -0.035435296708138546)]},
#  'lucene/contrib/queryparser/src/java/org/apache/lucene/queryParser/standard/StandardQueryParser.java': {1: [(4,
#     0.24870287749138592),
#    (2, 0.08876753918734191),
#    (3, -0.067000871887801),
#    (0, -0.03208776349330207),
#    (1, -0.02059026259335949)]},
#  'lucene/contrib/queryparser/src/java/org/apache/lucene/queryParser/surround/parser/CharStream.java': {0: [(4,
#     0.08620255882117632),
#    (2, -0.07137477313838281),
#    (3, 0.0635782082686892),
#    (0, 0.009383933367474303),
#    (1, -0.001644565921450703)]},
#  'lucene/contrib/queryparser/src/java/org/apache/lucene/queryParser/surround/parser/FastCharStream.java': {0: [(3,
#     0.11069595559230987),
#    (2, 0.10592662900192519),
#    (0, 0.03956174286442339),
#    (4, 0.03819741289109522),
#    (1, 0.02815343973154412)]},
#  'lucene/contrib/queryparser/src/java/org/apache/lucene/queryParser/surround/parser/ParseException.java': {0: [(2,
#     0.11784528579018952),
#    (3, 0.10554849548774835),
#    (0, -0.10003068134384087),
#    (1, -0.08145032477125573),
#    (4, 0.03800064816538096)]},
#  'lucene/contrib/queryparser/src/java/org/apache/lucene/queryParser/surround/parser/QueryParser.java': {1: [(4,
#     0.21470459574314524),
#    (2, 0.09408085888123913),
#    (0, 0.08446890209212685),
#    (1, 0.07262918102763719),
#    (3, -0.07113147858971501)]},
#  'lucene/contrib/queryparser/src/java/org/apache/lucene/queryParser/surround/parser/QueryParserConstants.java': {0: [(3,
#     0.12059388799157998),
#    (2, 0.11567203744731311),
#    (4, 0.09071534438578473),
#    (0, 0.005188289843795534),
#    (1, 0.00308187252974832)]},
#  'lucene/contrib/queryparser/src/java/org/apache/lucene/queryParser/surround/parser/QueryParserTokenManager.java': {0: [(4,
#     -0.22728686380257113),
#    (2, 0.11699025874599409),
#    (3, 0.1069118768045577),
#    (0, -0.08755941755241349),
#    (1, -0.07683361719854243)]},
#  'lucene/contrib/queryparser/src/java/org/apache/lucene/queryParser/surround/parser/Token.java': {0: [(2,
#     0.12023153182496377),
#    (3, 0.11378403703834475),
#    (4, 0.027773844678832555),
#    (0, 0.020551775017402272),
#    (1, 0.010035283509421039)]},
#  'lucene/contrib/queryparser/src/java/org/apache/lucene/queryParser/surround/parser/TokenMgrError.java': {0: [(2,
#     0.1205851816684405),
#    (3, 0.10092044393312155),
#    (0, -0.09291397394586152),
#    (1, 0.04391738181879849),
#    (4, 0.030102109102753516)]},
#  'lucene/contrib/queryparser/src/java/org/apache/lucene/queryParser/surround/query/AndQuery.java': {0: [(2,
#     0.11761458298862595),
#    (4, 0.11469380570525975),
#    (3, 0.10612243606363897),
#    (1, 0.020497599349677438),
#    (0, 0.012826157315794607)]},
#  'lucene/contrib/queryparser/src/java/org/apache/lucene/queryParser/surround/query/BasicQueryFactory.java': {0: [(4,
#     0.12762086403934372),
#    (2, 0.10947027937346317),
#    (3, 0.09790846162149315),
#    (0, 0.036443029488352374),
#    (1, 0.01906446350041565)]},
#  'lucene/contrib/queryparser/src/java/org/apache/lucene/queryParser/surround/query/ComposedQuery.java': {0: [(3,
#     0.10662904690060253),
#    (2, 0.10547283156801734),
#    (1, 0.052774183636323864),
#    (0, 0.04188004808083377),
#    (4, 0.027803843698973933)]},
#  'lucene/contrib/queryparser/src/java/org/apache/lucene/queryParser/surround/query/DistanceQuery.java': {0: [(2,
#     0.11293579624222211),
#    (3, 0.09647345438937076),
#    (1, 0.05606828773895607),
#    (0, 0.037727103779283865),
#    (4, 0.036020613657853244)]},
#  'lucene/contrib/queryparser/src/java/org/apache/lucene/queryParser/surround/query/DistanceSubQuery.java': {0: [(4,
#     0.12517892634457511),
#    (2, 0.11220695423552658),
#    (3, 0.10848620607205546),
#    (0, 0.021701019009690903),
#    (1, 0.017131848964603794)]},
#  'lucene/contrib/queryparser/src/java/org/apache/lucene/queryParser/surround/query/FieldsQuery.java': {0: [(2,
#     0.11572508498883137),
#    (3, 0.1032712660010803),
#    (4, 0.09426326466757742),
#    (0, 0.0337378298962924),
#    (1, 0.029752784206215133)]},
#  'lucene/contrib/queryparser/src/java/org/apache/lucene/queryParser/surround/query/NotQuery.java': {0: [(2,
#     0.1253406226949257),
#    (4, 0.12121717978557923),
#    (3, 0.10823816575325475),
#    (1, 0.013631107801988772),
#    (0, 0.0035827143836858625)]},
#  'lucene/contrib/queryparser/src/java/org/apache/lucene/queryParser/surround/query/OrQuery.java': {0: [(4,
#     0.10756394920341839),
#    (2, 0.10647479245429947),
#    (3, 0.10505792088565098),
#    (0, 0.04268192035528286),
#    (1, 0.03896054465213316)]},
#  'lucene/contrib/queryparser/src/java/org/apache/lucene/queryParser/surround/query/SimpleTerm.java': {0: [(2,
#     0.11312862587673818),
#    (3, 0.10819885318861923),
#    (0, 0.04089011413260789),
#    (1, 0.03369603533123187),
#    (4, 0.027749582332162993)]},
#  'lucene/contrib/queryparser/src/java/org/apache/lucene/queryParser/surround/query/SpanNearClauseFactory.java': {0: [(3,
#     0.11836243098800413),
#    (2, 0.1104635651380458),
#    (0, 0.04351027590839817),
#    (4, 0.03735283967032958),
#    (1, 0.02480220645337523)]},
#  'lucene/contrib/queryparser/src/java/org/apache/lucene/queryParser/surround/query/SrndBooleanQuery.java': {0: [(2,
#     0.1189245165532048),
#    (4, 0.10902423668030019),
#    (3, 0.10755493980316579),
#    (0, 0.029258492020494725),
#    (1, 0.024469380366593366)]},
#  'lucene/contrib/queryparser/src/java/org/apache/lucene/queryParser/surround/query/SrndPrefixQuery.java': {0: [(2,
#     0.10976167758562311),
#    (3, 0.09674197080987505),
#    (4, 0.08333446246556463),
#    (1, 0.034968789712126455),
#    (0, 0.027570713731281733)]},
#  'lucene/contrib/queryparser/src/java/org/apache/lucene/queryParser/surround/query/SrndQuery.java': {0: [(2,
#     0.11360814765714129),
#    (3, 0.11108097040501289),
#    (4, 0.08561993796850896),
#    (1, 0.03341273760239988),
#    (0, 0.02142678753768616)]},
#  'lucene/contrib/queryparser/src/java/org/apache/lucene/queryParser/surround/query/SrndTermQuery.java': {0: [(4,
#     0.11441335169799122),
#    (2, 0.10455344807967844),
#    (3, 0.0997785994332067),
#    (0, 0.0517143315226302),
#    (1, 0.0337335254207059)]},
#  'lucene/contrib/queryparser/src/java/org/apache/lucene/queryParser/surround/query/SrndTruncQuery.java': {0: [(3,
#     0.11860648498312643),
#    (2, 0.10743452766618794),
#    (4, 0.0787395488895497),
#    (0, 0.050643757330739635),
#    (1, 0.033543937702621235)]},
#  'lucene/contrib/queryparser/src/java/org/apache/lucene/queryParser/surround/query/TooManyBasicQueries.java': {0: [(4,
#     0.12397102861163743),
#    (2, 0.11122985772901775),
#    (3, 0.10190603282267491),
#    (1, 0.022324839004456604),
#    (0, 0.00933889476394073)]},
#  'lucene/contrib/queryparser/src/test/org/apache/lucene/queryParser/analyzing/TestAnalyzingQueryParser.java': {0: [(2,
#     0.12116519749832513),
#    (3, 0.09846538342358271),
#    (1, 0.038592470430890334),
#    (0, 0.036773764280198636),
#    (4, 0.02955406676850274)]},
#  'lucene/contrib/queryparser/src/test/org/apache/lucene/queryParser/complexPhrase/TestComplexPhraseQuery.java': {0: [(2,
#     0.11491831722854255),
#    (3, 0.09407849774355283),
#    (4, 0.03512857509891476),
#    (0, 0.030634852180808067),
#    (1, 0.030005620048721406)]},
#  'lucene/contrib/queryparser/src/test/org/apache/lucene/queryParser/core/builders/TestQueryTreeBuilder.java': {0: [(4,
#     0.11062699039355692),
#    (2, 0.10651417736056266),
#    (1, 0.021756496655466875),
#    (0, 0.01791976301673547),
#    (3, 0.0009917176568707221)]},
#  'lucene/contrib/queryparser/src/test/org/apache/lucene/queryParser/core/nodes/TestQueryNode.java': {0: [(4,
#     0.1074560849908681),
#    (3, 0.08643681915682115),
#    (2, -0.049875335936456336),
#    (1, 0.024286320731186365),
#    (0, 0.002550954781235584)]},
#  'lucene/contrib/queryparser/src/test/org/apache/lucene/queryParser/ext/ExtensionStub.java': {0: [(2,
#     0.12307601990414278),
#    (4, 0.11598792388482818),
#    (3, 0.10094121756359031),
#    (0, 0.017537391367195097),
#    (1, 0.009518364288154812)]},
#  'lucene/contrib/queryparser/src/test/org/apache/lucene/queryParser/ext/TestExtendableQueryParser.java': {0: [(2,
#     0.11730991869304036),
#    (3, 0.0944336825419135),
#    (1, 0.04786618652587489),
#    (4, 0.04106877401756201),
#    (0, 0.025408234717860093)]},
#  'lucene/contrib/queryparser/src/test/org/apache/lucene/queryParser/ext/TestExtensions.java': {0: [(2,
#     0.1283916882673604),
#    (4, 0.1008345260359881),
#    (3, 0.08737974059527226),
#    (0, 0.038934262307172944),
#    (1, 0.02229672920810754)]},
#  'lucene/contrib/queryparser/src/test/org/apache/lucene/queryParser/precedence/TestPrecedenceQueryParser.java': {1: [(4,
#     0.23567543302150948),
#    (3, 0.1662406278630594),
#    (2, 0.08818148033946892),
#    (0, -0.03872912335662274),
#    (1, -0.013358888061815326)]},
#  'lucene/contrib/queryparser/src/test/org/apache/lucene/queryParser/spans/SpanOrQueryNodeBuilder.java': {0: [(4,
#     0.11144906836093192),
#    (2, 0.10952843882504287),
#    (3, 0.10217056070731048),
#    (0, 0.03898250279642395),
#    (1, 0.03071255717556033)]},
#  'lucene/contrib/queryparser/src/test/org/apache/lucene/queryParser/spans/SpansQueryConfigHandler.java': {0: [(4,
#     0.11624133287898601),
#    (3, 0.06439344342405746),
#    (0, 0.019100268068178123),
#    (2, -0.017151184310544756),
#    (1, 0.011047964975969804)]},
#  'lucene/contrib/queryparser/src/test/org/apache/lucene/queryParser/spans/SpansQueryTreeBuilder.java': {0: [(4,
#     0.12093872645156405),
#    (2, 0.11849174586783265),
#    (3, 0.10278295891764125),
#    (1, 0.023019881183377503),
#    (0, 0.012246822165227184)]},
#  'lucene/contrib/queryparser/src/test/org/apache/lucene/queryParser/spans/SpansValidatorQueryNodeProcessor.java': {0: [(2,
#     0.11041764269245305),
#    (3, 0.1028961681999843),
#    (4, 0.09062615875060219),
#    (1, 0.04038287203915663),
#    (0, 0.024982003427298942)]},
#  'lucene/contrib/queryparser/src/test/org/apache/lucene/queryParser/spans/SpanTermQueryNodeBuilder.java': {0: [(4,
#     0.1264177239803523),
#    (3, 0.11259411175024363),
#    (2, 0.1112634169382789),
#    (1, 0.025204636515576462),
#    (0, 0.019764984931240757)]},
#  'lucene/contrib/queryparser/src/test/org/apache/lucene/queryParser/spans/TestSpanQueryParser.java': {0: [(4,
#     -0.24076585866393976),
#    (0, -0.0962657720100238),
#    (1, -0.07285577011417041),
#    (3, 0.06746719273648695),
#    (2, -0.05653739302947474)]},
#  'lucene/contrib/queryparser/src/test/org/apache/lucene/queryParser/spans/TestSpanQueryParserSimpleSample.java': {0: [(1,
#     -0.0869591201362543),
#    (3, 0.07685376534622691),
#    (0, 0.04599206841209008),
#    (2, -0.043712724587038614),
#    (4, 0.042043449297978014)]},
#  'lucene/contrib/queryparser/src/test/org/apache/lucene/queryParser/spans/UniqueFieldAttribute.java': {0: [(4,
#     0.1261697818623242),
#    (3, 0.12240703294576244),
#    (2, 0.11039876640442665),
#    (1, 0.01176932646695034),
#    (0, 0.00033009844993111084)]},
#  'lucene/contrib/queryparser/src/test/org/apache/lucene/queryParser/spans/UniqueFieldAttributeImpl.java': {0: [(3,
#     0.09746761102828498),
#    (4, 0.09217399420907857),
#    (2, -0.05343728276498882),
#    (0, 0.04694321261240146),
#    (1, 0.01983041074854866)]},
#  'lucene/contrib/queryparser/src/test/org/apache/lucene/queryParser/spans/UniqueFieldQueryNodeProcessor.java': {0: [(2,
#     0.1091282342499659),
#    (3, 0.10840516335116769),
#    (4, 0.09999404296675679),
#    (0, 0.04749208109925734),
#    (1, 0.03540272657404139)]},
#  'lucene/contrib/queryparser/src/test/org/apache/lucene/queryParser/standard/config/TestAttributes.java': {0: [(4,
#     0.11777704230785457),
#    (2, -0.05544419853133093),
#    (1, 0.021479849212351097),
#    (0, 0.018423789120589867),
#    (3, -0.005766124100162431)]},
#  'lucene/contrib/queryparser/src/test/org/apache/lucene/queryParser/standard/TestMultiAnalyzerQPHelper.java': {0: [(4,
#     -0.24074266230059377),
#    (2, 0.11425472464150535),
#    (3, 0.10051405463896203),
#    (1, 0.04848554063859398),
#    (0, 0.041343691180538246)]},
#  ...}

# %%
import csv
with open("file.csv", "w", newline="") as fp:
    # Create a writer object
    writer = csv.DictWriter(fp, fieldnames=test_dict.keys())

    # Write the header row
    writer.writeheader()

    # Write the data rows
    writer.writerow(test_dict)
    print('Done writing dict to a csv file')
# Out:
# Done writing dict to a csv file

# %%
import pandas as pd
import ast
df = pd.read_csv("file.csv")
columns = df.columns.values.tolist()
val_cal_0 = {"0": 0, "1": 0, "2": 0, "3": 0, "4": 0}
val_cal_1 = {"0": 0, "1": 0, "2": 0, "3": 0, "4": 0}
val_cal_count_0 = {"0": 0, "1": 0, "2": 0, "3": 0, "4": 0}
val_cal_count_1 = {"0": 0, "1": 0, "2": 0, "3": 0, "4": 0}
for col in columns:
#     print(df[col].values.tolist()[0])
    val = ast.literal_eval(df[col].values.tolist()[0])
    if 0 in val.keys():
        dict_val = val[0]
        for i in dict_val:
            index = str(i[0])
            value = i[1]
            val_cal_0[index] += value
            val_cal_count_0[index] +=1
    else:
        dict_val = val[1]
        for i in dict_val:
            index = str(i[0])
            value = i[1]
            val_cal_1[index] += value
            val_cal_count_1[index] +=1
print(val_cal_0)
print(val_cal_count_0)
print(val_cal_1)
print(val_cal_count_1)
# Out:
# {'0': 5.088484645726477, '1': 1.8371661556059797, '2': 86.9433132662648, '3': 203.98715766671484, '4': 44.374170392790056}
# {'0': 2607, '1': 2607, '2': 2607, '3': 2607, '4': 2607}
# {'0': 7.197018125243167, '1': 5.580436650460818, '2': 11.124735917231188, '3': 5.163721513522769, '4': 32.47894199030552}
# {'0': 199, '1': 199, '2': 199, '3': 199, '4': 199}

# %%
print("For defective: ")
for i in val_cal_0.keys():
    print("for {}: average is {}".format(i, (val_cal_0[i]/val_cal_count_0[i])))
# Out:
# For defective:
# for 0: average is 0.001951854486277897
# for 1: average is 0.000704705084620629
# for 2: average is 0.03334994755130986
# for 3: average is 0.07824593696460101
# for 4: average is 0.017021162406133508

# %%
print("For clean: ")
for i in val_cal_1.keys():
    print("for {}: average is {}".format(i, (val_cal_1[i]/val_cal_count_1[i])))
# Out:
# For clean:
# for 0: average is 0.0361659202273526
# for 1: average is 0.028042395228446322
# for 2: average is 0.05590319556397582
# for 3: average is 0.025948349314184768
# for 4: average is 0.16321076377037952

# %% [markdown]
# ## SHAP

# %%
# Import libraries for SHAP
import subprocess
import sys
import importlib
import numpy
import shap

file_to_be_explained = 'lucene/backwards/src/test/org/apache/lucene/analysis/BaseTokenStreamTestCase.java'
file_to_be_explained_idx = list(X_test.index).index(file_to_be_explained)

# %%
# explainer = shap.Explainer(our_rf_model, numpy.ascontiguousarray(X_train))
# shap_values = explainer(numpy.ascontiguousarray(X_test))

explainer = shap.Explainer(our_rf_model)
shap_values = explainer(X_test)

# %%
import matplotlib.pyplot as plt
shap.plots.bar(shap_values[file_to_be_explained_idx, :, 1], show=True)

# %% [markdown]
# ## BreakDown

# %%
## Load Data and preparing datasets

# Import for Load Data
from os import listdir
from os.path import isfile, join
import pandas as pd

# Import for Split Data into Training and Testing Samples
from sklearn.model_selection import train_test_split

train_dataset = pd.read_csv(('/Users/saumenduroy/Documents/PhD Life/Explainability + SOAR/Explainers code/Best datset_model perspective_AUC/Data/lucene-2.9.0.csv'), index_col = 'File')
test_dataset = pd.read_csv(('/Users/saumenduroy/Documents/PhD Life/Explainability + SOAR/Explainers code/Best datset_model perspective_AUC/Data/lucene-3.1.csv'), index_col = 'File')

outcome = 'RealBug'
features = ['CountPath_Max', 'CountPath_Mean', 'Del_lines', 'Added_lines', 'CountLine', 'CountStmt', 'CountLineCode', 'CountLineCodeExe', 'CountSemicolon', 'CountStmtExe']
# commits - # of commits that modify the file of interest
# Added lines - # of added lines of code
# Count class coupled - # of classes that interact or couple with the class of interest
# LOC - # of lines of code
# RatioCommentToCode - The ratio of lines of comments to lines of code

# process outcome to 0 and 1
train_dataset[outcome] = pd.Categorical(train_dataset[outcome])
train_dataset[outcome] = train_dataset[outcome].cat.codes

test_dataset[outcome] = pd.Categorical(test_dataset[outcome])
test_dataset[outcome] = test_dataset[outcome].cat.codes

X_train = train_dataset.loc[:, features]
X_test = test_dataset.loc[:, features]

y_train = train_dataset.loc[:, outcome]
y_test = test_dataset.loc[:, outcome]

class_labels = ['Clean', 'Defective']

X_train.columns = features
X_test.columns = features
training_data = pd.concat([X_train, y_train], axis=1)
testing_data = pd.concat([X_test, y_test], axis=1)

# %%
from sklearn.ensemble import RandomForestClassifier
our_rf_model = RandomForestClassifier(random_state=0)
our_rf_model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=0)

# %%
#necessary imports
from pyBreakDown.explainer import Explainer
from pyBreakDown.explanation import Explanation
#make explainer object
exp = Explainer(clf=our_rf_model, data= X_train, colnames=features)

# %%
#make explanation object that contains all information

explanation = exp.explain(observation=X_train.iloc[0,:].values,direction="up",useIntercept=True)
# Out:
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names
# X does not have valid feature names, but RandomForestClassifier was fitted with feature names

# %%
explanation.visualize()

# %% [markdown]
# ## PyExplainer

# %%
## Load Data and preparing datasets

# Import for Load Data
from os import listdir
from os.path import isfile, join
import pandas as pd

# Import for Split Data into Training and Testing Samples
from sklearn.model_selection import train_test_split

train_dataset = pd.read_csv(('/Users/saumenduroy/Documents/PhD Life/Explainability + SOAR/Explainers code/Best datset_model perspective_AUC/Data/lucene-2.9.0.csv'), index_col = 'File')
test_dataset = pd.read_csv(('/Users/saumenduroy/Documents/PhD Life/Explainability + SOAR/Explainers code/Best datset_model perspective_AUC/Data/lucene-3.1.csv'), index_col = 'File')

outcome = 'RealBug'
features = ['CountPath_Max', 'CountPath_Mean', 'Del_lines', 'Added_lines', 'CountLine', 'CountStmt', 'CountLineCode', 'CountLineCodeExe', 'CountSemicolon', 'CountStmtExe']
# OWN_COMMIT - # code ownership
# Added lines - # of added lines of code
# Count class coupled - # of classes that interact or couple with the class of interest
# RatioCommentToCode - The ratio of lines of comments to lines of code

# process outcome to 0 and 1
train_dataset[outcome] = pd.Categorical(train_dataset[outcome])
train_dataset[outcome] = train_dataset[outcome].cat.codes

test_dataset[outcome] = pd.Categorical(test_dataset[outcome])
test_dataset[outcome] = test_dataset[outcome].cat.codes

X_train = train_dataset.loc[:, features]
X_test = test_dataset.loc[:, features]

y_train = train_dataset.loc[:, outcome]
y_test = test_dataset.loc[:, outcome]


class_labels = ['Clean', 'Defective']

X_train.columns = features
X_test.columns = features
training_data = pd.concat([X_train, y_train], axis=1)
testing_data = pd.concat([X_test, y_test], axis=1)

# %%
from sklearn.ensemble import RandomForestClassifier
rf_model = RandomForestClassifier(random_state=0)
rf_model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=0)

# %%
from pyexplainer.pyexplainer_pyexplainer import PyExplainer
file_to_be_explained = 'lucene/backwards/src/test/org/apache/lucene/analysis/BaseTokenStreamTestCase.java'
import numpy as np
np.random.seed(0)

pyexp = PyExplainer(X_train = X_train,
                           y_train = y_train,
                           indep = X_train.columns,
                           dep = outcome,
                           top_k_rules=5,
                           blackbox_model = rf_model)

# PyExplainer Step 2 - Generate the rule-based explanation of an instance to be explained
exp_obj = pyexp.explain(X_explain = X_test.loc[file_to_be_explained,:].to_frame().transpose(),
                        y_explain = pd.Series(bool(y_test.loc[file_to_be_explained]), 
                                                      index = [file_to_be_explained],
                                                      name = outcome),
                        search_function = 'crossoverinterpolation',
                        max_iter=1000,
                        max_rules=20,
                        random_state=0,
                        reuse_local_model=True)

# Print rule 
exp_obj['top_k_positive_rules'][:1]

# Please use the code below to visualise the generated PyExplainer explanation (What-If interactive visualisation).
pyexp.visualise(exp_obj, title="Why this file is predicted as defect-introducing?")
# Out:
# set top_k_rules failed, top_k_rules should be int in range 1 - 15 (both included)
# PyExplainer can not find rules to avoid!
# This could lead to blank explanation UI!
# Please check whether the global model is properly trained with sufficient training data.
# HBox(children=(Label(value='Risk Score: '), FloatProgress(value=0.0, bar_style='info', layout=Layout(width='40…
# Output(layout=Layout(border='3px solid black'))
# FloatSlider(value=47.86, continuous_update=False, description='#1 The value of CountPath_Mean is more than 47.…
# FloatSlider(value=170.0, continuous_update=False, description='#2 The value of CountLine is more than 170.0', …

# %% [markdown]
# ## PDP

# %%
## Load Data and preparing datasets

# Import for Load Data
from os import listdir
from os.path import isfile, join
import pandas as pd

# Import for Split Data into Training and Testing Samples
from sklearn.model_selection import train_test_split

train_dataset = pd.read_csv(('/Users/saumenduroy/Documents/PhD Life/Explainability + SOAR/Explainers code/Best datset_model perspective_AUC/Data/lucene-2.9.0.csv'), index_col = 'File')
test_dataset = pd.read_csv(('/Users/saumenduroy/Documents/PhD Life/Explainability + SOAR/Explainers code/Best datset_model perspective_AUC/Data/lucene-3.1.csv'), index_col = 'File')


#outcome = 'RealBug'
#features = ['MAJOR_COMMIT', 'ADEV', 'COMM', 'OWN_COMMIT', 'CountClassCoupled', 'HeuBugCount', 'DDEV', 'HeuBug', 'HeuBugCount']
outcome = 'RealBug'
features = ['CountPath_Max', 'CountPath_Mean', 'Del_lines', 'Added_lines', 'CountLine', 'CountStmt', 'CountLineCode', 'CountLineCodeExe', 'CountSemicolon', 'CountStmtExe']
# commits - # of commits that modify the file of interest
# Added lines - # of added lines of code
# Count class coupled - # of classes that interact or couple with the class of interest
# LOC - # of lines of code
# RatioCommentToCode - The ratio of lines of comments to lines of code

# process outcome to 0 and 1
train_dataset[outcome] = pd.Categorical(train_dataset[outcome])
train_dataset[outcome] = train_dataset[outcome].cat.codes

test_dataset[outcome] = pd.Categorical(test_dataset[outcome])
test_dataset[outcome] = test_dataset[outcome].cat.codes

X_train = train_dataset.loc[:, features]
X_test = test_dataset.loc[:, features]

y_train = train_dataset.loc[:, outcome]
y_test = test_dataset.loc[:, outcome]

class_labels = ['Clean', 'Defective']

X_train.columns = features
X_test.columns = features
training_data = pd.concat([X_train, y_train], axis=1)
testing_data = pd.concat([X_test, y_test], axis=1)

# %%
from sklearn.ensemble import RandomForestClassifier
our_rf_model = RandomForestClassifier(random_state=0)
our_rf_model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=0)

# %%
import numpy as np
import pandas as pd
# sklearn version: v1.0.1
from sklearn.model_selection import train_test_split
from sklearn.ensemble import (RandomForestClassifier, 
                              AdaBoostClassifier)
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import roc_auc_score
from sklearn.inspection import (partial_dependence, 
                                PartialDependenceDisplay)
import matplotlib.pyplot as plt
import seaborn as sns


file_to_be_explained = 'lucene/backwards/src/test/org/apache/lucene/analysis/BaseTokenStreamTestCase.java'

print(f'Explaining {file_to_be_explained} with PDP')
# Out:
# Explaining lucene/backwards/src/test/org/apache/lucene/analysis/BaseTokenStreamTestCase.java with PDP

# %% [markdown]
# ## Average Value of CountPath_Max

# %%
from sklearn.inspection import partial_dependence
results = partial_dependence(our_rf_model, X_test, [0], kind = 'average')

# %%
plt.plot(results['values'][0], results['average'][0])

# %% [markdown]
# ## Average Value of CountPath_Mean

# %%
from sklearn.inspection import partial_dependence
results = partial_dependence(our_rf_model, X_test, [1], kind = 'average')

# %%
plt.plot(results['values'][0], results['average'][0])

# %% [markdown]
# ## Average Value of Del_lines

# %%
from sklearn.inspection import partial_dependence
results = partial_dependence(our_rf_model, X_test, [2], kind = 'average')

# %%
plt.plot(results['values'][0], results['average'][0])

# %% [markdown]
# ## Average Value of Added_lines

# %%
from sklearn.inspection import partial_dependence
results = partial_dependence(our_rf_model, X_test, [3], kind = 'average')

# %%
plt.plot(results['values'][0], results['average'][0])

# %% [markdown]
# ## Average Value of CountLine

# %%
from sklearn.inspection import partial_dependence
results = partial_dependence(our_rf_model, X_test, [4], kind = 'average')

# %%
plt.plot(results['values'][0], results['average'][0])

# %% [markdown]
# ## Average Value of CountStmt

# %%
from sklearn.inspection import partial_dependence
results = partial_dependence(our_rf_model, X_test, [5], kind = 'average')

# %%
plt.plot(results['values'][0], results['average'][0])

# %% [markdown]
# ## Average Value of CountLineCode

# %%
from sklearn.inspection import partial_dependence
results = partial_dependence(our_rf_model, X_test, [6], kind = 'average')

# %%
plt.plot(results['values'][0], results['average'][0])

# %% [markdown]
# ## Average Value of CountLineCodeExe

# %%
from sklearn.inspection import partial_dependence
results = partial_dependence(our_rf_model, X_test, [7], kind = 'average')

# %%
plt.plot(results['values'][0], results['average'][0])

# %% [markdown]
# ## Average Value of CountSemicolon

# %%
from sklearn.inspection import partial_dependence
results = partial_dependence(our_rf_model, X_test, [8], kind = 'average')

# %%
plt.plot(results['values'][0], results['average'][0])

# %% [markdown]
# ## Average Value of CountStmtExe

# %%
from sklearn.inspection import partial_dependence
results = partial_dependence(our_rf_model, X_test, [9], kind = 'average')

# %%
plt.plot(results['values'][0], results['average'][0])

# %% [markdown]
# ## ICE

# %%
import subprocess
import sys
import importlib
import numpy
import shap

shap.plots.partial_dependence(
    "CountPath_Max", our_rf_model.predict, X_test, ice=True,
    feature_expected_value=True)

# %%
shap.plots.partial_dependence(
    "CountPath_Mean", our_rf_model.predict, X_test, ice=True,
    feature_expected_value=True)

# %%
shap.plots.partial_dependence(
    "Del_lines", our_rf_model.predict, X_test, ice=True,
    feature_expected_value=True)

# %%
shap.plots.partial_dependence(
    "Added_lines", our_rf_model.predict, X_test, ice=True,
    feature_expected_value=True)

# %%
shap.plots.partial_dependence(
    "CountLine", our_rf_model.predict, X_test, ice=True,
    feature_expected_value=True)

# %%
shap.plots.partial_dependence(
    "CountStmt", our_rf_model.predict, X_test, ice=True,
    feature_expected_value=True)

# %%
shap.plots.partial_dependence(
    "CountLineCode", our_rf_model.predict, X_test, ice=True,
    feature_expected_value=True)

# %%
shap.plots.partial_dependence(
    "CountLineCodeExe", our_rf_model.predict, X_test, ice=True,
    feature_expected_value=True)

# %%
shap.plots.partial_dependence(
    "CountSemicolon", our_rf_model.predict, X_test, ice=True,
    feature_expected_value=True)

# %%
shap.plots.partial_dependence(
    "CountStmtExe", our_rf_model.predict, X_test, ice=True,
    feature_expected_value=True)

# %%
import seaborn as sns
import pandas as pd

data1 = pd.read_csv("/Users/saumenduroy/Documents/PhD Life/Explainability + SOAR/Explainers code/Feature Engineering_Explainer implemetation/k=10/k10Chi_Feature Agreement.csv", index_col=0)
data2 = pd.read_csv("/Users/saumenduroy/Documents/PhD Life/Explainability + SOAR/Explainers code/Feature Engineering_Explainer implemetation/k=10/k10Chi_Sign Agreement.csv", index_col=0)
data3 = pd.read_csv("/Users/saumenduroy/Documents/PhD Life/Explainability + SOAR/Explainers code/Feature Engineering_Explainer implemetation/k=10/k10Chi_Rank Agreement.csv", index_col=0)


fig, ax = plt.subplots(1,3, figsize=(30, 6))


sns.set(font_scale=1.2)
sns.heatmap(data1, cmap="coolwarm", annot=True, fmt=".2f", vmin=0, vmax=1, ax= ax[0])
ax[0].title.set_text("Feature Agreement (When k=10)")

sns.heatmap(data2, cmap="coolwarm", annot=True, fmt=".2f", vmin=0, vmax=1, ax= ax[1])
ax[1].title.set_text("Sign Agreement (When k=10)")

sns.heatmap(data3, cmap="coolwarm", annot=True, fmt=".2f", vmin=0, vmax=1, ax= ax[2])
ax[2].title.set_text("Rank Agreement (When k=10)")


plt.show()
