# %%
## Load Data and preparing datasets

# Import for Load Data
from os import listdir
from os.path import isfile, join
import pandas as pd

# Import for Split Data into Training and Testing Samples
from sklearn.model_selection import train_test_split


import os
import numpy as np
from glob import glob
import subprocess
import sys
import importlib
import numpy
import shap
import matplotlib.pyplot as plt
import random
import lime
import lime.lime_tabular
from sklearn.ensemble import RandomForestClassifier
from pyBreakDown.explainer import Explainer
from pyBreakDown.explanation import Explanation
from pyexplainer.pyexplainer_pyexplainer import PyExplainer
import io
import contextlib
import re
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# feature agreement
def calculate_task1(dict1, dict2):
    if len(dict1) == 0 or len(dict2) == 0:
        return 0.00
    keys1 = set(dict1.keys())
    keys2 = set(dict2.keys())
    common_keys = len(keys1.intersection(keys2))
    return common_keys / max(len(dict1), len(dict2))

# Rank Agreement
def calculate_task2(dict1, dict2):
    if len(dict1) == 0 or len(dict2) == 0:
        return 0.00
    keys1 = list(dict1.keys())
    keys2 = list(dict2.keys())
    common_keys = 0
    for i in range(min(len(keys1), len(keys2))):
        if keys1[i] == keys2[i]:
            common_keys += 1
    return common_keys / max(len(dict1), len(dict2))

# Sign Agreement
def calculate_task3(dict1, dict2):
    if len(dict1) == 0 or len(dict2) == 0:
        return 0.00
    common_signs = 0
    total_common = 0
    for key in dict1:
        if key in dict2:
            if dict1[key] * dict2[key] > 0:
                common_signs += 1
            total_common += 1
    if total_common == 0:
        return 0.00
    return common_signs / total_common

file_list = glob("/Users/saumenduroy/Desktop/TOSEM_replicationpackage/data_jira/*.csv")
tested_file = []
print("Total file: ", len(file_list))

for file in file_list:
    print("\n===================\n")
    print("Processing File: ", file)
    main_file=file
    train_dataset = pd.read_csv(file, index_col = 'File')
    
    test_data_list = [f for f in file_list if f != file]
    test_dataset = pd.DataFrame(columns=["File"]+train_dataset.columns.values.tolist())
    for test_file in test_data_list:
        tmp_df = pd.read_csv(test_file)
        test_dataset = pd.DataFrame(np.concatenate([test_dataset.values, tmp_df.values]), columns=tmp_df.columns)
    test_dataset.set_index("File", inplace=True)
    outcome = 'RealBug'
    features = ['ADEV', 'CountDeclMethod', 'MAJOR_COMMIT', 'CountSemicolon', 'SumCyclomatic']
    # commits - # of commits that modify the file of interest
    # Added lines - # of added lines of code
    # Count class coupled - # of classes that interact or couple with the class of interest
    # LOC - # of lines of code
    # RatioCommentToCode - The ratio of lines of comments to lines of code

    # process outcome to 0 and 1
    train_dataset[outcome] = pd.Categorical(train_dataset[outcome])
    train_dataset[outcome] = train_dataset[outcome].cat.codes

    test_dataset[outcome] = pd.Categorical(test_dataset[outcome])
    test_dataset[outcome] = test_dataset[outcome].cat.codes

    X_train = train_dataset.loc[:, features]
    X_test = test_dataset.loc[:, features]

    y_train = train_dataset.loc[:, outcome]
    y_test = test_dataset.loc[:, outcome]

    class_labels = ['Clean', 'Defective']

    X_train.columns = features
    X_test.columns = features
    training_data = pd.concat([X_train, y_train], axis=1)
    testing_data = pd.concat([X_test, y_test], axis=1)

    our_rf_model = RandomForestClassifier(random_state=0)
    our_rf_model.fit(X_train, y_train)  
    
    #### LIME

    # Import for LIME
    
    
    file_to_be_explained = ""
    
    worked = True
    
    while worked:
        try:
            
            random_file = random.choice(testing_data.index.values.tolist())
            if random_file in tested_file:
                continue
            file_to_be_explained = random_file
            # LIME Step 1 - Construct an explainer
            our_lime_explainer = lime.lime_tabular.LimeTabularExplainer(
                                        training_data = X_train.values,  
                                        mode = 'classification',
                                        training_labels = y_train,
                                        feature_names = features,
                                        class_names = class_labels,
                                        discretize_continuous = True)

            # LIME Step 2 - Use the constructed explainer with the predict function 
            # of your predictive model to explain any instance
            lime_local_explanation_of_an_instance = our_lime_explainer.explain_instance(
                                       # X_test[0],
                                      # data_row = X_test.loc['FileName.py', : ], 
                                        data_row = X_test.loc[file_to_be_explained, : ],
                                        predict_fn = our_rf_model.predict_proba, 
                                        num_features = len(features),
                                        top_labels = 1)

            #explainer = lime_tabular.LimeTabularExplainer(X_train, mode = "regression", feature_names = boston_housing.feature_names)
            #explanation = explainer.explain_instance(X_test[0], model.predict, num_features = len(boston_housing.feature_names))
            lime_prob = lime_local_explanation_of_an_instance.predict_proba
            if lime_prob[1] >= 0.67:
                print(f'Explaining {file_to_be_explained} with LIME')
                lime_results = lime_local_explanation_of_an_instance.as_list()
                lime_dict = {}
                for results in lime_results:
                    feat = ""
                    for r in results:
                        ignoring_sym = [">=", ">", "<=", "<", "="]
                        if isinstance(r, str):
                            feat = re.sub(r'[^a-zA-Z\s_]', '', r).rstrip().lstrip()
                        else:
                            if r >= 0:
                                lime_dict[feat] = 1
                            else:
                                lime_dict[feat] = -1
                print(lime_dict)
            
                # Please use the code below to visualise the generated LIME explanation.
                ### save lime output
                # lime_local_explanation_of_an_instance.show_in_notebook()
                
                
                ### SHAP:
                file_to_be_explained_idx = list(X_test.index).index(file_to_be_explained)
                explainer = shap.Explainer(our_rf_model)
                shap_values = explainer(X_test)
                # shap.plots.bar(shap_values[file_to_be_explained_idx, :, 1], show=True)
                explain_file_val = shap_values[file_to_be_explained_idx, :, 1].values.tolist()
                shap_dict = {}
                test_columns = X_test.columns.values.tolist()
                for col_index in range(0, len(test_columns)):
                    shap_dict[test_columns[col_index]] = explain_file_val[col_index]
                sorted_shap_dict = dict(sorted(shap_dict.items(), key=lambda item: abs(item[1]), reverse=True))
                for keys in sorted_shap_dict.keys():
                    if sorted_shap_dict[keys] >= 0:
                        sorted_shap_dict[keys] = 1
                    else:
                        sorted_shap_dict[keys] = -1
                print(sorted_shap_dict)
                
                
                #Breakdown
                our_rf_model = RandomForestClassifier(random_state=0)
                our_rf_model.fit(X_train, y_train)
                #make explainer object
                exp = Explainer(clf=our_rf_model, data= X_train, colnames=features)
                #make explanation object that contains all information
                explanation = exp.explain(observation=X_test.iloc[file_to_be_explained_idx,:].values,direction="up",useIntercept=True)
                # explanation.visualize()
                output_buffer = io.StringIO()
                with contextlib.redirect_stdout(output_buffer):
                    explanation.text()

                captured_output = output_buffer.getvalue()
                with open("test.txt", "w") as file:
                    file.write(captured_output)
                    
                breakdown_df = pd.read_csv("test.txt", sep='\t')
                
                counter=-1
                breakdown_dict={}
                for _, row in breakdown_df.iterrows():
                    counter+=1
                    if counter < 1:
                        continue
                    row_val = row.values.tolist()
                    row_val = row_val[0].split(" ")
                    row_val_main = []
                    for c in row_val:
                        if len(c) == 0 or c == "=":
                            continue
                        row_val_main.append(c)
                    if float(row_val_main[2]) >= 0:
                        breakdown_dict[row_val_main[0]] = 1
                    else:
                        breakdown_dict[row_val_main[0]] = -1
                    if counter == len(features):
                        break
                print(breakdown_dict)
                
                
                #### pyexplainer
                rf_model = RandomForestClassifier(random_state=0)
                rf_model.fit(X_train, y_train) 
                np.random.seed(0)
                pyexp = PyExplainer(X_train = X_train,
                                           y_train = y_train,
                                           indep = X_train.columns,
                                           dep = outcome,
                                           top_k_rules=5,
                                           blackbox_model = rf_model)

                # PyExplainer Step 2 - Generate the rule-based explanation of an instance to be explained
                exp_obj = pyexp.explain(X_explain = X_test.loc[file_to_be_explained,:].to_frame().transpose(),
                                        y_explain = pd.Series(bool(y_test.loc[file_to_be_explained]), 
                                                                      index = [file_to_be_explained],
                                                                      name = outcome),
                                        search_function = 'crossoverinterpolation',
                                        max_iter=1000,
                                        max_rules=20,
                                        random_state=0,
                                        reuse_local_model=True)

                # Please use the code below to visualise the generated PyExplainer explanation (What-If interactive visualisation).
                pyexp.visualise(exp_obj, title="Why this file is predicted as defect-introducing?")
                top_rules = pyexp.parse_top_rules(exp_obj['top_k_positive_rules'],exp_obj['top_k_negative_rules'])['top_tofollow_rules']
                bullet_data = pyexp.generate_bullet_data(pyexp.parse_top_rules(exp_obj['top_k_positive_rules'],exp_obj['top_k_negative_rules']))
                pyexp_dict = {}
                for rules in range(0, len(top_rules)):
                    variable = top_rules[rules]['variable']
                    value = float(top_rules[rules]['value'])
                    marker = bullet_data[rules]['markers'][0]
                    if top_rules[rules]['lessthan']:
                        if marker <= value:
                            pyexp_dict[variable] = 1
                        else:
                            pyexp_dict[variable] = -1
                    else:
                        if marker > value:
                            pyexp_dict[variable] = 1
                        else:
                            pyexp_dict[variable] = -1

                print(pyexp_dict)
                worked=False
                tested_file.append(file_to_be_explained)
                    
                data_task1 = np.array([
                    [calculate_task1(lime_dict, lime_dict), calculate_task1(lime_dict, sorted_shap_dict), calculate_task1(lime_dict, breakdown_dict), calculate_task1(lime_dict, pyexp_dict)],
                    [calculate_task1(sorted_shap_dict, lime_dict), calculate_task1(sorted_shap_dict, sorted_shap_dict), calculate_task1(sorted_shap_dict, breakdown_dict), calculate_task1(sorted_shap_dict, pyexp_dict)],
                    [calculate_task1(breakdown_dict, lime_dict), calculate_task1(breakdown_dict, sorted_shap_dict), calculate_task1(breakdown_dict, breakdown_dict), calculate_task1(breakdown_dict, pyexp_dict)],
                    [calculate_task1(pyexp_dict, lime_dict), calculate_task1(pyexp_dict, sorted_shap_dict), calculate_task1(pyexp_dict, breakdown_dict), calculate_task1(pyexp_dict, pyexp_dict)]
                ])

                data_task2 = np.array([
                    [calculate_task2(lime_dict, lime_dict), calculate_task2(lime_dict, sorted_shap_dict), calculate_task2(lime_dict, breakdown_dict), calculate_task2(lime_dict, pyexp_dict)],
                    [calculate_task2(sorted_shap_dict, lime_dict), calculate_task2(sorted_shap_dict, sorted_shap_dict), calculate_task2(sorted_shap_dict, breakdown_dict), calculate_task2(sorted_shap_dict, pyexp_dict)],
                    [calculate_task2(breakdown_dict, lime_dict), calculate_task2(breakdown_dict, sorted_shap_dict), calculate_task2(breakdown_dict, breakdown_dict), calculate_task2(breakdown_dict, pyexp_dict)],
                    [calculate_task2(pyexp_dict, lime_dict), calculate_task2(pyexp_dict, sorted_shap_dict), calculate_task2(pyexp_dict, breakdown_dict), calculate_task2(pyexp_dict, pyexp_dict)]
                ])

                data_task3 = np.array([
                    [calculate_task3(lime_dict, lime_dict), calculate_task3(lime_dict, sorted_shap_dict), calculate_task3(lime_dict, breakdown_dict), calculate_task3(lime_dict, pyexp_dict)],
                    [calculate_task3(sorted_shap_dict, lime_dict), calculate_task3(sorted_shap_dict, sorted_shap_dict), calculate_task3(sorted_shap_dict, breakdown_dict), calculate_task3(sorted_shap_dict, pyexp_dict)],
                    [calculate_task3(breakdown_dict, lime_dict), calculate_task3(breakdown_dict, sorted_shap_dict), calculate_task3(breakdown_dict, breakdown_dict), calculate_task3(breakdown_dict, pyexp_dict)],
                    [calculate_task3(pyexp_dict, lime_dict), calculate_task3(pyexp_dict, sorted_shap_dict), calculate_task3(pyexp_dict, breakdown_dict), calculate_task3(pyexp_dict, pyexp_dict)]
                ])

                # Row and column labels
                pairs = ["LIME", "SHAP", "BreakDown", "PyExplainer"]
                tasks = ["Feature Agreement", "Rank Agreement", "Sign Agreement"]

                # Create the figure and subplots
                fig, axes = plt.subplots(1, 3, figsize=(18, 6))
                fig.suptitle("Processing file: "+main_file.split("/")[-1])

                # Plot heatmap for FA
                sns.heatmap(data_task1, annot=True, cmap="coolwarm", fmt=".2f", linewidths=.5, xticklabels=pairs, yticklabels=pairs, ax=axes[0])
                axes[0].set_title(tasks[0] + " (When k="+str(len(features))+")")
                
                # Plot heatmap for SA
                sns.heatmap(data_task3, annot=True, cmap="coolwarm", fmt=".2f", linewidths=.5, xticklabels=pairs, yticklabels=pairs, ax=axes[1])
                axes[1].set_title(tasks[2] + " (When k="+str(len(features))+")")

                # Plot heatmap for RA
                sns.heatmap(data_task2, annot=True, cmap="coolwarm", fmt=".2f", linewidths=.5, xticklabels=pairs, yticklabels=pairs, ax=axes[2])
                axes[2].set_title(tasks[1] + " (When k="+str(len(features))+")")

                plt.tight_layout()
                fig_file_name = main_file.split("/")[-1].replace(".", "_")+"-"+file_to_be_explained.replace("/", "_").replace(".","_")+"_fa_ra_sa_plot.png"
                plt.savefig(fig_file_name)
                
            else:
                continue
            
        except Exception as e:
            pass
# Out:
# Total file:  32
#
# ===================
#
# Processing File:  /Users/saumenduroy/Desktop/TOSEM_replicationpackage/data_jira/activemq-5.2.0.csv
# Explaining wicket-core/src/test/java/org/apache/wicket/redirect/intercept/TargetPage.java with LIME
# {'MAJOR_COMMIT': 1, 'ADEV': 1, 'SumCyclomatic': -1, 'CountDeclMethod': -1, 'CountSemicolon': 1}
# {'MAJOR_COMMIT': 1, 'ADEV': 1, 'CountSemicolon': 1, 'CountDeclMethod': 1, 'SumCyclomatic': -1}
# {'SumCyclomatic': -1, 'CountDeclMethod': -1, 'ADEV': -1, 'MAJOR_COMMIT': 1, 'CountSemicolon': 1}
# HBox(children=(Label(value='Risk Score: '), FloatProgress(value=0.0, bar_style='info', layout=Layout(width='40…
# Output(layout=Layout(border='3px solid black'))
# FloatSlider(value=1.0, continuous_update=False, description='#1 The value of CountDeclMethod is less than 1', …
# {'CountDeclMethod': -1}
#
# ===================
#
# Processing File:  /Users/saumenduroy/Desktop/TOSEM_replicationpackage/data_jira/derby-10.5.1.1.csv
# Explaining solr/src/java/org/apache/solr/spelling/SpellCheckCollator.java with LIME
# {'ADEV': 1, 'SumCyclomatic': -1, 'CountSemicolon': -1, 'MAJOR_COMMIT': 1, 'CountDeclMethod': 1}
# {'ADEV': 1, 'MAJOR_COMMIT': 1, 'SumCyclomatic': 1, 'CountDeclMethod': 1, 'CountSemicolon': 1}
# {'ADEV': 1, 'MAJOR_COMMIT': 1, 'CountDeclMethod': 1, 'CountSemicolon': 1, 'SumCyclomatic': 1}
# /Users/saumenduroy/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/saumenduroy/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/saumenduroy/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/saumenduroy/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/saumenduroy/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# set top_k_rules failed, top_k_rules should be int in range 1 - 15 (both included)
# PyExplainer can not find rules to avoid!
# This could lead to blank explanation UI!
# Please check whether the global model is properly trained with sufficient training data.
# actual value of SumCyclomatic < 0, currently do not support this type of rule
# HBox(children=(Label(value='Risk Score: '), FloatProgress(value=0.0, bar_style='info', layout=Layout(width='40…
# Output(layout=Layout(border='3px solid black'))
# FloatSlider(value=68.0, continuous_update=False, description='#1 The value of CountSemicolon is more than 68',…
# FloatSlider(value=16.0, continuous_update=False, description='#2 The value of SumCyclomatic is more than 16', …
# set top_k_rules failed, top_k_rules should be int in range 1 - 15 (both included)
# PyExplainer can not find rules to avoid!
# This could lead to blank explanation UI!
# Please check whether the global model is properly trained with sufficient training data.
# set top_k_rules failed, top_k_rules should be int in range 1 - 15 (both included)
# PyExplainer can not find rules to avoid!
# This could lead to blank explanation UI!
# Please check whether the global model is properly trained with sufficient training data.
# actual value of SumCyclomatic < 0, currently do not support this type of rule
# {'CountSemicolon': -1, 'SumCyclomatic': -1}
#
# ===================
#
# Processing File:  /Users/saumenduroy/Desktop/TOSEM_replicationpackage/data_jira/hive-0.9.0.csv
# Explaining src/main/java/org/apache/hadoop/hbase/client/Result.java with LIME
# {'CountSemicolon': 1, 'SumCyclomatic': 1, 'ADEV': 1, 'MAJOR_COMMIT': 1, 'CountDeclMethod': -1}
# {'CountSemicolon': 1, 'SumCyclomatic': 1, 'ADEV': 1, 'MAJOR_COMMIT': 1, 'CountDeclMethod': 1}
# {'CountSemicolon': 1, 'ADEV': 1, 'CountDeclMethod': 1, 'MAJOR_COMMIT': 1, 'SumCyclomatic': 1}
# /Users/saumenduroy/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/saumenduroy/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/saumenduroy/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/saumenduroy/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/saumenduroy/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# HBox(children=(Label(value='Risk Score: '), FloatProgress(value=0.0, bar_style='info', layout=Layout(width='40…
# Output(layout=Layout(border='3px solid black'))
# FloatSlider(value=5.0, continuous_update=False, description='#1 The value of ADEV is more than 5', layout=Layo…
# {'ADEV': -1}
#
# ===================
#
# Processing File:  /Users/saumenduroy/Desktop/TOSEM_replicationpackage/data_jira/activemq-5.0.0.csv
# Explaining solr/src/java/org/apache/solr/handler/component/QueryComponent.java with LIME
# {'MAJOR_COMMIT': 1, 'ADEV': 1, 'CountSemicolon': 1, 'SumCyclomatic': 1, 'CountDeclMethod': 1}
# {'MAJOR_COMMIT': 1, 'ADEV': 1, 'CountSemicolon': 1, 'SumCyclomatic': 1, 'CountDeclMethod': -1}
# {'MAJOR_COMMIT': 1, 'ADEV': 1, 'CountDeclMethod': 1, 'CountSemicolon': 1, 'SumCyclomatic': 1}
# /Users/saumenduroy/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/saumenduroy/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/saumenduroy/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/saumenduroy/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
# set top_k_rules failed, top_k_rules should be int in range 1 - 15 (both included)
# PyExplainer can not find rules to follow!
# This could lead to blank explanation UI!
# Please check whether the global model is properly trained with sufficient training data.
# PyExplainer can not find rules to avoid!
# This could lead to blank explanation UI!
# Please check whether the global model is properly trained with sufficient training data.
#   n_iter_i = _check_optimize_result(
# /Users/saumenduroy/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# HBox(children=(Label(value='Risk Score: '), FloatProgress(value=0.0, bar_style='info', layout=Layout(width='40…
# Output(layout=Layout(border='3px solid black'))
# set top_k_rules failed, top_k_rules should be int in range 1 - 15 (both included)
# PyExplainer can not find rules to follow!
# This could lead to blank explanation UI!
# Please check whether the global model is properly trained with sufficient training data.
# PyExplainer can not find rules to avoid!
# This could lead to blank explanation UI!
# Please check whether the global model is properly trained with sufficient training data.
# set top_k_rules failed, top_k_rules should be int in range 1 - 15 (both included)
# PyExplainer can not find rules to follow!
# This could lead to blank explanation UI!
# Please check whether the global model is properly trained with sufficient training data.
# PyExplainer can not find rules to avoid!
# This could lead to blank explanation UI!
# Please check whether the global model is properly trained with sufficient training data.
# {}
#
# ===================
#
# Processing File:  /Users/saumenduroy/Desktop/TOSEM_replicationpackage/data_jira/jruby-1.4.0.csv
# Explaining hcatalog/core/src/main/java/org/apache/hcatalog/data/HCatRecordSerDe.java with LIME
# {'SumCyclomatic': 1, 'CountDeclMethod': 1, 'CountSemicolon': 1, 'MAJOR_COMMIT': 1, 'ADEV': 1}
# {'MAJOR_COMMIT': 1, 'CountSemicolon': 1, 'SumCyclomatic': 1, 'CountDeclMethod': 1, 'ADEV': 1}
# {'CountSemicolon': -1, 'SumCyclomatic': -1, 'ADEV': 1, 'CountDeclMethod': 1, 'MAJOR_COMMIT': 1}
# set top_k_rules failed, top_k_rules should be int in range 1 - 15 (both included)
# PyExplainer can not find rules to avoid!
# This could lead to blank explanation UI!
# Please check whether the global model is properly trained with sufficient training data.
# HBox(children=(Label(value='Risk Score: '), FloatProgress(value=0.0, bar_style='info', layout=Layout(width='40…
# Output(layout=Layout(border='3px solid black'))
# FloatSlider(value=13.0, continuous_update=False, description='#1 The value of CountDeclMethod is more than 13'…
# FloatSlider(value=3.0, continuous_update=False, description='#2 The value of MAJOR_COMMIT is less than 3', lay…
# FloatSlider(value=5.0, continuous_update=False, description='#3 The value of ADEV is more than 5', layout=Layo…
# set top_k_rules failed, top_k_rules should be int in range 1 - 15 (both included)
# PyExplainer can not find rules to avoid!
# This could lead to blank explanation UI!
# Please check whether the global model is properly trained with sufficient training data.
# set top_k_rules failed, top_k_rules should be int in range 1 - 15 (both included)
# PyExplainer can not find rules to avoid!
# This could lead to blank explanation UI!
# Please check whether the global model is properly trained with sufficient training data.
# {'CountDeclMethod': 1, 'MAJOR_COMMIT': 1, 'ADEV': -1}
#
# ===================
#
# Processing File:  /Users/saumenduroy/Desktop/TOSEM_replicationpackage/data_jira/hbase-0.94.0.csv
# Explaining src/org/jruby/ext/openssl/X509Cert.java with LIME
# {'ADEV': 1, 'CountSemicolon': 1, 'MAJOR_COMMIT': -1, 'SumCyclomatic': 1, 'CountDeclMethod': 1}
# {'ADEV': 1, 'CountSemicolon': 1, 'MAJOR_COMMIT': -1, 'SumCyclomatic': 1, 'CountDeclMethod': 1}
# {'ADEV': 1, 'CountSemicolon': 1, 'CountDeclMethod': 1, 'MAJOR_COMMIT': 1, 'SumCyclomatic': 1}
# set top_k_rules failed, top_k_rules should be int in range 1 - 15 (both included)
# PyExplainer can not find rules to avoid!
# This could lead to blank explanation UI!
# Please check whether the global model is properly trained with sufficient training data.
# HBox(children=(Label(value='Risk Score: '), FloatProgress(value=0.0, bar_style='info', layout=Layout(width='40…
# Output(layout=Layout(border='3px solid black'))
# FloatSlider(value=56.0, continuous_update=False, description='#1 The value of ADEV is more than 56', layout=La…
# FloatSlider(value=82.0, continuous_update=False, description='#2 The value of SumCyclomatic is less than 82', …
# set top_k_rules failed, top_k_rules should be int in range 1 - 15 (both included)
# PyExplainer can not find rules to avoid!
# This could lead to blank explanation UI!
# Please check whether the global model is properly trained with sufficient training data.
# set top_k_rules failed, top_k_rules should be int in range 1 - 15 (both included)
# PyExplainer can not find rules to avoid!
# This could lead to blank explanation UI!
# Please check whether the global model is properly trained with sufficient training data.
# {'ADEV': -1, 'SumCyclomatic': 1}
#
# ===================
#
# Processing File:  /Users/saumenduroy/Desktop/TOSEM_replicationpackage/data_jira/camel-2.11.0.csv
# Explaining java/testing/org/apache/derbyTesting/functionTests/tests/derbynet/prepStmt.java with LIME
# {'SumCyclomatic': 1, 'ADEV': 1, 'CountDeclMethod': 1, 'MAJOR_COMMIT': 1, 'CountSemicolon': 1}
# {'SumCyclomatic': 1, 'ADEV': 1, 'CountSemicolon': 1, 'MAJOR_COMMIT': 1, 'CountDeclMethod': 1}
# {'SumCyclomatic': -1, 'CountDeclMethod': 1, 'MAJOR_COMMIT': 1, 'ADEV': 1, 'CountSemicolon': 1}
# set top_k_rules failed, top_k_rules should be int in range 1 - 15 (both included)
# PyExplainer can not find rules to avoid!
# This could lead to blank explanation UI!
# Please check whether the global model is properly trained with sufficient training data.
# HBox(children=(Label(value='Risk Score: '), FloatProgress(value=0.0, bar_style='info', layout=Layout(width='40…
# Output(layout=Layout(border='3px solid black'))
# FloatSlider(value=29.0, continuous_update=False, description='#1 The value of CountDeclMethod is more than 29'…
# FloatSlider(value=114.0, continuous_update=False, description='#2 The value of SumCyclomatic is more than 114'…
# FloatSlider(value=4.0, continuous_update=False, description='#3 The value of MAJOR_COMMIT is more than 4', lay…
# set top_k_rules failed, top_k_rules should be int in range 1 - 15 (both included)
# PyExplainer can not find rules to avoid!
# This could lead to blank explanation UI!
# Please check whether the global model is properly trained with sufficient training data.
# set top_k_rules failed, top_k_rules should be int in range 1 - 15 (both included)
# PyExplainer can not find rules to avoid!
# This could lead to blank explanation UI!
# Please check whether the global model is properly trained with sufficient training data.
# {'CountDeclMethod': 1, 'SumCyclomatic': -1, 'MAJOR_COMMIT': -1}
#
# ===================
#
# Processing File:  /Users/saumenduroy/Desktop/TOSEM_replicationpackage/data_jira/jruby-1.1.csv
# Explaining src/main/java/org/apache/hadoop/hbase/master/HMaster.java with LIME
# {'ADEV': 1, 'MAJOR_COMMIT': 1, 'SumCyclomatic': 1, 'CountSemicolon': 1, 'CountDeclMethod': 1}
# {'ADEV': 1, 'SumCyclomatic': 1, 'CountSemicolon': 1, 'MAJOR_COMMIT': 1, 'CountDeclMethod': 1}
# {'ADEV': 1, 'MAJOR_COMMIT': 1, 'SumCyclomatic': 1, 'CountSemicolon': 1, 'CountDeclMethod': 1}
# HBox(children=(Label(value='Risk Score: '), FloatProgress(value=0.0, bar_style='info', layout=Layout(width='40…
# Output(layout=Layout(border='3px solid black'))
# FloatSlider(value=4.0, continuous_update=False, description='#1 The value of MAJOR_COMMIT is more than 4', lay…
# {'MAJOR_COMMIT': 1}
#
# ===================
#
# Processing File:  /Users/saumenduroy/Desktop/TOSEM_replicationpackage/data_jira/jruby-1.7.0.preview1.csv
# Explaining activemq-broker/src/main/java/org/apache/activemq/network/DemandForwardingBridgeSupport.java with LIME
# {'MAJOR_COMMIT': 1, 'CountDeclMethod': 1, 'SumCyclomatic': 1, 'CountSemicolon': 1, 'ADEV': 1}
# {'MAJOR_COMMIT': 1, 'SumCyclomatic': 1, 'CountDeclMethod': 1, 'CountSemicolon': 1, 'ADEV': -1}
# {'ADEV': -1, 'CountSemicolon': -1, 'CountDeclMethod': 1, 'SumCyclomatic': 1, 'MAJOR_COMMIT': 1}
# HBox(children=(Label(value='Risk Score: '), FloatProgress(value=0.0, bar_style='info', layout=Layout(width='40…
# Output(layout=Layout(border='3px solid black'))
# FloatSlider(value=15.0, continuous_update=False, description='#1 The value of ADEV is more than 15', layout=La…
# FloatSlider(value=631.0, continuous_update=False, description='#2 The value of CountSemicolon is less than 631…
# {'ADEV': 1, 'CountSemicolon': 1}
#
# ===================
#
# Processing File:  /Users/saumenduroy/Desktop/TOSEM_replicationpackage/data_jira/activemq-5.1.0.csv
# Explaining lucene/src/test/org/apache/lucene/search/spans/TestBasics.java with LIME
# {'ADEV': 1, 'CountSemicolon': 1, 'SumCyclomatic': 1, 'CountDeclMethod': 1, 'MAJOR_COMMIT': 1}
# {'ADEV': 1, 'CountSemicolon': 1, 'MAJOR_COMMIT': 1, 'CountDeclMethod': 1, 'SumCyclomatic': 1}
# {'ADEV': 1, 'CountSemicolon': 1, 'CountDeclMethod': 1, 'MAJOR_COMMIT': 1, 'SumCyclomatic': 1}
# set top_k_rules failed, top_k_rules should be int in range 1 - 15 (both included)
# PyExplainer can not find rules to avoid!
# This could lead to blank explanation UI!
# Please check whether the global model is properly trained with sufficient training data.
# HBox(children=(Label(value='Risk Score: '), FloatProgress(value=0.0, bar_style='info', layout=Layout(width='40…
# Output(layout=Layout(border='3px solid black'))
# FloatSlider(value=27.0, continuous_update=False, description='#1 The value of CountDeclMethod is less than 27'…
# FloatSlider(value=258.0, continuous_update=False, description='#2 The value of CountSemicolon is more than 258…
# FloatSlider(value=31.0, continuous_update=False, description='#3 The value of SumCyclomatic is more than 31', …
# set top_k_rules failed, top_k_rules should be int in range 1 - 15 (both included)
# PyExplainer can not find rules to avoid!
# This could lead to blank explanation UI!
# Please check whether the global model is properly trained with sufficient training data.
# set top_k_rules failed, top_k_rules should be int in range 1 - 15 (both included)
# PyExplainer can not find rules to avoid!
# This could lead to blank explanation UI!
# Please check whether the global model is properly trained with sufficient training data.
# {'CountDeclMethod': -1, 'CountSemicolon': -1, 'SumCyclomatic': 1}
#
# ===================
#
# Processing File:  /Users/saumenduroy/Desktop/TOSEM_replicationpackage/data_jira/lucene-2.9.0.csv
# Explaining lucene/src/java/org/apache/lucene/search/IndexSearcher.java with LIME
# {'CountSemicolon': 1, 'ADEV': 1, 'MAJOR_COMMIT': 1, 'CountDeclMethod': 1, 'SumCyclomatic': -1}
# {'ADEV': 1, 'CountSemicolon': 1, 'MAJOR_COMMIT': 1, 'SumCyclomatic': 1, 'CountDeclMethod': -1}
# {'CountSemicolon': 1, 'MAJOR_COMMIT': 1, 'ADEV': 1, 'SumCyclomatic': 1, 'CountDeclMethod': 1}
# /Users/saumenduroy/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# HBox(children=(Label(value='Risk Score: '), FloatProgress(value=0.0, bar_style='info', layout=Layout(width='40…
# Output(layout=Layout(border='3px solid black'))
# FloatSlider(value=94.0, continuous_update=False, description='#1 The value of SumCyclomatic is more than 94', …
# FloatSlider(value=4.0, continuous_update=False, description='#2 The value of MAJOR_COMMIT is less than 4', lay…
# {'SumCyclomatic': -1, 'MAJOR_COMMIT': -1}
#
# ===================
#
# Processing File:  /Users/saumenduroy/Desktop/TOSEM_replicationpackage/data_jira/activemq-5.3.0.csv
# Explaining src/org/jruby/ir/operands/UndefinedValue.java with LIME
# {'SumCyclomatic': 1, 'ADEV': 1, 'CountDeclMethod': 1, 'MAJOR_COMMIT': 1, 'CountSemicolon': 1}
# {'ADEV': 1, 'SumCyclomatic': 1, 'CountDeclMethod': 1, 'MAJOR_COMMIT': 1, 'CountSemicolon': 1}
# {'ADEV': 1, 'CountDeclMethod': 1, 'CountSemicolon': 1, 'MAJOR_COMMIT': 1, 'SumCyclomatic': 1}
# PyExplainer can not find rules to follow!
# This could lead to blank explanation UI!
# Please check whether the global model is properly trained with sufficient training data.
# HBox(children=(Label(value='Risk Score: '), FloatProgress(value=0.0, bar_style='info', layout=Layout(width='40…
# Output(layout=Layout(border='3px solid black'))
# PyExplainer can not find rules to follow!
# This could lead to blank explanation UI!
# Please check whether the global model is properly trained with sufficient training data.
# PyExplainer can not find rules to follow!
# This could lead to blank explanation UI!
# Please check whether the global model is properly trained with sufficient training data.
# {}
#
# ===================
#
# Processing File:  /Users/saumenduroy/Desktop/TOSEM_replicationpackage/data_jira/camel-2.9.0.csv
# Explaining src/main/java/org/apache/hadoop/hbase/thrift/generated/Hbase.java with LIME
# {'SumCyclomatic': 1, 'ADEV': 1, 'CountSemicolon': 1, 'MAJOR_COMMIT': 1, 'CountDeclMethod': 1}
# {'SumCyclomatic': 1, 'CountSemicolon': 1, 'ADEV': 1, 'CountDeclMethod': 1, 'MAJOR_COMMIT': 1}
# {'ADEV': -1, 'CountDeclMethod': 1, 'MAJOR_COMMIT': 1, 'SumCyclomatic': 1, 'CountSemicolon': 1}
# /Users/saumenduroy/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/saumenduroy/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# HBox(children=(Label(value='Risk Score: '), FloatProgress(value=0.0, bar_style='info', layout=Layout(width='40…
# Output(layout=Layout(border='3px solid black'))
# FloatSlider(value=2.0, continuous_update=False, description='#1 The value of MAJOR_COMMIT is more than 2', lay…
# FloatSlider(value=10214.0, continuous_update=False, description='#2 The value of SumCyclomatic is more than 10…
# {'MAJOR_COMMIT': -1, 'SumCyclomatic': -1}
#
# ===================
#
# Processing File:  /Users/saumenduroy/Desktop/TOSEM_replicationpackage/data_jira/hbase-0.95.0.csv
# Explaining hbase-client/src/main/java/org/apache/hadoop/hbase/coprocessor/CoprocessorException.java with LIME
# {'ADEV': -1, 'MAJOR_COMMIT': -1, 'CountDeclMethod': -1, 'CountSemicolon': -1, 'SumCyclomatic': -1}
# {'CountSemicolon': 1, 'CountDeclMethod': 1, 'SumCyclomatic': 1, 'ADEV': 1, 'MAJOR_COMMIT': 1}
# {'SumCyclomatic': -1, 'MAJOR_COMMIT': -1, 'CountSemicolon': 1, 'CountDeclMethod': 1, 'ADEV': 1}
# set top_k_rules failed, top_k_rules should be int in range 1 - 15 (both included)
# PyExplainer can not find rules to avoid!
# This could lead to blank explanation UI!
# Please check whether the global model is properly trained with sufficient training data.
# HBox(children=(Label(value='Risk Score: '), FloatProgress(value=0.0, bar_style='info', layout=Layout(width='40…
# Output(layout=Layout(border='3px solid black'))
# FloatSlider(value=8.0, continuous_update=False, description='#1 The value of CountSemicolon is less than 8', l…
# set top_k_rules failed, top_k_rules should be int in range 1 - 15 (both included)
# PyExplainer can not find rules to avoid!
# This could lead to blank explanation UI!
# Please check whether the global model is properly trained with sufficient training data.
# set top_k_rules failed, top_k_rules should be int in range 1 - 15 (both included)
# PyExplainer can not find rules to avoid!
# This could lead to blank explanation UI!
# Please check whether the global model is properly trained with sufficient training data.
# {'CountSemicolon': 1}
#
# ===================
#
# Processing File:  /Users/saumenduroy/Desktop/TOSEM_replicationpackage/data_jira/camel-2.10.0.csv
# Explaining src/org/jruby/ir/transformations/inlining/InlinerInfo.java with LIME
# {'CountSemicolon': 1, 'SumCyclomatic': 1, 'ADEV': 1, 'MAJOR_COMMIT': 1, 'CountDeclMethod': -1}
# {'ADEV': 1, 'CountSemicolon': 1, 'SumCyclomatic': 1, 'CountDeclMethod': 1, 'MAJOR_COMMIT': 1}
# {'ADEV': 1, 'CountSemicolon': 1, 'SumCyclomatic': 1, 'CountDeclMethod': 1, 'MAJOR_COMMIT': 1}
# HBox(children=(Label(value='Risk Score: '), FloatProgress(value=0.0, bar_style='info', layout=Layout(width='40…
# Output(layout=Layout(border='3px solid black'))
# FloatSlider(value=135.0, continuous_update=False, description='#1 The value of CountSemicolon is more than 135…
# {'CountSemicolon': -1}
#
# ===================
#
# Processing File:  /Users/saumenduroy/Desktop/TOSEM_replicationpackage/data_jira/lucene-3.1.csv
# Explaining src/org/jruby/ext/openssl/PKeyDSA.java with LIME
# {'ADEV': 1, 'CountSemicolon': 1, 'CountDeclMethod': 1, 'SumCyclomatic': 1, 'MAJOR_COMMIT': 1}
# {'ADEV': 1, 'CountDeclMethod': 1, 'SumCyclomatic': 1, 'CountSemicolon': 1, 'MAJOR_COMMIT': -1}
# {'ADEV': 1, 'CountSemicolon': 1, 'CountDeclMethod': 1, 'MAJOR_COMMIT': 1, 'SumCyclomatic': 1}
# HBox(children=(Label(value='Risk Score: '), FloatProgress(value=0.0, bar_style='info', layout=Layout(width='40…
# Output(layout=Layout(border='3px solid black'))
# FloatSlider(value=1.0, continuous_update=False, description='#1 The value of MAJOR_COMMIT is more than 1', lay…
# {'MAJOR_COMMIT': 1}
#
# ===================
#
# Processing File:  /Users/saumenduroy/Desktop/TOSEM_replicationpackage/data_jira/jruby-1.5.0.csv
# Explaining solr/src/test/org/apache/solr/SolrTestCaseJ4.java with LIME
# {'ADEV': 1, 'CountDeclMethod': 1, 'SumCyclomatic': 1, 'MAJOR_COMMIT': 1, 'CountSemicolon': 1}
# {'ADEV': 1, 'CountDeclMethod': 1, 'SumCyclomatic': 1, 'MAJOR_COMMIT': 1, 'CountSemicolon': 1}
# {'ADEV': 1, 'CountDeclMethod': 1, 'SumCyclomatic': 1, 'MAJOR_COMMIT': 1, 'CountSemicolon': 1}
# set top_k_rules failed, top_k_rules should be int in range 1 - 15 (both included)
# PyExplainer can not find rules to avoid!
# This could lead to blank explanation UI!
# Please check whether the global model is properly trained with sufficient training data.
# HBox(children=(Label(value='Risk Score: '), FloatProgress(value=0.0, bar_style='info', layout=Layout(width='40…
# Output(layout=Layout(border='3px solid black'))
# FloatSlider(value=95.0, continuous_update=False, description='#1 The value of SumCyclomatic is more than 95', …
# FloatSlider(value=18.0, continuous_update=False, description='#2 The value of ADEV is more than 18', layout=La…
# FloatSlider(value=5.0, continuous_update=False, description='#3 The value of MAJOR_COMMIT is more than 5', lay…
# set top_k_rules failed, top_k_rules should be int in range 1 - 15 (both included)
# PyExplainer can not find rules to avoid!
# This could lead to blank explanation UI!
# Please check whether the global model is properly trained with sufficient training data.
# set top_k_rules failed, top_k_rules should be int in range 1 - 15 (both included)
# PyExplainer can not find rules to avoid!
# This could lead to blank explanation UI!
# Please check whether the global model is properly trained with sufficient training data.
# {'SumCyclomatic': -1, 'ADEV': -1, 'MAJOR_COMMIT': -1}
#
# ===================
#
# Processing File:  /Users/saumenduroy/Desktop/TOSEM_replicationpackage/data_jira/hbase-0.95.2.csv
# Explaining java/testing/org/apache/derbyTesting/functionTests/tests/jdbcapi/lobStreams.java with LIME
# {'MAJOR_COMMIT': 1, 'CountSemicolon': 1, 'ADEV': 1, 'SumCyclomatic': 1, 'CountDeclMethod': -1}
# {'MAJOR_COMMIT': 1, 'CountSemicolon': 1, 'SumCyclomatic': 1, 'ADEV': 1, 'CountDeclMethod': 1}
# {'CountSemicolon': 1, 'ADEV': 1, 'SumCyclomatic': -1, 'MAJOR_COMMIT': 1, 'CountDeclMethod': 1}
# HBox(children=(Label(value='Risk Score: '), FloatProgress(value=0.0, bar_style='info', layout=Layout(width='40…
# Output(layout=Layout(border='3px solid black'))
# FloatSlider(value=14.0, continuous_update=False, description='#1 The value of CountDeclMethod is more than 14'…
# {'CountDeclMethod': 1}
#
# ===================
#
# Processing File:  /Users/saumenduroy/Desktop/TOSEM_replicationpackage/data_jira/wicket-1.3.0-incubating-beta-1.csv
# Explaining lucene/src/test/org/apache/lucene/index/TestDoc.java with LIME
# {'ADEV': 1, 'MAJOR_COMMIT': 1, 'SumCyclomatic': 1, 'CountSemicolon': -1, 'CountDeclMethod': -1}
# {'ADEV': 1, 'MAJOR_COMMIT': 1, 'SumCyclomatic': 1, 'CountSemicolon': -1, 'CountDeclMethod': 1}
# {'ADEV': 1, 'CountDeclMethod': 1, 'SumCyclomatic': 1, 'MAJOR_COMMIT': 1, 'CountSemicolon': 1}
# set top_k_rules failed, top_k_rules should be int in range 1 - 15 (both included)
# PyExplainer can not find rules to avoid!
# This could lead to blank explanation UI!
# Please check whether the global model is properly trained with sufficient training data.
# HBox(children=(Label(value='Risk Score: '), FloatProgress(value=0.0, bar_style='info', layout=Layout(width='40…
# Output(layout=Layout(border='3px solid black'))
# FloatSlider(value=14.0, continuous_update=False, description='#1 The value of ADEV is more than 14', layout=La…
# FloatSlider(value=120.0, continuous_update=False, description='#2 The value of CountSemicolon is less than 120…
# FloatSlider(value=7.0, continuous_update=False, description='#3 The value of CountDeclMethod is more than 7', …
# set top_k_rules failed, top_k_rules should be int in range 1 - 15 (both included)
# PyExplainer can not find rules to avoid!
# This could lead to blank explanation UI!
# Please check whether the global model is properly trained with sufficient training data.
# set top_k_rules failed, top_k_rules should be int in range 1 - 15 (both included)
# PyExplainer can not find rules to avoid!
# This could lead to blank explanation UI!
# Please check whether the global model is properly trained with sufficient training data.
# {'ADEV': -1, 'CountSemicolon': 1, 'CountDeclMethod': 1}
#
# ===================
#
# Processing File:  /Users/saumenduroy/Desktop/TOSEM_replicationpackage/data_jira/groovy-1_5_7.csv
# Explaining src/main/java/org/apache/hadoop/hbase/KeyValue.java with LIME
# {'ADEV': 1, 'MAJOR_COMMIT': 1, 'CountSemicolon': 1, 'SumCyclomatic': 1, 'CountDeclMethod': 1}
# {'CountSemicolon': 1, 'SumCyclomatic': 1, 'ADEV': 1, 'MAJOR_COMMIT': 1, 'CountDeclMethod': 1}
# {'CountDeclMethod': -1, 'MAJOR_COMMIT': 1, 'SumCyclomatic': 1, 'CountSemicolon': 1, 'ADEV': 1}
# set top_k_rules failed, top_k_rules should be int in range 1 - 15 (both included)
# PyExplainer can not find rules to avoid!
# This could lead to blank explanation UI!
# Please check whether the global model is properly trained with sufficient training data.
# HBox(children=(Label(value='Risk Score: '), FloatProgress(value=0.0, bar_style='info', layout=Layout(width='40…
# Output(layout=Layout(border='3px solid black'))
# FloatSlider(value=4.0, continuous_update=False, description='#1 The value of MAJOR_COMMIT is less than 4', lay…
# FloatSlider(value=514.0, continuous_update=False, description='#2 The value of CountSemicolon is more than 514…
# FloatSlider(value=247.0, continuous_update=False, description='#3 The value of SumCyclomatic is more than 247'…
# set top_k_rules failed, top_k_rules should be int in range 1 - 15 (both included)
# PyExplainer can not find rules to avoid!
# This could lead to blank explanation UI!
# Please check whether the global model is properly trained with sufficient training data.
# set top_k_rules failed, top_k_rules should be int in range 1 - 15 (both included)
# PyExplainer can not find rules to avoid!
# This could lead to blank explanation UI!
# Please check whether the global model is properly trained with sufficient training data.
# {'MAJOR_COMMIT': 1, 'CountSemicolon': -1, 'SumCyclomatic': -1}
#
# ===================
#
# Processing File:  /Users/saumenduroy/Desktop/TOSEM_replicationpackage/data_jira/groovy-1_6_BETA_2.csv
# Explaining solr/src/java/org/apache/solr/core/SolrCore.java with LIME
# {'ADEV': 1, 'MAJOR_COMMIT': 1, 'SumCyclomatic': 1, 'CountSemicolon': 1, 'CountDeclMethod': 1}
# {'MAJOR_COMMIT': 1, 'ADEV': 1, 'SumCyclomatic': 1, 'CountSemicolon': 1, 'CountDeclMethod': 1}
# {'CountDeclMethod': -1, 'CountSemicolon': -1, 'ADEV': 1, 'MAJOR_COMMIT': 1, 'SumCyclomatic': 1}
# PyExplainer can not find rules to follow!
# This could lead to blank explanation UI!
# Please check whether the global model is properly trained with sufficient training data.
# HBox(children=(Label(value='Risk Score: '), FloatProgress(value=0.0, bar_style='info', layout=Layout(width='40…
# Output(layout=Layout(border='3px solid black'))
# PyExplainer can not find rules to follow!
# This could lead to blank explanation UI!
# Please check whether the global model is properly trained with sufficient training data.
# PyExplainer can not find rules to follow!
# This could lead to blank explanation UI!
# Please check whether the global model is properly trained with sufficient training data.
# {}
#
# ===================
#
# Processing File:  /Users/saumenduroy/Desktop/TOSEM_replicationpackage/data_jira/derby-10.3.1.4.csv
# Explaining hbase-examples/src/main/java/org/apache/hadoop/hbase/thrift2/DemoClient.java with LIME
# {'ADEV': 1, 'MAJOR_COMMIT': 1, 'CountSemicolon': 1, 'SumCyclomatic': -1, 'CountDeclMethod': -1}
# {'ADEV': 1, 'SumCyclomatic': 1, 'MAJOR_COMMIT': 1, 'CountSemicolon': 1, 'CountDeclMethod': -1}
# {'ADEV': 1, 'CountDeclMethod': 1, 'SumCyclomatic': 1, 'CountSemicolon': 1, 'MAJOR_COMMIT': 1}
# PyExplainer can not find rules to follow!
# This could lead to blank explanation UI!
# Please check whether the global model is properly trained with sufficient training data.
# HBox(children=(Label(value='Risk Score: '), FloatProgress(value=0.0, bar_style='info', layout=Layout(width='40…
# Output(layout=Layout(border='3px solid black'))
# PyExplainer can not find rules to follow!
# This could lead to blank explanation UI!
# Please check whether the global model is properly trained with sufficient training data.
# PyExplainer can not find rules to follow!
# This could lead to blank explanation UI!
# Please check whether the global model is properly trained with sufficient training data.
# {}
#
# ===================
#
# Processing File:  /Users/saumenduroy/Desktop/TOSEM_replicationpackage/data_jira/groovy-1_6_BETA_1.csv
# Explaining src/org/jruby/ext/openssl/Request.java with LIME
# {'ADEV': 1, 'SumCyclomatic': 1, 'MAJOR_COMMIT': 1, 'CountDeclMethod': 1, 'CountSemicolon': 1}
# {'ADEV': 1, 'SumCyclomatic': 1, 'MAJOR_COMMIT': 1, 'CountSemicolon': 1, 'CountDeclMethod': 1}
# {'ADEV': 1, 'MAJOR_COMMIT': 1, 'CountSemicolon': 1, 'CountDeclMethod': 1, 'SumCyclomatic': 1}
# HBox(children=(Label(value='Risk Score: '), FloatProgress(value=0.0, bar_style='info', layout=Layout(width='40…
# Output(layout=Layout(border='3px solid black'))
# FloatSlider(value=23.0, continuous_update=False, description='#1 The value of CountDeclMethod is less than 23'…
# FloatSlider(value=47.0, continuous_update=False, description='#2 The value of SumCyclomatic is less than 47', …
# {'CountDeclMethod': -1, 'SumCyclomatic': 1}
#
# ===================
#
# Processing File:  /Users/saumenduroy/Desktop/TOSEM_replicationpackage/data_jira/lucene-2.3.0.csv
# Explaining src/org/jruby/ir/dataflow/DataFlowProblem.java with LIME
# {'ADEV': 1, 'MAJOR_COMMIT': 1, 'CountSemicolon': 1, 'SumCyclomatic': -1, 'CountDeclMethod': 1}
# {'ADEV': 1, 'MAJOR_COMMIT': 1, 'CountSemicolon': 1, 'SumCyclomatic': -1, 'CountDeclMethod': -1}
# {'ADEV': 1, 'MAJOR_COMMIT': 1, 'CountSemicolon': 1, 'CountDeclMethod': 1, 'SumCyclomatic': 1}
# set top_k_rules failed, top_k_rules should be int in range 1 - 15 (both included)
# PyExplainer can not find rules to avoid!
# This could lead to blank explanation UI!
# Please check whether the global model is properly trained with sufficient training data.
# HBox(children=(Label(value='Risk Score: '), FloatProgress(value=0.0, bar_style='info', layout=Layout(width='40…
# Output(layout=Layout(border='3px solid black'))
# FloatSlider(value=1.0, continuous_update=False, description='#1 The value of MAJOR_COMMIT is more than 1', lay…
# FloatSlider(value=60.0, continuous_update=False, description='#2 The value of CountSemicolon is more than 60',…
# FloatSlider(value=19.0, continuous_update=False, description='#3 The value of CountDeclMethod is less than 19'…
# set top_k_rules failed, top_k_rules should be int in range 1 - 15 (both included)
# PyExplainer can not find rules to avoid!
# This could lead to blank explanation UI!
# Please check whether the global model is properly trained with sufficient training data.
# set top_k_rules failed, top_k_rules should be int in range 1 - 15 (both included)
# PyExplainer can not find rules to avoid!
# This could lead to blank explanation UI!
# Please check whether the global model is properly trained with sufficient training data.
# {'MAJOR_COMMIT': -1, 'CountSemicolon': -1, 'CountDeclMethod': 1}
#
# ===================
#
# Processing File:  /Users/saumenduroy/Desktop/TOSEM_replicationpackage/data_jira/wicket-1.3.0-beta2.csv
# Explaining src/main/java/org/apache/hadoop/hbase/regionserver/wal/HLogSplitter.java with LIME
# {'ADEV': 1, 'CountSemicolon': 1, 'MAJOR_COMMIT': 1, 'SumCyclomatic': 1, 'CountDeclMethod': -1}
# {'ADEV': 1, 'MAJOR_COMMIT': 1, 'CountSemicolon': 1, 'SumCyclomatic': 1, 'CountDeclMethod': 1}
# {'ADEV': 1, 'MAJOR_COMMIT': 1, 'CountSemicolon': 1, 'CountDeclMethod': 1, 'SumCyclomatic': 1}
# set top_k_rules failed, top_k_rules should be int in range 1 - 15 (both included)
# PyExplainer can not find rules to avoid!
# This could lead to blank explanation UI!
# Please check whether the global model is properly trained with sufficient training data.
# HBox(children=(Label(value='Risk Score: '), FloatProgress(value=0.0, bar_style='info', layout=Layout(width='40…
# Output(layout=Layout(border='3px solid black'))
# FloatSlider(value=15.0, continuous_update=False, description='#1 The value of ADEV is more than 15', layout=La…
# FloatSlider(value=54.0, continuous_update=False, description='#2 The value of CountDeclMethod is more than 54'…
# FloatSlider(value=468.0, continuous_update=False, description='#3 The value of CountSemicolon is more than 468…
# set top_k_rules failed, top_k_rules should be int in range 1 - 15 (both included)
# PyExplainer can not find rules to avoid!
# This could lead to blank explanation UI!
# Please check whether the global model is properly trained with sufficient training data.
# set top_k_rules failed, top_k_rules should be int in range 1 - 15 (both included)
# PyExplainer can not find rules to avoid!
# This could lead to blank explanation UI!
# Please check whether the global model is properly trained with sufficient training data.
# {'ADEV': -1, 'CountDeclMethod': -1, 'CountSemicolon': -1}
#
# ===================
#
# Processing File:  /Users/saumenduroy/Desktop/TOSEM_replicationpackage/data_jira/camel-1.4.0.csv
# Explaining solr/src/java/org/apache/solr/handler/AnalysisRequestHandler.java with LIME
# {'ADEV': 1, 'MAJOR_COMMIT': 1, 'SumCyclomatic': 1, 'CountSemicolon': 1, 'CountDeclMethod': 1}
# {'MAJOR_COMMIT': 1, 'ADEV': 1, 'SumCyclomatic': 1, 'CountSemicolon': 1, 'CountDeclMethod': 1}
# {'CountSemicolon': -1, 'ADEV': 1, 'MAJOR_COMMIT': 1, 'CountDeclMethod': 1, 'SumCyclomatic': 1}
# set top_k_rules failed, top_k_rules should be int in range 1 - 15 (both included)
# PyExplainer can not find rules to avoid!
# This could lead to blank explanation UI!
# Please check whether the global model is properly trained with sufficient training data.
# HBox(children=(Label(value='Risk Score: '), FloatProgress(value=0.0, bar_style='info', layout=Layout(width='40…
# Output(layout=Layout(border='3px solid black'))
# FloatSlider(value=10.0, continuous_update=False, description='#1 The value of CountDeclMethod is less than 10'…
# FloatSlider(value=113.0, continuous_update=False, description='#2 The value of CountSemicolon is more than 113…
# FloatSlider(value=35.0, continuous_update=False, description='#3 The value of SumCyclomatic is less than 35', …
# set top_k_rules failed, top_k_rules should be int in range 1 - 15 (both included)
# PyExplainer can not find rules to avoid!
# This could lead to blank explanation UI!
# Please check whether the global model is properly trained with sufficient training data.
# set top_k_rules failed, top_k_rules should be int in range 1 - 15 (both included)
# PyExplainer can not find rules to avoid!
# This could lead to blank explanation UI!
# Please check whether the global model is properly trained with sufficient training data.
# {'CountDeclMethod': -1, 'CountSemicolon': -1, 'SumCyclomatic': -1}
#
# ===================
#
# Processing File:  /Users/saumenduroy/Desktop/TOSEM_replicationpackage/data_jira/derby-10.2.1.6.csv
# Explaining activemq-unit-tests/src/test/java/org/apache/activemq/openwire/v8/JournalTraceTest.java with LIME
# {'ADEV': -1, 'CountSemicolon': -1, 'MAJOR_COMMIT': -1, 'SumCyclomatic': -1, 'CountDeclMethod': -1}
# {'CountSemicolon': 1, 'SumCyclomatic': 1, 'CountDeclMethod': 1, 'ADEV': -1, 'MAJOR_COMMIT': -1}
# {'ADEV': -1, 'SumCyclomatic': -1, 'MAJOR_COMMIT': -1, 'CountDeclMethod': -1, 'CountSemicolon': 1}
# set top_k_rules failed, top_k_rules should be int in range 1 - 15 (both included)
# PyExplainer can not find rules to avoid!
# This could lead to blank explanation UI!
# Please check whether the global model is properly trained with sufficient training data.
# HBox(children=(Label(value='Risk Score: '), FloatProgress(value=0.0, bar_style='info', layout=Layout(width='40…
# Output(layout=Layout(border='3px solid black'))
# FloatSlider(value=2.0, continuous_update=False, description='#1 The value of SumCyclomatic is more than 2', la…
# FloatSlider(value=2.0, continuous_update=False, description='#2 The value of CountDeclMethod is less than 2', …
# FloatSlider(value=13.0, continuous_update=False, description='#3 The value of CountSemicolon is less than 13',…
# set top_k_rules failed, top_k_rules should be int in range 1 - 15 (both included)
# PyExplainer can not find rules to avoid!
# This could lead to blank explanation UI!
# Please check whether the global model is properly trained with sufficient training data.
# set top_k_rules failed, top_k_rules should be int in range 1 - 15 (both included)
# PyExplainer can not find rules to avoid!
# This could lead to blank explanation UI!
# Please check whether the global model is properly trained with sufficient training data.
# {'SumCyclomatic': 1, 'CountDeclMethod': -1, 'CountSemicolon': -1}
#
# ===================
#
# Processing File:  /Users/saumenduroy/Desktop/TOSEM_replicationpackage/data_jira/wicket-1.5.3.csv
# Explaining activemq-broker/src/main/java/org/apache/activemq/broker/region/Queue.java with LIME
# {'CountSemicolon': 1, 'SumCyclomatic': 1, 'ADEV': 1, 'CountDeclMethod': 1, 'MAJOR_COMMIT': 1}
# {'CountSemicolon': 1, 'SumCyclomatic': 1, 'ADEV': 1, 'CountDeclMethod': 1, 'MAJOR_COMMIT': 1}
# {'CountDeclMethod': -1, 'ADEV': 1, 'CountSemicolon': 1, 'SumCyclomatic': 1, 'MAJOR_COMMIT': 1}
# HBox(children=(Label(value='Risk Score: '), FloatProgress(value=0.0, bar_style='info', layout=Layout(width='40…
# Output(layout=Layout(border='3px solid black'))
# FloatSlider(value=5.0, continuous_update=False, description='#1 The value of ADEV is more than 5', layout=Layo…
# FloatSlider(value=114.0, continuous_update=False, description='#2 The value of CountDeclMethod is more than 11…
# {'ADEV': 1, 'CountDeclMethod': -1}
#
# ===================
#
# Processing File:  /Users/saumenduroy/Desktop/TOSEM_replicationpackage/data_jira/activemq-5.8.0.csv
# Explaining hcatalog/core/src/main/java/org/apache/hive/hcatalog/cli/SemanticAnalysis/CreateTableHook.java with LIME
# {'ADEV': 1, 'SumCyclomatic': 1, 'MAJOR_COMMIT': 1, 'CountSemicolon': 1, 'CountDeclMethod': 1}
# {'ADEV': 1, 'SumCyclomatic': 1, 'MAJOR_COMMIT': 1, 'CountSemicolon': 1, 'CountDeclMethod': 1}
# {'ADEV': 1, 'SumCyclomatic': 1, 'MAJOR_COMMIT': 1, 'CountDeclMethod': 1, 'CountSemicolon': 1}
# set top_k_rules failed, top_k_rules should be int in range 1 - 15 (both included)
# PyExplainer can not find rules to avoid!
# This could lead to blank explanation UI!
# Please check whether the global model is properly trained with sufficient training data.
# HBox(children=(Label(value='Risk Score: '), FloatProgress(value=0.0, bar_style='info', layout=Layout(width='40…
# Output(layout=Layout(border='3px solid black'))
# FloatSlider(value=2.0, continuous_update=False, description='#1 The value of CountDeclMethod is more than 2', …
# FloatSlider(value=84.0, continuous_update=False, description='#2 The value of CountSemicolon is more than 84',…
# FloatSlider(value=4.0, continuous_update=False, description='#3 The value of ADEV is less than 4', layout=Layo…
# set top_k_rules failed, top_k_rules should be int in range 1 - 15 (both included)
# PyExplainer can not find rules to avoid!
# This could lead to blank explanation UI!
# Please check whether the global model is properly trained with sufficient training data.
# set top_k_rules failed, top_k_rules should be int in range 1 - 15 (both included)
# PyExplainer can not find rules to avoid!
# This could lead to blank explanation UI!
# Please check whether the global model is properly trained with sufficient training data.
# {'CountDeclMethod': 1, 'CountSemicolon': 1, 'ADEV': 1}
#
# ===================
#
# Processing File:  /Users/saumenduroy/Desktop/TOSEM_replicationpackage/data_jira/hive-0.10.0.csv
# Explaining solr/src/test/org/apache/solr/handler/DocumentAnalysisRequestHandlerTest.java with LIME
# {'ADEV': 1, 'CountDeclMethod': 1, 'CountSemicolon': 1, 'SumCyclomatic': -1, 'MAJOR_COMMIT': 1}
# {'ADEV': 1, 'CountSemicolon': 1, 'CountDeclMethod': 1, 'MAJOR_COMMIT': 1, 'SumCyclomatic': 1}
# {'ADEV': 1, 'CountDeclMethod': 1, 'SumCyclomatic': 1, 'MAJOR_COMMIT': 1, 'CountSemicolon': 1}
# set top_k_rules failed, top_k_rules should be int in range 1 - 15 (both included)
# PyExplainer can not find rules to avoid!
# This could lead to blank explanation UI!
# Please check whether the global model is properly trained with sufficient training data.
# HBox(children=(Label(value='Risk Score: '), FloatProgress(value=0.0, bar_style='info', layout=Layout(width='40…
# Output(layout=Layout(border='3px solid black'))
# FloatSlider(value=3.0, continuous_update=False, description='#1 The value of MAJOR_COMMIT is less than 3', lay…
# FloatSlider(value=4.0, continuous_update=False, description='#2 The value of ADEV is less than 4', layout=Layo…
# FloatSlider(value=12.0, continuous_update=False, description='#3 The value of SumCyclomatic is less than 12', …
# set top_k_rules failed, top_k_rules should be int in range 1 - 15 (both included)
# PyExplainer can not find rules to avoid!
# This could lead to blank explanation UI!
# Please check whether the global model is properly trained with sufficient training data.
# set top_k_rules failed, top_k_rules should be int in range 1 - 15 (both included)
# PyExplainer can not find rules to avoid!
# This could lead to blank explanation UI!
# Please check whether the global model is properly trained with sufficient training data.
# {'MAJOR_COMMIT': 1, 'ADEV': 1, 'SumCyclomatic': -1}
#
# ===================
#
# Processing File:  /Users/saumenduroy/Desktop/TOSEM_replicationpackage/data_jira/lucene-3.0.0.csv
# Explaining src/main/java/org/apache/hadoop/hbase/regionserver/HRegionServer.java with LIME
# {'ADEV': 1, 'CountSemicolon': 1, 'MAJOR_COMMIT': 1, 'SumCyclomatic': -1, 'CountDeclMethod': 1}
# {'ADEV': 1, 'CountSemicolon': 1, 'MAJOR_COMMIT': 1, 'CountDeclMethod': 1, 'SumCyclomatic': -1}
# {'SumCyclomatic': -1, 'MAJOR_COMMIT': 1, 'CountDeclMethod': -1, 'CountSemicolon': 1, 'ADEV': 1}
# HBox(children=(Label(value='Risk Score: '), FloatProgress(value=0.0, bar_style='info', layout=Layout(width='40…
# Output(layout=Layout(border='3px solid black'))
# FloatSlider(value=5.0, continuous_update=False, description='#1 The value of MAJOR_COMMIT is more than 5', lay…
# {'MAJOR_COMMIT': -1}
#
# ===================
#
# Processing File:  /Users/saumenduroy/Desktop/TOSEM_replicationpackage/data_jira/hive-0.12.0.csv
# Explaining src/org/jruby/ir/representations/CFG.java with LIME
# {'ADEV': 1, 'CountSemicolon': 1, 'CountDeclMethod': 1, 'MAJOR_COMMIT': 1, 'SumCyclomatic': 1}
# {'ADEV': 1, 'CountSemicolon': 1, 'SumCyclomatic': -1, 'MAJOR_COMMIT': 1, 'CountDeclMethod': 1}
# {'ADEV': 1, 'CountSemicolon': 1, 'CountDeclMethod': 1, 'MAJOR_COMMIT': 1, 'SumCyclomatic': 1}
# /Users/saumenduroy/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/saumenduroy/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/saumenduroy/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/saumenduroy/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/saumenduroy/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# set top_k_rules failed, top_k_rules should be int in range 1 - 15 (both included)
# PyExplainer can not find rules to follow!
# This could lead to blank explanation UI!
# Please check whether the global model is properly trained with sufficient training data.
# PyExplainer can not find rules to avoid!
# This could lead to blank explanation UI!
# Please check whether the global model is properly trained with sufficient training data.
# HBox(children=(Label(value='Risk Score: '), FloatProgress(value=0.0, bar_style='info', layout=Layout(width='40…
# Output(layout=Layout(border='3px solid black'))
# set top_k_rules failed, top_k_rules should be int in range 1 - 15 (both included)
# PyExplainer can not find rules to follow!
# This could lead to blank explanation UI!
# Please check whether the global model is properly trained with sufficient training data.
# PyExplainer can not find rules to avoid!
# This could lead to blank explanation UI!
# Please check whether the global model is properly trained with sufficient training data.
# set top_k_rules failed, top_k_rules should be int in range 1 - 15 (both included)
# PyExplainer can not find rules to follow!
# This could lead to blank explanation UI!
# Please check whether the global model is properly trained with sufficient training data.
# PyExplainer can not find rules to avoid!
# This could lead to blank explanation UI!
# Please check whether the global model is properly trained with sufficient training data.
# {}
